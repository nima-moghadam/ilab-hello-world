# %% [markdown]
# # Running InstructLab with a GPU
#
# <ul>
# <li>Contributors: InstructLab team and IBM Research Technology Education team:
# <li>Questions and support: kochel@us.ibm.com, IBM.Research.JupyterLab@ibm.com
# <li>Version: 1.0.14
# <li>Release date: 2025-03-20
# <li>Compute requirements: Colab with GPU
# </ul>

# %% [markdown]
# # Summary
# This Jupyter notebook demonstrates InstructLab, an open source AI project that facilitates knowledge and skills contributions to Large Language Models (LLMs). InstructLab uses a novel synthetic data-based alignment tuning method for Large Language Models introduced in this [paper](https://arxiv.org/abs/2403.01081). The open source InstructLab repository is available [here](https://github.com/instructlab/instructlab) and provides additional documentation on using InstructLab.
#
# The InstructLab method consists of three major components:
# * **Taxonomy-driven data curation:**  The taxonomy is a set of training data curated by humans as examples of new knowledge and skills for the model.
# * **Large-scale synthetic data generation:** A teacher model is used to generate new examples based on the seed training data. Since synthetic data can vary in quality, InstructLab adds an automated step to refine the example answers, ensuring they are grounded and safe.
# * **Iterative model alignment tuning:** The model is retrained based on the synthetic data. The InstructLab method includes two tuning phases: knowledge tuning, followed by skill tuning.
#
# <img src="https://github.com/KenOcheltree/ilab-colab/blob/main/data/images/Flow.png?raw=1" width="800">
#
# InstructLab can take the form of an open source installation or a Red Hat AI InstructLab installation. In this notebook, we will demonstrate the open source version of InstructLab running on Colab with a GPU, broken into the following major sequential sections:
# * Configuring InstructLab
# * Generating Syntehtic Data
# * Training with InstructLab
# * Inferencing with InstructLab

# %% [markdown]
# # Running this Notebook
#
# **IMPORTANT:** This notebook must be run within a Colab GPU runtime. You can check you are running with a GPU by selecting Runtime-> Change Runtime Type and confirming that a GPU Runtime is selected. While this notebook can be started on a free Colab account, the GPUs availabe with a free access do not have sufficient memory to run InstructLab training.
#
# You can run this notebook either:
# - Running All Cells by selecting Runtime->Run all
# - Cell by cell by selecting the arrow on each code cell and running them sequentially.
#
# Once the Configuring Instructlab section has been run, the other sections of this notebook can be repeatedly run on other data sets.

# %% [markdown]
# # Section 1. Configure InstructLab
#
# ## Step 1.1 Environment Configuration
# Replicate the ilab data repository containing the pip requirements and data files and run the pip installs that require a reset.
#
# **IMPORTANT:** Run the next cell, allow it to complete running, then Restart the session , run the following cell to specify parameters and then you can run the remainder of the notebook. Ignore any spurious pip install warnings or errors.
#
# After selecting parameters, the remainder of this notebook can be run either:
# - Running All Cells by selecting Runtime->Run cell and below
# - Cell by cell by selecting the arrow on each code cell and running them sequentially.

# %%
# Run this cell, then perform the requested Reset
import os

    #!git clone https://github.com/KenOcheltree/ilab.git
# !pip install numpy==1.26.4 torch==2.5.1 psutil==7.0.0 pillow==10.4.0
# Out:
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: torch==2.5.1 in /usr/local/lib/python3.11/dist-packages (2.5.1)
# Requirement already satisfied: psutil==7.0.0 in /usr/local/lib/python3.11/dist-packages (7.0.0)
# Requirement already satisfied: pillow==10.4.0 in /usr/local/lib/python3.11/dist-packages (10.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.5.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.5.1) (3.0.2)

# %%
import os
if not os.path.exists("ilab-hello-world"):
    # !git clone https://github.com/nima-moghadam/ilab-hello-world.git

# %%
# !git fetch https://github.com/nima-moghadam/ilab-hello-world.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %% [markdown]
# ## Step 1.2 Optionally, provide your own InstructLab QNA data set
#
# You can optionally provide your own InstructLab QNA file for processing in this step.
#
# **Note:** You may want to run this notebook with an existing dataset before creating your own to understand the InstructLab flow.
#
# Follow these steps to add your own dataset:
# 1. Create your own qna.yaml file following the directions on the InstructLab taxonomy [readme](https://github.com/instructlab/taxonomy).
# 1. Create a questions.txt file with related sample questions to use on inferencing.
# 1. Add your qna.yaml and sample questions.txt files to the /content/ilab/data/your_content_1 folder or the /content/ilab/data/your_content_2 folder by dragging and dropping them in the desired folder.
# 1. Double click on the /content/ilab/config.json file to edit and specify the qna_location where your data resides within the Dewey Decimal classification system. Close and save the config.json file.
# 1. You can now specify to run with your own data by selecting **Your Content 1** or **Your Content 2** in the next code cell.

# %% [markdown]
# ## Step 1.3 Select InstructLab Parameters
# Run this next cell, select the following parameters, then follow the direction in the next text cell to run the notebook.
#
# We've provided question-and-answer files for these datasets: "2024 Oscar Awards Ceremony" and "Quantum Roadmap and Patterns" and "Artificial Intelligence Agents". Feel free to choose one of these datasets, or select your own custom dataset in the cell below.

# %%
# Run this second cell to show parameters
import ipywidgets as widgets
#See instructions on placing your hf_token in colab userdata
from google.colab import userdata
# hf_token=userdata.get('hf_token')
hf_token="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"


# data_set = widgets.ToggleButtons(
#     options=['2024 Oscars', 'Quantum', 'Agentic AI', 'Your Content 1', 'Your Content 2'],
#     description='Dataset:', style={"button_width": "auto"}
# )
# sdg_pipe = widgets.ToggleButtons(
#     options=['Simple', 'Full with GPU'], description='Processing:', style={"button_width": "auto"}
# )
# instr=widgets.ToggleButtons(
#     options=['Default (>450)','>15', '>50', '>200', '>500', '>1000'],
#     description='# of QNAs:', style={"button_width": "auto"}
# )
# train_pipe = widgets.ToggleButtons(
#     options=['Simple with GPU','Accelerated GPU'],description='Processing',style={"button_width":"auto"}
# )
# epoch=widgets.ToggleButtons(
#     options=['1', '2', '3', '4', '5', '10', '15'],description='Epochs:',style={"button_width":"auto"}
# )
# it=widgets.ToggleButtons(
#     options=['1', '3', '5','10','20','50','100','200'],description='Iterations:',style={"button_width":"auto"}
# )
# questions=widgets.ToggleButtons(options=['Yes','No'],description='Live Q&A:',style={"button_width":"auto"})
# download=widgets.ToggleButtons(options=['Yes','No'],description='Download:',style={"button_width":"auto"}
# )

data_set = "realstate"
sdg_pipe = "Full with GPU"
instr = 'Default (>450)'
train_pipe = "Accelerated GPU"
epoch = "3"
it = "1"
questions = "Yes"
download = "No"



# print("\nSelect the Dataset for this run:")
# display(data_set)
# print("Select the Synthetic Data Generation parameter to use:")
# sdg_pipe.value='Simple'
# display(sdg_pipe)
# # instr.value = 'Default (>450)'
# display(instr)
# print("Select the Training parameters to use:")
# # train_pipe.value='Simple with GPU'
# #display(train_pipe)
# # epoch.value="3"
# display(epoch)
# # it.value="5"
# display(it)
# print("Select what to do with the model after training:")
# questions.value="Yes"
# display(questions)
# download.value="No"
# display(download)


print("After selecting the parameters, select the next cell and then choose Runtime->Run cell and below")
print("When that run completes, you can come here, choose different parameters and rerun at the next cell with Runtime->Run cell and below")
print("Note: You can also go back and rerun individual sections of the notebook with different parameters.")
# Out:
# After selecting the parameters, select the next cell and then choose Runtime->Run cell and below
# When that run completes, you can come here, choose different parameters and rerun at the next cell with Runtime->Run cell and below
# Note: You can also go back and rerun individual sections of the notebook with different parameters.

# %% [markdown]
# test

# %% [markdown]
# ## 1.4 Complete Environment Set Up and Optionally Run All
# This next code cell installs the remainder of the reuired pip packages and takes about 7 minutes to run.
#
# If you perform **Runtime->Run cell and below** on this cell, the rest of notebook will take about an hour to run. After running, it will present a prompt for providing questions to the pre-trained and trained models to test improvements in the model.
#
# **Note:** Please ignore the pip dependency errors that appear in the output of the pip installs. They do not affect the successful running of Instructlab.

# %%
# Run the rest of the notebook by selecting this third cell and choosing "Runtime->Run cell and below"
# !pip cache remove llama_cpp_python
# !pip install -r ilab-hello-world/requirements_gpu.txt
# !pip list
# Out:
# WARNING: No matching packages for pattern "llama_cpp_python"
# Files removed: 0
# Collecting llama_cpp_python==0.3.6 (from llama_cpp_python[server]==0.3.6->-r ilab-hello-world/requirements_gpu.txt (line 3))
#   Downloading llama_cpp_python-0.3.6.tar.gz (66.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 MB 9.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting instructlab==0.25 (from instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading instructlab-0.25.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 5.7 MB/s eta 0:00:00
# Collecting vllm==0.7.3 (from -r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading vllm-0.7.3-cp38-abi3-manylinux1_x86_64.whl.metadata (25 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from llama_cpp_python==0.3.6->llama_cpp_python[server]==0.3.6->-r ilab-hello-world/requirements_gpu.txt (line 3)) (4.13.2)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from llama_cpp_python==0.3.6->llama_cpp_python[server]==0.3.6->-r ilab-hello-world/requirements_gpu.txt (line 3)) (1.26.4)
# Collecting diskcache>=5.6.1 (from llama_cpp_python==0.3.6->llama_cpp_python[server]==0.3.6->-r ilab-hello-world/requirements_gpu.txt (line 3))
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: jinja2>=2.11.3 in /usr/local/lib/python3.11/dist-packages (from llama_cpp_python==0.3.6->llama_cpp_python[server]==0.3.6->-r ilab-hello-world/requirements_gpu.txt (line 3)) (3.1.6)
# Collecting boto3>=1.35.96 (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading boto3-1.38.29-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /usr/local/lib/python3.11/dist-packages (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (8.2.1)
# Collecting click-didyoumean>=0.3.0 (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading click_didyoumean-0.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting datasets>=2.18.0 (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (3.18.0)
# Collecting gguf>=0.6.0 (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading gguf-0.17.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: GitPython>=3.1.42 in /usr/local/lib/python3.11/dist-packages (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (3.1.44)
# Requirement already satisfied: httpx>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (0.28.1)
# Collecting instructlab-eval>=0.5.1 (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading instructlab_eval-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting instructlab-quantize>=0.1.0 (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading instructlab_quantize-0.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting instructlab-schema>=0.4.2 (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading instructlab_schema-0.4.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting instructlab-sdg>=0.7.3 (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading instructlab_sdg-0.8.2-py3-none-any.whl.metadata (9.1 kB)
# Collecting instructlab-training>=0.8.0 (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading instructlab_training-0.11-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: openai>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (1.82.1)
# Requirement already satisfied: peft>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (0.15.2)
# Requirement already satisfied: prompt-toolkit>=3.0.38 in /usr/local/lib/python3.11/dist-packages (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (3.0.51)
# Requirement already satisfied: pydantic>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (2.11.5)
# Collecting pydantic_yaml>=1.2.0 (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading pydantic_yaml-1.5.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (6.0.2)
# Requirement already satisfied: rich>=13.3.1 in /usr/local/lib/python3.11/dist-packages (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (13.9.4)
# Collecting rouge-score>=0.1.2 (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ruamel.yaml>=0.17.0 (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading ruamel.yaml-0.18.12-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (0.2.0)
# Requirement already satisfied: tokenizers>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (0.21.1)
# Requirement already satisfied: toml>=0.10.2 in /usr/local/lib/python3.11/dist-packages (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (0.10.2)
# Requirement already satisfied: torch<2.6.0,>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (2.5.1)
# Requirement already satisfied: tqdm>=4.66.2 in /usr/local/lib/python3.11/dist-packages (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (4.67.1)
# Collecting transformers<4.51.0,>=4.41.2 (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading transformers-4.50.3-py3-none-any.whl.metadata (39 kB)
# Collecting trl<0.15.0,>=0.12.2 (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading trl-0.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: wandb>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (0.19.11)
# Collecting xdg-base-dirs>=6.0.1 (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading xdg_base_dirs-6.0.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: psutil>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (7.0.0)
# Requirement already satisfied: huggingface_hub>=0.1.8 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_transfer]>=0.1.8->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (0.32.2)
# Collecting haystack-ai>=2.8 (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading haystack_ai-2.14.1-py3-none-any.whl.metadata (14 kB)
# Collecting docling-core>=2.10.0 (from docling-core[chunking]>=2.10.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading docling_core-2.33.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting docling>=2.18.0 (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading docling-2.36.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sentence-transformers>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (4.1.0)
# Requirement already satisfied: numba==0.60.0 in /usr/local/lib/python3.11/dist-packages (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (0.60.0)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (2.32.3)
# Collecting blake3 (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading blake3-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (9.0.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (5.29.5)
# Requirement already satisfied: fastapi!=0.113.*,!=0.114.0,>=0.107.0 in /usr/local/lib/python3.11/dist-packages (from fastapi[standard]!=0.113.*,!=0.114.0,>=0.107.0; python_version >= "3.9"->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (0.115.12)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (3.11.15)
# Requirement already satisfied: prometheus_client>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (0.22.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (10.4.0)
# Collecting prometheus-fastapi-instrumentator>=7.0.0 (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading prometheus_fastapi_instrumentator-7.1.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: tiktoken>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (0.9.0)
# Collecting lm-format-enforcer<0.11,>=0.10.9 (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading lm_format_enforcer-0.10.11-py3-none-any.whl.metadata (17 kB)
# Collecting outlines==0.1.11 (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading outlines-0.1.11-py3-none-any.whl.metadata (17 kB)
# Collecting lark==1.2.2 (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading lark-1.2.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting xgrammar==0.1.11 (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading xgrammar-0.1.11-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (2.0 kB)
# Collecting partial-json-parser (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading partial_json_parser-0.2.1.1.post5-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.11/dist-packages (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (24.0.1)
# Collecting msgspec (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading msgspec-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting gguf>=0.6.0 (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading gguf-0.10.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/dist-packages (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (8.7.0)
# Collecting mistral_common>=1.5.0 (from mistral_common[opencv]>=1.5.0->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading mistral_common-1.5.6-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (0.8.1)
# Collecting compressed-tensors==0.9.1 (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading compressed_tensors-0.9.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting depyf==0.18.0 (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading depyf-0.18.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (3.1.1)
# Collecting ray==2.40.0 (from ray[adag]==2.40.0->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading ray-2.40.0-cp311-cp311-manylinux2014_x86_64.whl.metadata (17 kB)
# Collecting torchaudio==2.5.1 (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading torchaudio-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.4 kB)
# Collecting torchvision==0.20.1 (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading torchvision-0.20.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.1 kB)
# Collecting xformers==0.0.28.post3 (from vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading xformers-0.0.28.post3-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# Requirement already satisfied: uvicorn>=0.22.0 in /usr/local/lib/python3.11/dist-packages (from llama_cpp_python[server]==0.3.6->-r ilab-hello-world/requirements_gpu.txt (line 3)) (0.34.2)
# Collecting pydantic-settings>=2.0.1 (from llama_cpp_python[server]==0.3.6->-r ilab-hello-world/requirements_gpu.txt (line 3))
#   Downloading pydantic_settings-2.9.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting sse-starlette>=1.6.1 (from llama_cpp_python[server]==0.3.6->-r ilab-hello-world/requirements_gpu.txt (line 3))
#   Downloading sse_starlette-2.3.6-py3-none-any.whl.metadata (10 kB)
# Collecting starlette-context<0.4,>=0.3.6 (from llama_cpp_python[server]==0.3.6->-r ilab-hello-world/requirements_gpu.txt (line 3))
#   Downloading starlette_context-0.3.6-py3-none-any.whl.metadata (4.3 kB)
# Collecting astor (from depyf==0.18.0->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from depyf==0.18.0->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (0.3.7)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba==0.60.0->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (0.43.0)
# Collecting interegular (from outlines==0.1.11->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading interegular-0.3.3-py37-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (1.6.0)
# Requirement already satisfied: referencing in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (0.36.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (4.24.0)
# Collecting pycountry (from outlines==0.1.11->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Collecting airportsdata (from outlines==0.1.11->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading airportsdata-20250523-py3-none-any.whl.metadata (9.1 kB)
# Collecting outlines_core==0.1.26 (from outlines==0.1.11->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading outlines_core-0.1.26-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ray==2.40.0->ray[adag]==2.40.0->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (1.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from ray==2.40.0->ray[adag]==2.40.0->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (24.2)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.11/dist-packages (from ray==2.40.0->ray[adag]==2.40.0->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (1.3.2)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.11/dist-packages (from ray==2.40.0->ray[adag]==2.40.0->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (1.6.0)
# Requirement already satisfied: cupy-cuda12x in /usr/local/lib/python3.11/dist-packages (from ray[adag]==2.40.0->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (13.3.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<2.6.0,>=2.3.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (3.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<2.6.0,>=2.3.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.0,>=2.3.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.0,>=2.3.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.0,>=2.3.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.0,>=2.3.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.0,>=2.3.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.0,>=2.3.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.0,>=2.3.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.0,>=2.3.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.0,>=2.3.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.0,>=2.3.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.0,>=2.3.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.0,>=2.3.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.0,>=2.3.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.0,>=2.3.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (1.13.1)
# Collecting pybind11 (from xgrammar==0.1.11->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: pytest in /usr/local/lib/python3.11/dist-packages (from xgrammar==0.1.11->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (8.3.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<2.6.0,>=2.3.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (1.3.0)
# Collecting botocore<1.39.0,>=1.38.29 (from boto3>=1.35.96->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading botocore-1.38.29-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.35.96->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.14.0,>=0.13.0 (from boto3>=1.35.96->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading s3transfer-0.13.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (18.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (0.70.15)
# Collecting fsspec (from torch<2.6.0,>=2.3.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting docling-ibm-models<4.0.0,>=3.4.4 (from docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading docling_ibm_models-3.4.4-py3-none-any.whl.metadata (6.4 kB)
# Collecting docling-parse<5.0.0,>=4.0.0 (from docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading docling_parse-4.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting pypdfium2<5.0.0,>=4.30.0 (from docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 4.5 MB/s eta 0:00:00
# Collecting easyocr<2.0,>=1.7 (from docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: certifi>=2024.7.4 in /usr/local/lib/python3.11/dist-packages (from docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (2025.4.26)
# Collecting rtree<2.0.0,>=1.3.0 (from docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading rtree-1.4.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting typer<0.16.0,>=0.12.5 (from docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading typer-0.15.4-py3-none-any.whl.metadata (15 kB)
# Collecting python-docx<2.0.0,>=1.1.2 (from docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting python-pptx<2.0.0,>=1.0.2 (from docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.11/dist-packages (from docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (4.13.4)
# Collecting marko<3.0.0,>=2.1.2 (from docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading marko-2.1.3-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /usr/local/lib/python3.11/dist-packages (from docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (3.1.5)
# Requirement already satisfied: lxml<6.0.0,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (5.4.0)
# Requirement already satisfied: pluggy<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (1.6.0)
# Collecting pylatexenc<3.0,>=2.10 (from docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 17.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting click<9.0.0,>=8.1.7 (from instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: scipy<2.0.0,>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (1.15.3)
# Collecting jsonref<2.0.0,>=1.1.0 (from docling-core>=2.10.0->docling-core[chunking]>=2.10.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from docling-core>=2.10.0->docling-core[chunking]>=2.10.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (0.9.0)
# Collecting latex2mathml<4.0.0,>=3.77.0 (from docling-core>=2.10.0->docling-core[chunking]>=2.10.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading latex2mathml-3.78.0-py3-none-any.whl.metadata (14 kB)
# Collecting semchunk<3.0.0,>=2.2.0 (from docling-core[chunking]>=2.10.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading semchunk-2.2.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi!=0.113.*,!=0.114.0,>=0.107.0->fastapi[standard]!=0.113.*,!=0.114.0,>=0.107.0; python_version >= "3.9"->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (0.46.2)
# Collecting fastapi-cli>=0.0.5 (from fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]!=0.113.*,!=0.114.0,>=0.107.0; python_version >= "3.9"->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading fastapi_cli-0.0.7-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.11/dist-packages (from fastapi[standard]!=0.113.*,!=0.114.0,>=0.107.0; python_version >= "3.9"->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (0.0.20)
# Collecting email-validator>=2.0.0 (from fastapi[standard]!=0.113.*,!=0.114.0,>=0.107.0; python_version >= "3.9"->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from GitPython>=3.1.42->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (4.0.12)
# Collecting haystack-experimental (from haystack-ai>=2.8->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading haystack_experimental-0.10.0-py3-none-any.whl.metadata (12 kB)
# Collecting lazy-imports (from haystack-ai>=2.8->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading lazy_imports-0.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from haystack-ai>=2.8->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (10.7.0)
# Collecting posthog!=3.12.0 (from haystack-ai>=2.8->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading posthog-4.2.0-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from haystack-ai>=2.8->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: tenacity!=8.4.0 in /usr/local/lib/python3.11/dist-packages (from haystack-ai>=2.8->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (9.1.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.25.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.1.8->huggingface_hub[hf_transfer]>=0.1.8->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (1.1.2)
# Requirement already satisfied: hf-transfer>=0.1.4 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[hf_transfer]>=0.1.8->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (0.1.9)
# Collecting shortuuid (from instructlab-eval>=0.5.1->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading shortuuid-1.0.13-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (from instructlab-eval>=0.5.1->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (1.7.0)
# Requirement already satisfied: pandas-stubs in /usr/local/lib/python3.11/dist-packages (from instructlab-eval>=0.5.1->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (2.2.2.240909)
# Collecting lm-eval>=0.4.4 (from instructlab-eval>=0.5.1->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading lm_eval-0.4.8-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 4.4 MB/s eta 0:00:00
# Collecting ragas>=0.2.11 (from instructlab-eval>=0.5.1->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading ragas-0.2.15-py3-none-any.whl.metadata (9.0 kB)
# Collecting yamllint>=1.35.1 (from instructlab-schema>=0.4.2->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading yamllint-1.37.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: h5py>=3.12.1 in /usr/local/lib/python3.11/dist-packages (from instructlab-sdg>=0.7.3->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (3.13.0)
# Requirement already satisfied: langchain-text-splitters in /usr/local/lib/python3.11/dist-packages (from instructlab-sdg>=0.7.3->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (0.3.8)
# Collecting submodlib-py (from instructlab-sdg>=0.7.3->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading submodlib_py-0.0.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: wheel>=0.43 in /usr/local/lib/python3.11/dist-packages (from instructlab-training>=0.8.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (0.45.1)
# Collecting instructlab-dolomite>=0.2.0 (from instructlab-training>=0.8.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading instructlab_dolomite-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: aiofiles>=23.2.1 in /usr/local/lib/python3.11/dist-packages (from instructlab-training>=0.8.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (24.1.0)
# Collecting flash-attn>=2.4.0 (from instructlab-training[cuda]>=0.8.0; extra == "cuda"->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading flash_attn-2.7.4.post1.tar.gz (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 105.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting bitsandbytes>=0.43.1 (from instructlab-training[cuda]>=0.8.0; extra == "cuda"->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Collecting accelerate (from instructlab-eval>=0.5.1->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading accelerate-1.0.1-py3-none-any.whl.metadata (19 kB)
# Collecting liger-kernel>=0.5.4 (from instructlab-training[cuda]>=0.8.0; extra == "cuda"->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading liger_kernel-0.5.10-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.11.3->llama_cpp_python==0.3.6->llama_cpp_python[server]==0.3.6->-r ilab-hello-world/requirements_gpu.txt (line 3)) (3.0.2)
# Requirement already satisfied: opencv-python-headless>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mistral_common[opencv]>=1.5.0->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (4.11.0.86)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (1.3.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from peft>=0.9.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (0.5.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit>=3.0.38->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.4->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.4->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.4->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (0.4.1)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings>=2.0.1->llama_cpp_python[server]==0.3.6->-r ilab-hello-world/requirements_gpu.txt (line 3))
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (2.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.3.1->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.3.1->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (2.19.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge-score>=0.1.2->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge-score>=0.1.2->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge-score>=0.1.2->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (1.17.0)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=3.0.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (1.6.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.6.0->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (2024.11.6)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.4->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (0.4.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.4->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (4.3.8)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.4->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (2.29.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.4->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (1.3.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb>=0.16.4->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (75.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (2.6.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (25.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (1.20.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (3.22.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (2.7)
# Collecting jsonlines<4.0.0,>=3.1.0 (from docling-ibm-models<4.0.0,>=3.4.4->docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading jsonlines-3.1.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting tesserocr<3.0.0,>=2.7.1 (from docling[tesserocr]>=2.28.4; sys_platform != "darwin"->instructlab-sdg>=0.7.3->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading tesserocr-2.8.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from easyocr<2.0,>=1.7->docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (0.25.2)
# Collecting python-bidi (from easyocr<2.0,>=1.7->docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading python_bidi-0.6.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.11/dist-packages (from easyocr<2.0,>=1.7->docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (2.1.1)
# Collecting pyclipper (from easyocr<2.0,>=1.7->docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading pyclipper-1.3.0.post6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Collecting ninja (from easyocr<2.0,>=1.7->docling>=2.18.0->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Using cached ninja-1.11.1.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.0 kB)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->fastapi[standard]!=0.113.*,!=0.114.0,>=0.107.0; python_version >= "3.9"->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting rich-toolkit>=0.11.1 (from fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]!=0.113.*,!=0.114.0,>=0.107.0; python_version >= "3.9"->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5))
#   Downloading rich_toolkit-0.14.7-py3-none-any.whl.metadata (999 bytes)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->GitPython>=3.1.42->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (5.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->outlines==0.1.11->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (2025.4.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->outlines==0.1.11->vllm==0.7.3->-r ilab-hello-world/requirements_gpu.txt (line 5)) (0.25.1)
# Collecting evaluate (from lm-eval>=0.4.4->instructlab-eval>=0.5.1->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.11/dist-packages (from lm-eval>=0.4.4->instructlab-eval>=0.5.1->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4)) (2.10.2)
# Collecting pytablewriter (from lm-eval>=0.4.4->instructlab-eval>=0.5.1->instructlab==0.25->instructlab[cuda]==0.25->-r ilab-hello-world/requirements_gpu.txt (line 4))
#   Downloading pytablewriter-1.2.1-py3-none-any.whl.metadata (38 kB)
# ...
# networkx                              3.5
# nibabel                               5.3.2
# ninja                                 1.11.1.4
# nltk                                  3.9.1
# notebook                              6.5.7
# notebook_shim                         0.2.4
# numba                                 0.60.0
# numba-cuda                            0.2.0
# numexpr                               2.10.2
# numpy                                 1.26.4
# nvidia-cublas-cu12                    12.4.5.8
# nvidia-cuda-cupti-cu12                12.4.127
# nvidia-cuda-nvcc-cu12                 12.5.82
# nvidia-cuda-nvrtc-cu12                12.4.127
# nvidia-cuda-runtime-cu12              12.4.127
# nvidia-cudnn-cu12                     9.1.0.70
# nvidia-cufft-cu12                     11.2.1.3
# nvidia-curand-cu12                    10.3.5.147
# nvidia-cusolver-cu12                  11.6.1.9
# nvidia-cusparse-cu12                  12.3.1.170
# nvidia-cusparselt-cu12                0.6.2
# nvidia-ml-py                          12.575.51
# nvidia-nccl-cu12                      2.21.5
# nvidia-nvcomp-cu12                    4.2.0.11
# nvidia-nvjitlink-cu12                 12.4.127
# nvidia-nvtx-cu12                      12.4.127
# nvtx                                  0.2.12
# nx-cugraph-cu12                       25.2.0
# oauth2client                          4.1.3
# oauthlib                              3.2.2
# omegaconf                             2.3.0
# openai                                1.82.1
# opencv-contrib-python                 4.11.0.86
# opencv-python                         4.11.0.86
# opencv-python-headless                4.11.0.86
# openpyxl                              3.1.5
# opt_einsum                            3.4.0
# optax                                 0.2.4
# optree                                0.16.0
# orbax-checkpoint                      0.11.13
# orjson                                3.10.18
# osqp                                  1.0.4
# outlines                              0.1.11
# outlines_core                         0.1.26
# packaging                             24.2
# pandas                                2.2.2
# pandas-datareader                     0.10.0
# pandas-gbq                            0.29.0
# pandas-stubs                          2.2.2.240909
# pandocfilters                         1.5.1
# panel                                 1.7.1
# param                                 2.2.0
# parso                                 0.8.4
# parsy                                 2.1
# partd                                 1.4.2
# partial-json-parser                   0.2.1.1.post5
# pathlib                               1.0.1
# pathspec                              0.12.1
# pathvalidate                          3.2.3
# patsy                                 1.0.1
# peewee                                3.18.1
# peft                                  0.15.2
# pexpect                               4.9.0
# pickleshare                           0.7.5
# pillow                                10.4.0
# pip                                   24.1.2
# platformdirs                          4.3.8
# plotly                                5.24.1
# plotnine                              0.14.5
# pluggy                                1.6.0
# ply                                   3.11
# polars                                1.21.0
# pooch                                 1.8.2
# portalocker                           3.1.1
# portpicker                            1.5.2
# posthog                               4.2.0
# preshed                               3.0.10
# prettytable                           3.16.0
# proglog                               0.1.12
# progressbar2                          4.5.0
# prometheus_client                     0.22.0
# prometheus-fastapi-instrumentator     7.1.0
# promise                               2.3
# prompt_toolkit                        3.0.51
# propcache                             0.3.1
# prophet                               1.1.6
# proto-plus                            1.26.1
# protobuf                              5.29.5
# psutil                                7.0.0
# psycopg2                              2.9.10
# ptyprocess                            0.7.0
# py-cpuinfo                            9.0.0
# py4j                                  0.10.9.7
# pyarrow                               18.1.0
# pyasn1                                0.6.1
# pyasn1_modules                        0.4.2
# pybind11                              2.13.6
# pycairo                               1.28.0
# pyclipper                             1.3.0.post6
# pycocotools                           2.0.8
# pycountry                             24.6.1
# pycparser                             2.22
# pycryptodomex                         3.23.0
# pydantic                              2.11.5
# pydantic_core                         2.33.2
# pydantic-settings                     2.9.1
# pydantic-yaml                         1.5.1
# pydata-google-auth                    1.9.1
# pydot                                 3.0.4
# pydotplus                             2.0.2
# PyDrive                               1.3.1
# PyDrive2                              1.21.3
# pydub                                 0.25.1
# pyerfa                                2.0.1.5
# pygame                                2.6.1
# pygit2                                1.18.0
# Pygments                              2.19.1
# PyGObject                             3.42.0
# PyJWT                                 2.10.1
# pylatexenc                            2.10
# pylibcudf-cu12                        25.2.1
# pylibcugraph-cu12                     25.2.0
# pylibraft-cu12                        25.2.0
# pymc                                  5.23.0
# pymystem3                             0.2.0
# pynndescent                           0.5.13
# pynvjitlink-cu12                      0.6.0
# pynvml                                12.0.0
# pyogrio                               0.11.0
# pyomo                                 6.9.2
# PyOpenGL                              3.1.9
# pyOpenSSL                             24.2.1
# pyparsing                             3.2.3
# pypdfium2                             4.30.1
# pyperclip                             1.9.0
# pyproj                                3.7.1
# pyproject_hooks                       1.2.0
# pyshp                                 2.3.1
# PySocks                               1.7.1
# pyspark                               3.5.1
# pytablewriter                         1.2.1
# pytensor                              2.31.2
# pytest                                8.3.5
# python-apt                            0.0.0
# python-bidi                           0.6.6
# python-box                            7.3.2
# python-dateutil                       2.9.0.post0
# python-docx                           1.1.2
# python-dotenv                         1.1.0
# python-louvain                        0.16
# python-multipart                      0.0.20
# python-pptx                           1.0.2
# python-slugify                        8.0.4
# python-snappy                         0.7.3
# python-utils                          3.9.1
# pytz                                  2025.2
# pyviz_comms                           3.0.4
# PyWavelets                            1.8.0
# PyYAML                                6.0.2
# pyzmq                                 24.0.1
# raft-dask-cu12                        25.2.0
# ragas                                 0.2.15
# rapids-dask-dependency                25.2.0
# ratelim                               0.1.6
# ray                                   2.40.0
# referencing                           0.36.2
# regex                                 2024.11.6
# requests                              2.32.3
# requests-oauthlib                     2.0.0
# requests-toolbelt                     1.0.0
# requirements-parser                   0.9.0
# rich                                  13.9.4
# rich-toolkit                          0.14.7
# rmm-cu12                              25.2.0
# roman-numerals-py                     3.1.0
# rouge_score                           0.1.2
# rpds-py                               0.25.1
# rpy2                                  3.5.17
# rsa                                   4.9.1
# rtree                                 1.4.0
# ruamel.yaml                           0.18.12
# ruamel.yaml.clib                      0.2.12
# ruff                                  0.11.12
# s3transfer                            0.13.0
# sacrebleu                             2.5.1
# safehttpx                             0.1.6
# safetensors                           0.5.3
# scikit-image                          0.25.2
# scikit-learn                          1.6.1
# scipy                                 1.15.3
# scooby                                0.10.1
# scs                                   3.2.7.post2
# seaborn                               0.13.2
# SecretStorage                         3.3.3
# semantic-version                      2.10.0
# semchunk                              2.2.2
# Send2Trash                            1.8.3
# sentence-transformers                 4.1.0
# sentencepiece                         0.2.0
# sentry-sdk                            2.29.1
# setproctitle                          1.3.6
# setuptools                            75.2.0
# shap                                  0.47.2
# shapely                               2.1.1
# shellingham                           1.5.4
# shortuuid                             1.0.13
# simple-parsing                        0.1.7
# simplejson                            3.20.1
# simsimd                               6.2.1
# six                                   1.17.0
# sklearn-compat                        0.1.3
# sklearn-pandas                        2.2.0
# slicer                                0.0.8
# smart-open                            7.1.0
# smmap                                 5.0.2
# sniffio                               1.3.1
# snowballstemmer                       3.0.1
# sortedcontainers                      2.4.0
# soundfile                             0.13.1
# soupsieve                             2.7
# soxr                                  0.5.0.post1
# spacy                                 3.8.7
# spacy-legacy                          3.0.12
# spacy-loggers                         1.0.5
# spanner-graph-notebook                1.1.6
# Sphinx                                8.2.3
# sphinxcontrib-applehelp               2.0.0
# sphinxcontrib-devhelp                 2.0.0
# sphinxcontrib-htmlhelp                2.1.0
# sphinxcontrib-jsmath                  1.0.1
# sphinxcontrib-qthelp                  2.0.0
# sphinxcontrib-serializinghtml         2.0.0
# SQLAlchemy                            2.0.41
# sqlglot                               25.20.2
# sqlitedict                            2.1.0
# sqlparse                              0.5.3
# srsly                                 2.5.1
# sse-starlette                         2.3.6
# stanio                                0.5.1
# starlette                             0.46.2
# starlette-context                     0.3.6
# statsmodels                           0.14.4
# stringzilla                           3.12.5
# stumpy                                1.13.0
# submodlib-py                          0.0.3
# sympy                                 1.13.1
# tabledata                             1.3.4
# tables                                3.10.2
# tabulate                              0.9.0
# tbb                                   2022.1.0
# tblib                                 3.1.0
# tcmlib                                1.3.0
# tcolorpy                              0.1.7
# tenacity                              9.1.2
# tensorboard                           2.18.0
# tensorboard-data-server               0.7.2
# tensorflow                            2.18.0
# tensorflow-datasets                   4.9.9
# tensorflow_decision_forests           1.11.0
# tensorflow-hub                        0.16.1
# tensorflow-io-gcs-filesystem          0.37.1
# tensorflow-metadata                   1.17.1
# tensorflow-probability                0.25.0
# tensorflow-text                       2.18.1
# tensorstore                           0.1.74
# termcolor                             3.1.0
# terminado                             0.18.1
# tesserocr                             2.8.0
# text-unidecode                        1.3
# textblob                              0.19.0
# tf_keras                              2.18.0
# tf-slim                               1.1.0
# thinc                                 8.3.6
# threadpoolctl                         3.6.0
# tifffile                              2025.5.26
# tiktoken                              0.9.0
# timm                                  1.0.15
# tinycss2                              1.4.0
# tokenizers                            0.21.1
# toml                                  0.10.2
# tomlkit                               0.13.2
# toolz                                 0.12.1
# torch                                 2.5.1
# torchao                               0.10.0
# torchaudio                            2.5.1
# torchdata                             0.11.0
# torchsummary                          1.5.1
# torchtune                             0.6.1
# torchvision                           0.20.1
# tornado                               6.4.2
# tqdm                                  4.67.1
# tqdm-multiprocess                     0.0.11
# traitlets                             5.7.1
# traittypes                            0.2.1
# transformers                          4.50.3
# treelite                              4.4.1
# treescope                             0.1.9
# triton                                3.1.0
# trl                                   0.14.0
# tsfresh                               0.21.0
# tweepy                                4.15.0
# typeguard                             4.4.2
# typepy                                1.3.4
# typer                                 0.15.4
# types-pytz                            2025.2.0.20250516
# types-setuptools                      80.9.0.20250529
# typing_extensions                     4.13.2
# typing-inspect                        0.9.0
# typing-inspection                     0.4.1
# tzdata                                2025.2
# tzlocal                               5.3.1
# uc-micro-py                           1.0.3
# ucx-py-cu12                           0.42.0
# ucxx-cu12                             0.42.0
# umap-learn                            0.5.7
# umf                                   0.10.0
# uritemplate                           4.1.1
# urllib3                               2.4.0
# uvicorn                               0.34.2
# uvloop                                0.21.0
# vega-datasets                         0.9.0
# vllm                                  0.7.3
# wadllib                               1.3.6
# wandb                                 0.19.11
# wasabi                                1.1.3
# watchfiles                            1.0.5
# wcwidth                               0.2.13
# weasel                                0.4.1
# webcolors                             24.11.1
# webencodings                          0.5.1
# websocket-client                      1.8.0
# websockets                            15.0.1
# Werkzeug                              3.1.3
# wheel                                 0.45.1
# widgetsnbextension                    3.6.10
# word2number                           1.1
# wordcloud                             1.9.4
# wrapt                                 1.17.2
# wurlitzer                             3.1.1
# xarray                                2025.3.1
# xarray-einstats                       0.9.0
# xdg-base-dirs                         6.0.2
# xformers                              0.0.28.post3
# xgboost                               2.1.4
# xgrammar                              0.1.11
# xlrd                                  2.0.1
# XlsxWriter                            3.2.3
# xxhash                                3.5.0
# xyzservices                           2025.4.0
# yamllint                              1.37.1
# yarl                                  1.20.0
# ydf                                   0.12.0
# yellowbrick                           1.5
# yfinance                              0.2.61
# zict                                  3.0.0
# zipp                                  3.22.0
# zstandard                             0.23.0

# %% [markdown]
# Wrap code cell output for ease of reading

# %%
from IPython.display import HTML, display
def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)

# %% [markdown]
# ## Step 1.5 Check Starting Configuration
# ### Check InstructLab Version
#
# Check that InstructLab is installed properly and is configured for using a GPU.
#
# The first line from 'InstructLab' section will give the InstructLab version.

# %%
# !ilab system info
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/llama_cpp/_ctypes_extensions.py", line 67, in load_shared_library
#     return ctypes.CDLL(str(lib_path), **cdll_args)  # type: ignore
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/ctypes/__init__.py", line 376, in __init__
#     self._handle = _dlopen(self._name, mode)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: libcuda.so.1: cannot open shared object file: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/ilab", line 8, in <module>
#     sys.exit(ilab())
#              ^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1161, in __call__
#     return self.main(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1082, in main
#     rv = self.invoke(ctx)
#          ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1697, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1697, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1443, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 788, in invoke
#     return __callback(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/instructlab/clickext.py", line 356, in wrapper
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/instructlab/cli/system/info.py", line 19, in info
#     categories = get_sysinfo_by_category()
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/instructlab/system/info.py", line 187, in get_sysinfo_by_category
#     add_to_category(categories, "llama_cpp_python", _llama_cpp_info())
#                                                     ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/instructlab/system/info.py", line 149, in _llama_cpp_info
#     import llama_cpp
#   File "/usr/local/lib/python3.11/dist-packages/llama_cpp/__init__.py", line 1, in <module>
#     from .llama_cpp import *
#   File "/usr/local/lib/python3.11/dist-packages/llama_cpp/llama_cpp.py", line 38, in <module>
#     _lib = load_shared_library(_lib_base_name, _base_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/llama_cpp/_ctypes_extensions.py", line 69, in load_shared_library
#     raise RuntimeError(f"Failed to load shared library '{lib_path}': {e}")
# RuntimeError: Failed to load shared library '/usr/local/lib/python3.11/dist-packages/llama_cpp/lib/libllama.so': libcuda.so.1: cannot open shared object file: No such file or directory

# %% [markdown]
# <a id="IL1_check"></a>
# ## Perform Imports and Check for a GPU
#
# This code cell checks for a GPU in the configuration. This notebook requires a GPU in the configuration to run properly.

# %%
import os
import torch
from IPython.display import Image, display
from datasets import load_dataset
from langchain.llms import LlamaCpp
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
import json
import subprocess
import shutil
import ruamel.yaml
os.environ['NUMEXPR_MAX_THREADS'] = '64'
Norm = "<p style='font-family:IBM Plex Sans;font-size:20px'>"

notebook_dir='/content/ilab-hello-world/'
os.chdir(notebook_dir)

## torch and cuda version check
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)

if torch.cuda.is_available() is False:
    print("No GPU in configuration")
else:
    os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
    print("GPU(s) are Available")
    gpus=torch.cuda.device_count()
    if gpus==1:
      gpu_type=torch.cuda.get_device_name(0)
      print("One GPU of Type: ", gpu_type)
    else:
      print("ERROR: More than 1 GPU in configuration: ",gpus)
print("Starting directory: "+ os.getcwd())
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# torch:  2.5 ; cuda:  cu124
# No GPU in configuration
# Starting directory: /content/ilab-hello-world

# %% [markdown]
# <a id="IL1_config"></a>
# ## Step 1.6 Configure InstructLab
#
# ### Create InstructLab config file
# The InstructLab configuration is captured in the *config.yaml* file. This step creates the config.yaml file and sets:
# - **taxomony_path = taxonomy** - the root location of the taxonomy is set to the taxonomy folder in instructlab-latest
# - **model_path = models/merlinite-7b-lab-Q4_K_M.gguf** - the default model is set to merlinite
#
# **Note:** The default directories for InstructLab are the following. If you initialize InstructLab on your own system, it will default to the following:
# * **Downloaded Models:**  ~/.cache/instructlab/models/ - Contains all downloaded large language models, including the saved output of ones you generate with ilab.
# * **Synthetic Data:** ~/.local/share/instructlab/datasets/ - Contains data output from the SDG phase, built on modifications to the taxonomy repository.
# * **Taxonomy:** ~/.local/share/instructlab/taxonomy/ - Contains the skill and knowledge data.
# * **Training Output:** ~/.local/share/instructlab/checkpoints/ - Contains the output of the training process.
# * **config.yaml:** ~/.config/instructlab/config.yaml - Contains the config.yaml file

# %%
#Remove Colab Sample directory
if os.path.exists("sample_data"):
    print("removing sample_data")
    shutil.rmtree("sample_data")
    os.chdir("ilab-hello-world")

#Initialize ilab
base_dir="/root/"
##Choose the base model as granite or mixtral
model_dir="models"
model_name="granite-7b-lab-Q4_K_M.gguf"
model_path = os.path.join(model_dir, model_name)

taxonomy_path='taxonomy'

## Define the file name
file_name = "config.yaml"
if os.path.exists(file_name):
    os.remove(file_name)
    print(f"ilab was already initialized. {file_name} has been deleted. Reinitialized")
else:
    print(f"ilab was not initialized yet. {file_name} does not exist.")

##Remove old data
if os.path.exists("taxonomy"):
    print("removing taxonomy")
    # shutil.rmtree("taxonomy")
if os.path.exists(base_dir+".cache/instructlab"):
    print("removing " + base_dir+".cache/instructlab")
    shutil.rmtree(base_dir+".cache/instructlab")
if os.path.exists(base_dir+".config/instructlab"):
    print("removing " + base_dir+".config/instructlab")
    shutil.rmtree(base_dir+".config/instructlab")
if os.path.exists(base_dir+".local/share/instructlab"):
    print("removing " + base_dir+".local/share/instructlab")
    shutil.rmtree(base_dir+".local/share/instructlab")

print(f"ilab model is {model_path}.")
print('#############################################################')
print(' ')

command = f"""
ilab config init<<EOF
{taxonomy_path}
Y
{model_path}
0
EOF
"""

## Using the ! operator to run the command
# !echo "Running ilab config init"
# !{command}
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ilab was not initialized yet. config.yaml does not exist.
# removing taxonomy
# ilab model is models/granite-7b-lab-Q4_K_M.gguf.
# #############################################################
#
# Running ilab config init
#
# ----------------------------------------------------
#          Welcome to the InstructLab CLI
#   This guide will help you to setup your environment
# ----------------------------------------------------
#
# Please provide the following values to initiate the environment [press 'Enter' for default options when prompted]
# Path to taxonomy repo [/root/.local/share/instructlab/taxonomy]: Path to your model [/root/.cache/instructlab/models/granite-7b-lab-Q4_K_M.gguf]:
# Generating config file:
#     /root/.config/instructlab/config.yaml
#
# WARNING 2025-06-04 04:19:07,250 instructlab.config.init:125: ilab is only officially supported on Linux and MacOS with M-Series Chips
# Please choose a system profile.
# Profiles set hardware-specific defaults for all commands and sections of the configuration.
# First, please select the hardware vendor your system falls into
# [0] NO SYSTEM PROFILE
# [1] INTEL
# [2] NVIDIA
# [3] APPLE
# [4] AMD
# Enter the number of your choice [0]: Error: 'models/granite-7b-lab-Q4_K_M.gguf' is not a valid integer range.
# Enter the number of your choice [0]: No profile selected - ilab will use generic code defaults - these may not be optimized for your system.
#
# --------------------------------------------
#     Initialization completed successfully!
#   You're ready to start using `ilab`. Enjoy!
# --------------------------------------------

# %% [markdown]
# ### Display the config.yaml file
# We examine the base configuration for identifying parameters for changing in the next step.

# %%
##to copy config.yaml to local directory
# !cp /root/.config/instructlab/config.yaml .
# !cat config.yaml
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# # Chat configuration section.
# chat:
#   # Predefined setting or environment that influences the behavior and responses of
#   # the chat assistant. Each context is associated with a specific prompt that
#   # guides the assistant on how to respond to user inputs. Available contexts:
#   # default, cli_helper.
#   # Default: default
#   context: default
#   # Directory where chat logs are stored.
#   # Default: /root/.local/share/instructlab/chatlogs
#   logs_dir: /root/.local/share/instructlab/chatlogs
#   # The maximum number of tokens that can be generated in the chat completion. Be
#   # aware that larger values use more memory.
#   # Default: None
#   max_tokens:
#   # Model to be used for chatting with.
#   # Default: /root/.cache/instructlab/models/granite-7b-lab-Q4_K_M.gguf
#   model: Y
#   # Filepath of a dialog session file.
#   # Default: None
#   session:
#   # Controls the randomness of the model's responses. Lower values make the output
#   # more deterministic, while higher values produce more random results.
#   # Default: 1.0
#   temperature: 1.0
#   # Enable vim keybindings for chat.
#   # Default: False
#   vi_mode: false
#   # Renders vertical overflow if enabled, displays ellipses otherwise.
#   # Default: True
#   visible_overflow: true
# # Evaluate configuration section.
# evaluate:
#   # Base taxonomy branch
#   # Default: None
#   base_branch:
#   # Base model to compare with 'model' for mt_bench_branch and mmlu_branch.
#   # Default: instructlab/granite-7b-lab
#   base_model: instructlab/granite-7b-lab
#   # Taxonomy branch containing custom skills/knowledge that should be used for
#   # evaluation runs.
#   # Default: None
#   branch:
#   # Settings to run DK-Bench against a file of user created questions, reference
#   # answers, and responses. If responses are not provided they are generated from a
#   # model
#   dk_bench:
#     # File with questions and reference answers used for evaluation during DK-Bench.
#     # The file must be valid a '.jsonl' file with the fields 'user_input' and
#     # 'reference' in each entry
#     # Default: None
#     input_questions:
#     # Judge model for DK-Bench.
#     # Default: gpt-4o
#     judge_model: gpt-4o
#     # Directory where DK-Bench evaluation results are stored.
#     # Default: /root/.local/share/instructlab/internal/eval_data/dk_bench
#     output_dir: /root/.local/share/instructlab/internal/eval_data/dk_bench
#     # Comma-separated list of file formats for results of the DK-Bench evaluation. Ex:
#     # 'csv,jsonl'. Valid options in the list are csv, jsonl, and xlsx. If this option
#     # is not provided the results are written as a .jsonl file
#     # Default: jsonl
#     output_file_formats: jsonl
#   # Number of GPUs to use for running evaluation.
#   # Default: None
#   gpus:
#   # MMLU benchmarking settings
#   mmlu:
#     # Batch size for evaluation. Valid values are a positive integer or 'auto' to
#     # select the largest batch size that will fit in memory.
#     # Default: auto
#     batch_size: auto
#     # Number of question-answer pairs provided in the context preceding the question
#     # used for evaluation.
#     # Default: 5
#     few_shots: 5
#   # Settings to run MMLU against a branch of taxonomy containing custom
#   # skills/knowledge used for training.
#   mmlu_branch:
#     # Directory where custom MMLU tasks are stored.
#     # Default: /root/.local/share/instructlab/datasets
#     tasks_dir: /root/.local/share/instructlab/datasets
#   # Model to be evaluated
#   # Default: None
#   model: Y
#   # Multi-turn benchmarking settings for skills.
#   mt_bench:
#     # Judge model for MT-Bench.
#     # Default: prometheus-eval/prometheus-8x7b-v2.0
#     judge_model: prometheus-eval/prometheus-8x7b-v2.0
#     # Number of workers to use for evaluation with mt_bench or mt_bench_branch. Must
#     # be a positive integer or 'auto'.
#     # Default: auto
#     max_workers: auto
#     # Directory where MT-Bench evaluation results are stored.
#     # Default: /root/.local/share/instructlab/internal/eval_data/mt_bench
#     output_dir: /root/.local/share/instructlab/internal/eval_data/mt_bench
#   # Settings to run MT-Bench against a branch of taxonomy containing custom
#   # skills/knowledge used for training
#   mt_bench_branch:
#     # Judge model for MT-Bench-Branch.
#     # Default: prometheus-eval/prometheus-8x7b-v2.0
#     judge_model: prometheus-eval/prometheus-8x7b-v2.0
#     # Directory where MT-Bench-Branch evaluation results are stored.
#     # Default: /root/.local/share/instructlab/internal/eval_data/mt_bench_branch
#     output_dir: /root/.local/share/instructlab/internal/eval_data/mt_bench_branch
#     # Path to where base taxonomy is stored.
#     # Default: /root/.local/share/instructlab/taxonomy
#     taxonomy_path: taxonomy
#   # System prompt for model getting responses during DK-Bench.
#   # Default: None
#   system_prompt:
#   # Temperature for model getting responses during DK-Bench. Temperature controls
#   # the randomness of the model's responses. Lower values make the output more
#   # deterministic, while higher values produce more random results.
#   # Default: 0.0
#   temperature: 0.0
# # General configuration section.
# general:
#   # Debug level for logging.
#   # Default: 0
#   debug_level: 0
#   # Log format. https://docs.python.org/3/library/logging.html#logrecord-attributes
#   # Default: %(levelname)s %(asctime)s %(name)s:%(lineno)d: %(message)s
#   log_format: '%(levelname)s %(asctime)s %(name)s:%(lineno)d: %(message)s'
#   # Log level for logging.
#   # Default: INFO
#   log_level: INFO
#   # Use legacy IBM Granite chat template (default uses 3.0 Instruct template)
#   # Default: False
#   use_legacy_tmpl: false
# # Generate configuration section.
# generate:
#   # Number of Batches to send for generation on each core.
#   # Default: 8
#   batch_size: 8
#   # Maximum number of words per chunk.
#   # Default: 1000
#   chunk_word_count: 1000
#   # The maximum amount of tokens for the model to generate during knowledge
#   # generation. A lower number yields less data but a faster SDG run. It is
#   # reccomended to use this on consumer hardware
#   # Default: 4096
#   max_num_tokens: 4096
#   # Teacher model that will be used to synthetically generate training data.
#   # Default: /root/.cache/instructlab/models/mistral-7b-instruct-v0.2.Q4_K_M.gguf
#   model: /root/.cache/instructlab/models/mistral-7b-instruct-v0.2.Q4_K_M.gguf
#   # Number of CPU cores to use for generation.
#   # Default: 10
#   num_cpus: 10
#   # Number of instructions to use
#   # Default: -1
#   # Deprecated: see 'sdg_scale_factor' instead
#   num_instructions: -1
#   # Directory where generated datasets are stored.
#   # Default: /root/.local/share/instructlab/datasets
#   output_dir: /root/.local/share/instructlab/datasets
#   # Data generation pipeline to use. Available: 'simple', 'full', or a valid path to
#   # a directory of pipeline workflow YAML files. Note that 'full' requires a larger
#   # teacher model, Mixtral-8x7b.
#   # Default: full
#   pipeline: full
#   # The total number of instructions to be generated.
#   # Default: 30
#   sdg_scale_factor: 30
#   # Branch of taxonomy used to calculate diff against.
#   # Default: origin/main
#   taxonomy_base: origin/main
#   # Directory where taxonomy is stored and accessed from.
#   # Default: /root/.local/share/instructlab/taxonomy
#   taxonomy_path: taxonomy
#   # Teacher configuration
#   teacher:
#     # Serving backend to use to host the model.
#     # Default: None
#     # Examples:
#     #   - vllm
#     #   - llama-cpp
#     backend:
#     # Chat template to supply to the model. Possible values: 'auto'(default),
#     # 'tokenizer', a path to a jinja2 file.
#     # Default: None
#     # Examples:
#     #   - auto
#     #   - tokenizer
#     #   - A filesystem path expressing the location of a custom template
#     chat_template:
#     # llama-cpp serving settings.
#     llama_cpp:
#       # Number of model layers to offload to GPU. -1 means all layers.
#       # Default: -1
#       gpu_layers: -1
#       # Large Language Model Family
#       # Default: ''
#       # Examples:
#       #   - granite
#       #   - mixtral
#       llm_family: ''
#       # Maximum number of tokens that can be processed by the model.
#       # Default: 4096
#       max_ctx_size: 4096
#     # Directory where model to be served is stored.
#     # Default: /root/.cache/instructlab/models/granite-7b-lab-Q4_K_M.gguf
#     model_path: /root/.cache/instructlab/models/mistral-7b-instruct-v0.2.Q4_K_M.gguf
#     # Server configuration including host and port.
#     # Default: host='127.0.0.1' port=8000 backend_type='' current_max_ctx_size=4096
#     server:
#       # Backend Instance Type
#       # Default: ''
#       # Examples:
#       #   - llama-cpp
#       #   - vllm
#       backend_type: ''
#       # Maximum number of tokens that can be processed by the currently served model.
#       # Default: 4096
#       current_max_ctx_size: 4096
#       # Host to serve on.
#       # Default: 127.0.0.1
#       host: 127.0.0.1
#       # Port to serve on.
#       # Default: 8000
#       port: 8000
#     # vLLM serving settings.
#     vllm:
#       # Number of GPUs to use.
#       # Default: None
#       gpus:
#       # Large Language Model Family
#       # Default: ''
#       # Examples:
#       #   - granite
#       #   - mixtral
#       llm_family: ''
#       # Maximum number of attempts to start the vLLM server.
#       # Default: 120
#       max_startup_attempts: 120
#       # vLLM specific arguments. All settings can be passed as a list of strings, see:
#       # https://docs.vllm.ai/en/latest/serving/openai_compatible_server.html
#       # Default: []
#       # Examples:
#       #   - ['--dtype', 'auto']
#       #   - ['--lora-alpha', '32']
#       vllm_args: []
# # Metadata pertaining to the specifics of the system which the Configuration is
# # meant to be applied to.
# metadata:
#   # Manufacturer, Family, and SKU of the system CPU, ex: Apple M3 Max
#   # Default: None
#   cpu_info:
#   # Amount of GPUs on the system, ex: 8
#   # Default: None
#   gpu_count:
#   # Family of the system GPU, ex: H100
#   # Default: None
#   gpu_family:
#   # Manufacturer of the system GPU, ex: Nvidia
#   # Default: None
#   gpu_manufacturer:
#   # Specific SKU related information about the given GPU, ex: PCIe, NVL
#   # Default: None
#   gpu_sku:
# # User-defined custom set of models. This allows people to use their own models
# # for the InstructLab model customization process.
# # Default: []
# models: []
# # RAG configuration section.
# rag:
#   # RAG convert configuration section.
#   convert:
#     # Directory where converted documents are stored.
#     # Default: /root/.local/share/instructlab/converted_documents
#     output_dir: /root/.local/share/instructlab/converted_documents
#     # Branch of taxonomy used to calculate diff against.
#     # Default: origin/main
#     taxonomy_base: origin/main
#     # Directory where taxonomy is stored and accessed from.
#     # Default: /root/.local/share/instructlab/taxonomy
#     taxonomy_path: /root/.local/share/instructlab/taxonomy
#   # Document store configuration for RAG.
#   document_store:
#     # Document store collection name.
#     # Default: ilab
#     collection_name: ilab
#     # Document store service URI.
#     # Default: /root/.local/share/instructlab/embeddings.db
#     uri: /root/.local/share/instructlab/embeddings.db
#   # Embedding model configuration for RAG
#   embedding_model:
#     # Embedding model to use for RAG.
#     # Default: /root/.cache/instructlab/models/ibm-granite/granite-embedding-125m-english
#     embedding_model_path: /root/.cache/instructlab/models/ibm-granite/granite-embedding-125m-english
#   # Flag for enabling RAG functionality.
#   # Default: False
#   enabled: false
#   # Retrieval configuration parameters for RAG
#   retriever:
#     # The maximum number of documents to retrieve.
#     # Default: 3
#     top_k: 3
# # Serve configuration section.
# serve:
#   # Serving backend to use to host the model.
#   # Default: None
#   # Examples:
#   #   - vllm
#   #   - llama-cpp
#   backend:
#   # Chat template to supply to the model. Possible values: 'auto'(default),
#   # 'tokenizer', a path to a jinja2 file.
#   # Default: None
#   # Examples:
#   #   - auto
#   #   - tokenizer
#   #   - A filesystem path expressing the location of a custom template
#   chat_template:
#   # llama-cpp serving settings.
#   llama_cpp:
#     # Number of model layers to offload to GPU. -1 means all layers.
#     # Default: -1
#     gpu_layers: -1
#     # Large Language Model Family
#     # Default: ''
#     # Examples:
#     #   - granite
#     #   - mixtral
#     llm_family: ''
#     # Maximum number of tokens that can be processed by the model.
#     # Default: 4096
#     max_ctx_size: 4096
#   # Directory where model to be served is stored.
#   # Default: /root/.cache/instructlab/models/granite-7b-lab-Q4_K_M.gguf
#   model_path: Y
#   # Server configuration including host and port.
#   # Default: host='127.0.0.1' port=8000 backend_type='' current_max_ctx_size=4096
#   server:
#     # Backend Instance Type
#     # Default: ''
#     # Examples:
#     #   - llama-cpp
#     #   - vllm
#     backend_type: ''
#     # Maximum number of tokens that can be processed by the currently served model.
#     # Default: 4096
#     current_max_ctx_size: 4096
#     # Host to serve on.
#     # Default: 127.0.0.1
#     host: 127.0.0.1
#     # Port to serve on.
#     # Default: 8000
#     port: 8000
#   # vLLM serving settings.
#   vllm:
#     # Number of GPUs to use.
#     # Default: None
#     gpus:
#     # Large Language Model Family
#     # Default: ''
#     # Examples:
#     #   - granite
#     #   - mixtral
#     llm_family: ''
#     # Maximum number of attempts to start the vLLM server.
#     # Default: 120
#     max_startup_attempts: 120
#     # vLLM specific arguments. All settings can be passed as a list of strings, see:
#     # https://docs.vllm.ai/en/latest/serving/openai_compatible_server.html
#     # Default: []
#     # Examples:
#     #   - ['--dtype', 'auto']
#     #   - ['--lora-alpha', '32']
#     vllm_args: []
# # Train configuration section.
# train:
#   # Additional arguments to pass to the training script. These arguments are passed
#   # as key-value pairs to the training script.
#   # Default: {}
#   additional_args: {}
#   # Save a checkpoint at the end of each epoch.
#   # Default: True
#   checkpoint_at_epoch: true
#   # Directory where periodic training checkpoints are stored.
#   # Default: /root/.local/share/instructlab/checkpoints
#   ckpt_output_dir: /root/.local/share/instructlab/checkpoints
#   # Directory where the processed training data is stored (post
#   # filtering/tokenization/masking).
#   # Default: /root/.local/share/instructlab/internal
#   data_output_dir: /root/.local/share/instructlab/internal
#   # For the training library (primary training method), this specifies the path to
#   # the dataset file. For legacy training (MacOS/Linux), this specifies the path to
#   # the directory.
#   # Default: /root/.local/share/instructlab/datasets
#   data_path: /root/.local/share/instructlab/datasets
#   # Allow CPU offload for deepspeed optimizer.
#   # Default: False
#   deepspeed_cpu_offload_optimizer: false
#   # PyTorch device to use. Use 'cpu' for 'simple' and 'full' training on Linux. Use
#   # 'mps' for 'full' training on MacOS Metal Performance Shader. Use 'cuda' for
#   # Nvidia CUDA / AMD ROCm GPUs. Use 'hpu' for Intel Gaudi GPUs.
#   # Default: cpu
#   # Examples:
#   #   - cpu
#   #   - mps
#   #   - cuda
#   #   - hpu
#   device: cpu
#   # Whether or not we should disable the use of flash-attention during training.
#   # This is useful when using older GPUs.
#   # Default: False
#   disable_flash_attn: false
#   # Pick a distributed training backend framework for GPU accelerated full fine-
#   # tuning.
#   # Default: fsdp
#   distributed_backend: fsdp
#   # The number of samples in a batch that the model should see before its parameters
#   # are updated.
#   # Default: 64
#   effective_batch_size: 64
#   # Allow CPU offload for FSDP optimizer.
#   # Default: False
#   fsdp_cpu_offload_optimizer: false
#   # Boolean to indicate if the model being trained is a padding-free transformer
#   # model such as Granite.
#   # Default: False
#   is_padding_free: false
#   # The data type for quantization in LoRA training. Valid options are 'None' and
#   # 'nf4'.
#   # Default: nf4
#   # Examples:
#   #   - nf4
#   lora_quantize_dtype: nf4
#   # Rank of low rank matrices to be used during training.
#   # Default: 0
#   lora_rank: 0
#   # Maximum tokens per gpu for each batch that will be handled in a single step. If
#   # running into out-of-memory errors, this value can be lowered but not below the
#   # `max_seq_len`.
#   # Default: 5000
#   max_batch_len: 5000
#   # Maximum sequence length to be included in the training set. Samples exceeding
#   # this length will be dropped.
#   # Default: 4096
#   max_seq_len: 4096
#   # Directory where the model to be trained is stored.
#   # Default: instructlab/granite-7b-lab
#   model_path: instructlab/granite-7b-lab
#   # Number of GPUs to use for training. This value is not supported in legacy
#   # training or MacOS.
#   # Default: 1
#   nproc_per_node: 1
#   # Number of epochs to run training for.
#   # Default: 10
#   num_epochs: 10
#   # Base directory for organization of end-to-end intermediate outputs.
#   # Default: /root/.local/share/instructlab/phased
#   phased_base_dir: /root/.local/share/instructlab/phased
#   # Judge model path for phased MT-Bench evaluation.
#   # Default: /root/.cache/instructlab/models/prometheus-eval/prometheus-8x7b-v2.0
#   phased_mt_bench_judge: /root/.cache/instructlab/models/prometheus-eval/prometheus-8x7b-v2.0
#   # Phased phase1 effective batch size.
#   # Default: 128
#   phased_phase1_effective_batch_size: 128
#   # Learning rate for phase1 knowledge training.
#   # Default: 2e-05
#   phased_phase1_learning_rate: 2e-05
#   # Number of epochs to run training for during phase1 (experimentally optimal
#   # number is 7).
#   # Default: 7
#   phased_phase1_num_epochs: 7
#   # Number of samples the model should see before saving a checkpoint during phase1.
#   # Disabled when set to 0.
#   # Default: 0
#   phased_phase1_samples_per_save: 0
#   # Phased phase2 effective batch size.
#   # Default: 3840
#   phased_phase2_effective_batch_size: 3840
#   # Learning rate for phase2 skills training.
#   # Default: 6e-06
#   phased_phase2_learning_rate: 6e-06
#   # Number of epochs to run training for during phase2.
#   # Default: 10
#   phased_phase2_num_epochs: 10
#   # Number of samples the model should see before saving a checkpoint during phase2.
#   # Disabled when set to 0.
#   # Default: 0
#   phased_phase2_samples_per_save: 0
#   # Training pipeline to use. Simple is for systems with limited resources, full is
#   # for more capable consumer systems (64 GB of RAM), and accelerated is for systems
#   # with a dedicated GPU.
#   # Default: full
#   # Examples:
#   #   - simple
#   #   - full
#   #   - accelerated
#   pipeline: full
#   # Number of samples the model should see before saving a checkpoint.
#   # Default: 250000
#   save_samples: 250000
#   # Optional path to a yaml file that tracks the progress of multiphase training.
#   # Default: None
#   training_journal:
# # Configuration file structure version.
# # Default: 1.0.0
# version: 1.0.0

# %% [markdown]
# ### Customize LLM Models and copy to notebook for use
#
# This cell changes the models to use for the generate stage. The mistral model as the teacher model in the generate step and as the student model to be trained.
#
# If you want to customize other models for generation or the training phase, you would specify the models in this step.
#
# This step specifies that the models to be used will be from this notebook's models directory.

# %%
##Use ruamel.yaml to load the yaml file to preserve comments

yaml = ruamel.yaml.YAML()
with open('config.yaml', 'r') as file:
    config = yaml.load(file)

##Upate to use the same models and just change the directory
teacher_model_path = "models/mistral-7b-instruct-v0.2.Q4_K_M.gguf"
base_model_path = "models/instructlab/granite-7b-lab"
##judge_model_path = "models/prometheus-eval/prometheus-8x7b-v2.0"

##config['evaluate']['mt_bench']['judge_model'] = judge_model_path
##config['evaluate']['mt_bench_branch']['judge_model'] = judge_model_path
config['generate']['model'] = teacher_model_path
config['generate']['teacher']['model_path']= teacher_model_path
##config['train']['phased_mt_bench_judge']=judge_model_path

#Update GPU information
config['evaluate']['gpus']=gpus
config['generate']['teacher']['vllm']['gpus']=gpus
config['serve']['vllm']['gpus']=gpus
config['train']['nproc_per_node']=gpus
config['metadata']['gpu_count']=gpus
if gpus==1:
  config['train']['device']="cuda"
  if gpu_type[:6]=="NVIDIA":
    config['metadata']['gpu_manufacturer']="Nvidia"
    config['metadata']['gpu_family']=gpu_type[7:]

## Save the updated config.yaml file
yaml.default_flow_style=False
with open('config.yaml', 'w') as file:
    yaml.dump(config, file)

##copy the config file to the .config/instructlab/ where it is used by InstructLab
# !cp config.yaml {base_dir}.config/instructlab/

print("Updated config.yaml successfully.\n")
# !cat config.yaml
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-212ff60be36f> in <cell line: 0>()
#      17
#      18 #Update GPU information
# ---> 19 config['evaluate']['gpus']=gpus
#      20 config['generate']['teacher']['vllm']['gpus']=gpus
#      21 config['serve']['vllm']['gpus']=gpus
#
# NameError: name 'gpus' is not defined

# %% [markdown]
# <a id="IL1_down"></a>
# ## Step 1.7 Download Models
# The models that will be used in the InstructLab processing are downloaded in this step. Additional steps can be added if other models are used in processing.

# %% [markdown]
# The merlinite model will be used as the teacher model for the simple pipeline in the **Training with InstructLab** section.
#
# The mistral-7b-instruct-v0.2.Q4_K_M model will be used as the teacher model for the full pipeline in that section.
#
# The granite07b-lab.gguf model is a quantized version of the granite-7b-lab model.

# %%
models_dir="models"
# !ilab model download --hf-token {hf_token} --model-dir {models_dir}

# Download the granite 7b safe tensors model
# !ilab model download --repository instructlab/granite-7b-lab --hf-token {hf_token} --model-dir {models_dir}
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# INFO 2025-06-04 04:19:37,191 instructlab.model.download:77: Downloading model from Hugging Face:
#     Model: instructlab/granite-7b-lab-GGUF@main
#     Destination: models
# Downloading 'granite-7b-lab-Q4_K_M.gguf' to 'models/.cache/huggingface/download/cBHY6fAjnFSRbyeHvtiPqRVG_SE=.6adeaad8c048b35ea54562c55e454cc32c63118a32c7b8152cf706b290611487.incomplete'
# INFO 2025-06-04 04:19:37,494 huggingface_hub.file_download:1701: Downloading 'granite-7b-lab-Q4_K_M.gguf' to 'models/.cache/huggingface/download/cBHY6fAjnFSRbyeHvtiPqRVG_SE=.6adeaad8c048b35ea54562c55e454cc32c63118a32c7b8152cf706b290611487.incomplete'
# granite-7b-lab-Q4_K_M.gguf: 100% 4.08G/4.08G [00:37<00:00, 108MB/s]
# Download complete. Moving file to models/granite-7b-lab-Q4_K_M.gguf
# INFO 2025-06-04 04:20:15,282 huggingface_hub.file_download:1734: Download complete. Moving file to models/granite-7b-lab-Q4_K_M.gguf
# INFO 2025-06-04 04:20:15,284 instructlab.model.download:288:
# ᕦ(òᴗóˇ)ᕤ instructlab/granite-7b-lab-GGUF model download completed successfully! ᕦ(òᴗóˇ)ᕤ
#
# INFO 2025-06-04 04:20:15,284 instructlab.model.download:77: Downloading model from Hugging Face:
#     Model: instructlab/merlinite-7b-lab-GGUF@main
#     Destination: models
# Downloading 'merlinite-7b-lab-Q4_K_M.gguf' to 'models/.cache/huggingface/download/lthSnQjZ9ZcQ2z_C0bHbTqkW0fw=.9ca044d727db34750e1aeb04e3b18c3cf4a8c064a9ac96cf00448c506631d16c.incomplete'
# INFO 2025-06-04 04:20:15,585 huggingface_hub.file_download:1701: Downloading 'merlinite-7b-lab-Q4_K_M.gguf' to 'models/.cache/huggingface/download/lthSnQjZ9ZcQ2z_C0bHbTqkW0fw=.9ca044d727db34750e1aeb04e3b18c3cf4a8c064a9ac96cf00448c506631d16c.incomplete'
# merlinite-7b-lab-Q4_K_M.gguf: 100% 4.37G/4.37G [00:36<00:00, 121MB/s]
# Download complete. Moving file to models/merlinite-7b-lab-Q4_K_M.gguf
# INFO 2025-06-04 04:20:51,736 huggingface_hub.file_download:1734: Download complete. Moving file to models/merlinite-7b-lab-Q4_K_M.gguf
# INFO 2025-06-04 04:20:51,737 instructlab.model.download:288:
# ᕦ(òᴗóˇ)ᕤ instructlab/merlinite-7b-lab-GGUF model download completed successfully! ᕦ(òᴗóˇ)ᕤ
#
# INFO 2025-06-04 04:20:51,737 instructlab.model.download:77: Downloading model from Hugging Face:
#     Model: TheBloke/Mistral-7B-Instruct-v0.2-GGUF@main
#     Destination: models
# Downloading 'mistral-7b-instruct-v0.2.Q4_K_M.gguf' to 'models/.cache/huggingface/download/zxktiwKjmHzn1ii-8vMr5CM80KA=.3e0039fd0273fcbebb49228943b17831aadd55cbcbf56f0af00499be2040ccf9.incomplete'
# INFO 2025-06-04 04:20:51,906 huggingface_hub.file_download:1701: Downloading 'mistral-7b-instruct-v0.2.Q4_K_M.gguf' to 'models/.cache/huggingface/download/zxktiwKjmHzn1ii-8vMr5CM80KA=.3e0039fd0273fcbebb49228943b17831aadd55cbcbf56f0af00499be2040ccf9.incomplete'
# mistral-7b-instruct-v0.2.Q4_K_M.gguf: 100% 4.37G/4.37G [00:39<00:00, 112MB/s]
# Download complete. Moving file to models/mistral-7b-instruct-v0.2.Q4_K_M.gguf
# INFO 2025-06-04 04:21:31,164 huggingface_hub.file_download:1734: Download complete. Moving file to models/mistral-7b-instruct-v0.2.Q4_K_M.gguf
# INFO 2025-06-04 04:21:31,165 instructlab.model.download:288:
# ᕦ(òᴗóˇ)ᕤ TheBloke/Mistral-7B-Instruct-v0.2-GGUF model download completed successfully! ᕦ(òᴗóˇ)ᕤ
#
# INFO 2025-06-04 04:21:31,165 instructlab.model.download:77: Downloading model from Hugging Face:
#     Model: ibm-granite/granite-embedding-125m-english@main
#     Destination: models
# Downloading '.gitattributes' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.a6344aac8c09253b3b630fb776ae94478aa0275b.incomplete'
# INFO 2025-06-04 04:21:31,897 huggingface_hub.file_download:1701: Downloading '.gitattributes' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.a6344aac8c09253b3b630fb776ae94478aa0275b.incomplete'
# .gitattributes: 100% 1.52k/1.52k [00:00<00:00, 9.55MB/s]
# Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/.gitattributes
# INFO 2025-06-04 04:21:32,039 huggingface_hub.file_download:1734: Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/.gitattributes
# Downloading '1_Pooling/config.json' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/1_Pooling/8_PA_wEVGiVa2goH2H4KQOQpvVY=.019ba7c500eae108dcab029f5e8dbb2960285a81.incomplete'
# INFO 2025-06-04 04:21:32,113 huggingface_hub.file_download:1701: Downloading '1_Pooling/config.json' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/1_Pooling/8_PA_wEVGiVa2goH2H4KQOQpvVY=.019ba7c500eae108dcab029f5e8dbb2960285a81.incomplete'
# config.json: 100% 191/191 [00:00<00:00, 1.33MB/s]
# Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/1_Pooling/config.json
# INFO 2025-06-04 04:21:32,263 huggingface_hub.file_download:1734: Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/1_Pooling/config.json
# Downloading 'README.md' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.6890f414028e16ec75b31c2a36e5bed4e4f5ac5d.incomplete'
# INFO 2025-06-04 04:21:32,357 huggingface_hub.file_download:1701: Downloading 'README.md' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.6890f414028e16ec75b31c2a36e5bed4e4f5ac5d.incomplete'
# README.md: 100% 466k/466k [00:00<00:00, 2.80MB/s]
# Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/README.md
# INFO 2025-06-04 04:21:32,972 huggingface_hub.file_download:1734: Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/README.md
# Downloading 'config.json' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/8_PA_wEVGiVa2goH2H4KQOQpvVY=.567a210b8af635995b70b221fcda1f6153796554.incomplete'
# INFO 2025-06-04 04:21:33,046 huggingface_hub.file_download:1701: Downloading 'config.json' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/8_PA_wEVGiVa2goH2H4KQOQpvVY=.567a210b8af635995b70b221fcda1f6153796554.incomplete'
# config.json: 100% 720/720 [00:00<00:00, 4.84MB/s]
# Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/config.json
# INFO 2025-06-04 04:21:33,223 huggingface_hub.file_download:1734: Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/config.json
# Downloading 'model.safetensors' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/xGOKKLRSlIhH692hSVvI1-gpoa8=.ee70cb80637b769409e4ccfde7d188bb2c564495d1a63cde3ca60741b2a7302d.incomplete'
# INFO 2025-06-04 04:21:33,301 huggingface_hub.file_download:1701: Downloading 'model.safetensors' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/xGOKKLRSlIhH692hSVvI1-gpoa8=.ee70cb80637b769409e4ccfde7d188bb2c564495d1a63cde3ca60741b2a7302d.incomplete'
# Xet Storage is enabled for this repo. Downloading file from Xet Storage..
# INFO 2025-06-04 04:21:33,301 huggingface_hub.file_download:1709: Xet Storage is enabled for this repo. Downloading file from Xet Storage..
# model.safetensors: 100% 249M/249M [00:04<00:00, 51.2MB/s]
# Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/model.safetensors
# INFO 2025-06-04 04:21:38,306 huggingface_hub.file_download:1734: Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/model.safetensors
# Downloading 'modules.json' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/rqDUs8AfQpUqG2NjnkGNseO9-Z4=.a32b46a13926a0aeb8367448eef21d776acd09b9.incomplete'
# INFO 2025-06-04 04:21:38,388 huggingface_hub.file_download:1701: Downloading 'modules.json' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/rqDUs8AfQpUqG2NjnkGNseO9-Z4=.a32b46a13926a0aeb8367448eef21d776acd09b9.incomplete'
# modules.json: 100% 350/350 [00:00<00:00, 2.08MB/s]
# Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/modules.json
# INFO 2025-06-04 04:21:38,845 huggingface_hub.file_download:1734: Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/modules.json
# Downloading 'pytorch_model.bin' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/Q1p2l2BzM1m6P5jKvr8WTq1TUio=.6c7f63729082870ffcd793b2b034c10880d1b84ad10887f649a19fd4b0608233.incomplete'
# INFO 2025-06-04 04:21:38,953 huggingface_hub.file_download:1701: Downloading 'pytorch_model.bin' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/Q1p2l2BzM1m6P5jKvr8WTq1TUio=.6c7f63729082870ffcd793b2b034c10880d1b84ad10887f649a19fd4b0608233.incomplete'
# Xet Storage is enabled for this repo. Downloading file from Xet Storage..
# INFO 2025-06-04 04:21:38,953 huggingface_hub.file_download:1709: Xet Storage is enabled for this repo. Downloading file from Xet Storage..
# pytorch_model.bin: 100% 249M/249M [00:09<00:00, 27.2MB/s]
# Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/pytorch_model.bin
# INFO 2025-06-04 04:21:48,203 huggingface_hub.file_download:1734: Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/pytorch_model.bin
# Downloading 'sentence_bert_config.json' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/lGVMDuXJ-eOxWaZOviD6MtO-75w=.42d076262fe42eec1f923135b424c5a2bada7931.incomplete'
# INFO 2025-06-04 04:21:48,347 huggingface_hub.file_download:1701: Downloading 'sentence_bert_config.json' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/lGVMDuXJ-eOxWaZOviD6MtO-75w=.42d076262fe42eec1f923135b424c5a2bada7931.incomplete'
# sentence_bert_config.json: 100% 54.0/54.0 [00:00<00:00, 411kB/s]
# Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/sentence_bert_config.json
# INFO 2025-06-04 04:21:48,443 huggingface_hub.file_download:1734: Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/sentence_bert_config.json
# Downloading 'special_tokens_map.json' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/ahkChHUJFxEmOdq5GDFEmerRzCY=.06a55849fa69a91e7179d909e373179ff7467d8c.incomplete'
# INFO 2025-06-04 04:21:48,520 huggingface_hub.file_download:1701: Downloading 'special_tokens_map.json' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/ahkChHUJFxEmOdq5GDFEmerRzCY=.06a55849fa69a91e7179d909e373179ff7467d8c.incomplete'
# special_tokens_map.json: 100% 957/957 [00:00<00:00, 6.37MB/s]
# Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/special_tokens_map.json
# INFO 2025-06-04 04:21:48,595 huggingface_hub.file_download:1734: Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/special_tokens_map.json
# Downloading 'tokenizer.json' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/HgM_lKo9sdSCfRtVg7MMFS7EKqo=.e49dc54bc4119e0bb31a290dc6da28d46b408f19.incomplete'
# INFO 2025-06-04 04:21:48,704 huggingface_hub.file_download:1701: Downloading 'tokenizer.json' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/HgM_lKo9sdSCfRtVg7MMFS7EKqo=.e49dc54bc4119e0bb31a290dc6da28d46b408f19.incomplete'
# tokenizer.json: 100% 2.11M/2.11M [00:00<00:00, 28.2MB/s]
# Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/tokenizer.json
# INFO 2025-06-04 04:21:48,865 huggingface_hub.file_download:1734: Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/tokenizer.json
# Downloading 'tokenizer_config.json' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/vzaExXFZNBay89bvlQv-ZcI6BTg=.553932f6f7d3063d5f372df43dad9e05177bd3be.incomplete'
# INFO 2025-06-04 04:21:48,947 huggingface_hub.file_download:1701: Downloading 'tokenizer_config.json' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/vzaExXFZNBay89bvlQv-ZcI6BTg=.553932f6f7d3063d5f372df43dad9e05177bd3be.incomplete'
# tokenizer_config.json: 100% 1.32k/1.32k [00:00<00:00, 5.87MB/s]
# Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/tokenizer_config.json
# INFO 2025-06-04 04:21:49,041 huggingface_hub.file_download:1734: Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/tokenizer_config.json
# Downloading 'trainer_state.json' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/1uiJ87Eu3vvlOlZKj0NZvGlSO3I=.ca0c08d4ccb437e472d37fe71364d7be6d479bd2.incomplete'
# INFO 2025-06-04 04:21:49,169 huggingface_hub.file_download:1701: Downloading 'trainer_state.json' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/1uiJ87Eu3vvlOlZKj0NZvGlSO3I=.ca0c08d4ccb437e472d37fe71364d7be6d479bd2.incomplete'
# trainer_state.json: 100% 451k/451k [00:00<00:00, 11.7MB/s]
# Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/trainer_state.json
# INFO 2025-06-04 04:21:49,286 huggingface_hub.file_download:1734: Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/trainer_state.json
# Downloading 'vocab.json' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/j3m-Hy6QvBddw8RXA1uSWl1AJ0c=.4ebe4bb3f3114daf2e4cc349f24873a1175a35d7.incomplete'
# INFO 2025-06-04 04:21:49,367 huggingface_hub.file_download:1701: Downloading 'vocab.json' to 'models/ibm-granite/granite-embedding-125m-english/.cache/huggingface/download/j3m-Hy6QvBddw8RXA1uSWl1AJ0c=.4ebe4bb3f3114daf2e4cc349f24873a1175a35d7.incomplete'
# vocab.json: 100% 798k/798k [00:00<00:00, 56.0MB/s]
# Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/vocab.json
# INFO 2025-06-04 04:21:49,474 huggingface_hub.file_download:1734: Download complete. Moving file to models/ibm-granite/granite-embedding-125m-english/vocab.json
# INFO 2025-06-04 04:21:49,477 instructlab.model.download:288:
# ᕦ(òᴗóˇ)ᕤ ibm-granite/granite-embedding-125m-english model download completed successfully! ᕦ(òᴗóˇ)ᕤ
#
# INFO 2025-06-04 04:21:49,477 instructlab.model.download:302: Available models (`ilab model list`):
# +--------------------------------------------+---------------------+----------+-----------------------------------------------------------------------+
# | Model Name                                 | Last Modified       | Size     | Absolute path                                                         |
# +--------------------------------------------+---------------------+----------+-----------------------------------------------------------------------+
# | ibm-granite/granite-embedding-125m-english | 2025-06-04 04:21:49 | 479.2 MB | /content/ilab-hello-world/models/ibm-granite                          |
# | mistral-7b-instruct-v0.2.Q4_K_M.gguf       | 2025-06-04 04:21:31 | 4.1 GB   | /content/ilab-hello-world/models/mistral-7b-instruct-v0.2.Q4_K_M.gguf |
# | granite-7b-lab-Q4_K_M.gguf                 | 2025-06-04 04:20:14 | 3.8 GB   | /content/ilab-hello-world/models/granite-7b-lab-Q4_K_M.gguf           |
# | merlinite-7b-lab-Q4_K_M.gguf               | 2025-06-04 04:20:51 | 4.1 GB   | /content/ilab-hello-world/models/merlinite-7b-lab-Q4_K_M.gguf         |
# +--------------------------------------------+---------------------+----------+-----------------------------------------------------------------------+
# INFO 2025-06-04 04:21:53,657 instructlab.model.download:77: Downloading model from Hugging Face:
#     Model: instructlab/granite-7b-lab@main
#     Destination: models
# Downloading '.gitattributes' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.a6344aac8c09253b3b630fb776ae94478aa0275b.incomplete'
# INFO 2025-06-04 04:21:55,475 huggingface_hub.file_download:1701: Downloading '.gitattributes' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.a6344aac8c09253b3b630fb776ae94478aa0275b.incomplete'
# .gitattributes: 100% 1.52k/1.52k [00:00<00:00, 7.17MB/s]
# Download complete. Moving file to models/instructlab/granite-7b-lab/.gitattributes
# INFO 2025-06-04 04:21:55,662 huggingface_hub.file_download:1734: Download complete. Moving file to models/instructlab/granite-7b-lab/.gitattributes
# Downloading 'README.md' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.d666b536700a28a709eca207f318d85f2429b4bb.incomplete'
# INFO 2025-06-04 04:21:55,785 huggingface_hub.file_download:1701: Downloading 'README.md' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.d666b536700a28a709eca207f318d85f2429b4bb.incomplete'
# README.md: 100% 7.48k/7.48k [00:00<00:00, 23.1MB/s]
# Download complete. Moving file to models/instructlab/granite-7b-lab/README.md
# INFO 2025-06-04 04:21:55,878 huggingface_hub.file_download:1734: Download complete. Moving file to models/instructlab/granite-7b-lab/README.md
# Downloading 'added_tokens.json' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/SeqzFlf9ZNZ3or_wZAOIdsM3Yxw=.ab9131bbe927da43320e49abbd99b99ef56a9c9b.incomplete'
# INFO 2025-06-04 04:21:55,989 huggingface_hub.file_download:1701: Downloading 'added_tokens.json' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/SeqzFlf9ZNZ3or_wZAOIdsM3Yxw=.ab9131bbe927da43320e49abbd99b99ef56a9c9b.incomplete'
# added_tokens.json: 100% 119/119 [00:00<00:00, 658kB/s]
# Download complete. Moving file to models/instructlab/granite-7b-lab/added_tokens.json
# INFO 2025-06-04 04:21:56,080 huggingface_hub.file_download:1734: Download complete. Moving file to models/instructlab/granite-7b-lab/added_tokens.json
# Downloading 'config.json' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/8_PA_wEVGiVa2goH2H4KQOQpvVY=.468e5f9b20571efbe262aceef3673616bcf101d6.incomplete'
# INFO 2025-06-04 04:21:56,175 huggingface_hub.file_download:1701: Downloading 'config.json' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/8_PA_wEVGiVa2goH2H4KQOQpvVY=.468e5f9b20571efbe262aceef3673616bcf101d6.incomplete'
# config.json: 100% 609/609 [00:00<00:00, 3.57MB/s]
# Download complete. Moving file to models/instructlab/granite-7b-lab/config.json
# INFO 2025-06-04 04:21:56,275 huggingface_hub.file_download:1734: Download complete. Moving file to models/instructlab/granite-7b-lab/config.json
# Downloading 'generation_config.json' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/3EVKVggOldJcKSsGjSdoUCN1AyQ=.9188e67b98e3b9ae3f6eb7179a89631e4ea1401e.incomplete'
# INFO 2025-06-04 04:21:56,370 huggingface_hub.file_download:1701: Downloading 'generation_config.json' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/3EVKVggOldJcKSsGjSdoUCN1AyQ=.9188e67b98e3b9ae3f6eb7179a89631e4ea1401e.incomplete'
# generation_config.json: 100% 111/111 [00:00<00:00, 594kB/s]
# Download complete. Moving file to models/instructlab/granite-7b-lab/generation_config.json
# INFO 2025-06-04 04:21:56,468 huggingface_hub.file_download:1734: Download complete. Moving file to models/instructlab/granite-7b-lab/generation_config.json
# Downloading 'model-00001-of-00003.safetensors' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/Y6g195DXbsCiN_Ka1NwH6jyLkvc=.d16bf783cb6670f7f692ad7d6885ab957c63cfc1b9649bc4a3ba1cfbdfd5230c.incomplete'
# INFO 2025-06-04 04:21:56,576 huggingface_hub.file_download:1701: Downloading 'model-00001-of-00003.safetensors' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/Y6g195DXbsCiN_Ka1NwH6jyLkvc=.d16bf783cb6670f7f692ad7d6885ab957c63cfc1b9649bc4a3ba1cfbdfd5230c.incomplete'
# model-00001-of-00003.safetensors: 100% 4.94G/4.94G [00:36<00:00, 135MB/s]
# Download complete. Moving file to models/instructlab/granite-7b-lab/model-00001-of-00003.safetensors
# INFO 2025-06-04 04:22:33,301 huggingface_hub.file_download:1734: Download complete. Moving file to models/instructlab/granite-7b-lab/model-00001-of-00003.safetensors
# Downloading 'model-00002-of-00003.safetensors' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/D5-QTaCbl9VUFv9Wr0C28eFewRc=.b4cbcd39f603d22deeeb7625ad6a8afda73ac3612d06e3da5142496934710ef3.incomplete'
# INFO 2025-06-04 04:22:33,413 huggingface_hub.file_download:1701: Downloading 'model-00002-of-00003.safetensors' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/D5-QTaCbl9VUFv9Wr0C28eFewRc=.b4cbcd39f603d22deeeb7625ad6a8afda73ac3612d06e3da5142496934710ef3.incomplete'
# model-00002-of-00003.safetensors: 100% 4.95G/4.95G [00:54<00:00, 90.6MB/s]
# Download complete. Moving file to models/instructlab/granite-7b-lab/model-00002-of-00003.safetensors
# INFO 2025-06-04 04:23:28,141 huggingface_hub.file_download:1734: Download complete. Moving file to models/instructlab/granite-7b-lab/model-00002-of-00003.safetensors
# Downloading 'model-00003-of-00003.safetensors' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/NmVQgThqhsRkG2FlXLh-M51MilA=.72ce22c1313f003edc09a3d5767e4a9a632759659ad3a5f975ced1c3bac16791.incomplete'
# INFO 2025-06-04 04:23:28,245 huggingface_hub.file_download:1701: Downloading 'model-00003-of-00003.safetensors' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/NmVQgThqhsRkG2FlXLh-M51MilA=.72ce22c1313f003edc09a3d5767e4a9a632759659ad3a5f975ced1c3bac16791.incomplete'
# model-00003-of-00003.safetensors: 100% 3.59G/3.59G [01:24<00:00, 42.7MB/s]
# Download complete. Moving file to models/instructlab/granite-7b-lab/model-00003-of-00003.safetensors
# INFO 2025-06-04 04:24:52,438 huggingface_hub.file_download:1734: Download complete. Moving file to models/instructlab/granite-7b-lab/model-00003-of-00003.safetensors
# Downloading 'model-card/Model Card for Merlinite 7b 28cc0b72cf574a4a828140d3539ede4a_Screenshot_2024-02-22_at_11.26.13_AM.png' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/model-card/4Md_LyO6To4lsiZqJtoLIgI6vTo=.33b033736ffe409d3571d4ad90d7e0309408c4a8.incomplete'
# INFO 2025-06-04 04:24:52,542 huggingface_hub.file_download:1701: Downloading 'model-card/Model Card for Merlinite 7b 28cc0b72cf574a4a828140d3539ede4a_Screenshot_2024-02-22_at_11.26.13_AM.png' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/model-card/4Md_LyO6To4lsiZqJtoLIgI6vTo=.33b033736ffe409d3571d4ad90d7e0309408c4a8.incomplete'
# (…)Screenshot_2024-02-22_at_11.26.13_AM.png: 100% 394k/394k [00:00<00:00, 2.93MB/s]
# Download complete. Moving file to models/instructlab/granite-7b-lab/model-card/Model Card for Merlinite 7b 28cc0b72cf574a4a828140d3539ede4a_Screenshot_2024-02-22_at_11.26.13_AM.png
# INFO 2025-06-04 04:24:52,794 huggingface_hub.file_download:1734: Download complete. Moving file to models/instructlab/granite-7b-lab/model-card/Model Card for Merlinite 7b 28cc0b72cf574a4a828140d3539ede4a_Screenshot_2024-02-22_at_11.26.13_AM.png
# Downloading 'model-card/Model Card for Merlinite 7b 28cc0b72cf574a4a828140d3539ede4a_Untitled 1.png' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/model-card/G0XvMsxpbLVoNCrO59bC-Qle1Cg=.73c4322b821886f685312c8f8da91acab944fcdc.incomplete'
# INFO 2025-06-04 04:24:52,897 huggingface_hub.file_download:1701: Downloading 'model-card/Model Card for Merlinite 7b 28cc0b72cf574a4a828140d3539ede4a_Untitled 1.png' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/model-card/G0XvMsxpbLVoNCrO59bC-Qle1Cg=.73c4322b821886f685312c8f8da91acab944fcdc.incomplete'
# (…)f574a4a828140d3539ede4a_Untitled%201.png: 100% 206k/206k [00:00<00:00, 57.6MB/s]
# Download complete. Moving file to models/instructlab/granite-7b-lab/model-card/Model Card for Merlinite 7b 28cc0b72cf574a4a828140d3539ede4a_Untitled 1.png
# INFO 2025-06-04 04:24:52,998 huggingface_hub.file_download:1734: Download complete. Moving file to models/instructlab/granite-7b-lab/model-card/Model Card for Merlinite 7b 28cc0b72cf574a4a828140d3539ede4a_Untitled 1.png
# Downloading 'model-card/Model Card for Merlinite 7b 28cc0b72cf574a4a828140d3539ede4a_Untitled 2.png' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/model-card/WXzkHPptQ7M9wyYjZwoiiEwpE_g=.963f698cd1e59590be685c18ede04eeba707f2b7.incomplete'
# INFO 2025-06-04 04:24:53,102 huggingface_hub.file_download:1701: Downloading 'model-card/Model Card for Merlinite 7b 28cc0b72cf574a4a828140d3539ede4a_Untitled 2.png' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/model-card/WXzkHPptQ7M9wyYjZwoiiEwpE_g=.963f698cd1e59590be685c18ede04eeba707f2b7.incomplete'
# (…)f574a4a828140d3539ede4a_Untitled%202.png: 100% 31.3k/31.3k [00:00<00:00, 81.4MB/s]
# Download complete. Moving file to models/instructlab/granite-7b-lab/model-card/Model Card for Merlinite 7b 28cc0b72cf574a4a828140d3539ede4a_Untitled 2.png
# INFO 2025-06-04 04:24:53,205 huggingface_hub.file_download:1734: Download complete. Moving file to models/instructlab/granite-7b-lab/model-card/Model Card for Merlinite 7b 28cc0b72cf574a4a828140d3539ede4a_Untitled 2.png
# Downloading 'model-card/Model Card for Merlinite 7b 28cc0b72cf574a4a828140d3539ede4a_Untitled.png' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/model-card/zwvs5T12N3XSFG8BMXBbQ3tPJPU=.07085c017249a4801a85d4c9dc87bcb6c10b6fbf.incomplete'
# INFO 2025-06-04 04:24:53,338 huggingface_hub.file_download:1701: Downloading 'model-card/Model Card for Merlinite 7b 28cc0b72cf574a4a828140d3539ede4a_Untitled.png' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/model-card/zwvs5T12N3XSFG8BMXBbQ3tPJPU=.07085c017249a4801a85d4c9dc87bcb6c10b6fbf.incomplete'
# (…)b72cf574a4a828140d3539ede4a_Untitled.png: 100% 185k/185k [00:00<00:00, 40.4MB/s]
# Download complete. Moving file to models/instructlab/granite-7b-lab/model-card/Model Card for Merlinite 7b 28cc0b72cf574a4a828140d3539ede4a_Untitled.png
# INFO 2025-06-04 04:24:53,438 huggingface_hub.file_download:1734: Download complete. Moving file to models/instructlab/granite-7b-lab/model-card/Model Card for Merlinite 7b 28cc0b72cf574a4a828140d3539ede4a_Untitled.png
# Downloading 'model-card/Model Card for Merlinite 7b 28cc0b72cf574a4a828140d3539ede4a_intuition.png' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/model-card/dWsNcdYxOtwsjf8KbI1mguU_YEE=.deace5b438454976d06206bcf9740ee2c73baf34.incomplete'
# INFO 2025-06-04 04:24:53,537 huggingface_hub.file_download:1701: Downloading 'model-card/Model Card for Merlinite 7b 28cc0b72cf574a4a828140d3539ede4a_intuition.png' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/model-card/dWsNcdYxOtwsjf8KbI1mguU_YEE=.deace5b438454976d06206bcf9740ee2c73baf34.incomplete'
# (…)72cf574a4a828140d3539ede4a_intuition.png: 100% 34.3k/34.3k [00:00<00:00, 93.1MB/s]
# Download complete. Moving file to models/instructlab/granite-7b-lab/model-card/Model Card for Merlinite 7b 28cc0b72cf574a4a828140d3539ede4a_intuition.png
# INFO 2025-06-04 04:24:53,638 huggingface_hub.file_download:1734: Download complete. Moving file to models/instructlab/granite-7b-lab/model-card/Model Card for Merlinite 7b 28cc0b72cf574a4a828140d3539ede4a_intuition.png
# Downloading 'model.safetensors.index.json' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/yVzAsSxRSINSz-tQbpx-TLpfkLU=.042f059959c28feee2de74e0c09a5c7c47d55afe.incomplete'
# INFO 2025-06-04 04:24:53,732 huggingface_hub.file_download:1701: Downloading 'model.safetensors.index.json' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/yVzAsSxRSINSz-tQbpx-TLpfkLU=.042f059959c28feee2de74e0c09a5c7c47d55afe.incomplete'
# model.safetensors.index.json: 100% 23.9k/23.9k [00:00<00:00, 70.4MB/s]
# Download complete. Moving file to models/instructlab/granite-7b-lab/model.safetensors.index.json
# INFO 2025-06-04 04:24:53,835 huggingface_hub.file_download:1734: Download complete. Moving file to models/instructlab/granite-7b-lab/model.safetensors.index.json
# Downloading 'paper.pdf' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/nleIIzOp7oS1exmi5ym6jExY63Q=.a5c0c72c8a42b54fc1dd20f9d24ca1031c4fa193.incomplete'
# INFO 2025-06-04 04:24:54,026 huggingface_hub.file_download:1701: Downloading 'paper.pdf' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/nleIIzOp7oS1exmi5ym6jExY63Q=.a5c0c72c8a42b54fc1dd20f9d24ca1031c4fa193.incomplete'
# paper.pdf: 100% 201k/201k [00:00<00:00, 34.8MB/s]
# Download complete. Moving file to models/instructlab/granite-7b-lab/paper.pdf
# INFO 2025-06-04 04:24:54,128 huggingface_hub.file_download:1734: Download complete. Moving file to models/instructlab/granite-7b-lab/paper.pdf
# Downloading 'special_tokens_map.json' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/ahkChHUJFxEmOdq5GDFEmerRzCY=.8773c59650d5903cd0a9671c74174cabdc322221.incomplete'
# INFO 2025-06-04 04:24:54,223 huggingface_hub.file_download:1701: Downloading 'special_tokens_map.json' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/ahkChHUJFxEmOdq5GDFEmerRzCY=.8773c59650d5903cd0a9671c74174cabdc322221.incomplete'
# special_tokens_map.json: 100% 655/655 [00:00<00:00, 3.26MB/s]
# Download complete. Moving file to models/instructlab/granite-7b-lab/special_tokens_map.json
# INFO 2025-06-04 04:24:54,323 huggingface_hub.file_download:1734: Download complete. Moving file to models/instructlab/granite-7b-lab/special_tokens_map.json
# Downloading 'tokenizer.json' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/HgM_lKo9sdSCfRtVg7MMFS7EKqo=.030630fdec0c3c6a18624b4fe08278b9456d37d2.incomplete'
# INFO 2025-06-04 04:24:54,446 huggingface_hub.file_download:1701: Downloading 'tokenizer.json' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/HgM_lKo9sdSCfRtVg7MMFS7EKqo=.030630fdec0c3c6a18624b4fe08278b9456d37d2.incomplete'
# tokenizer.json: 100% 1.84M/1.84M [00:00<00:00, 13.5MB/s]
# Download complete. Moving file to models/instructlab/granite-7b-lab/tokenizer.json
# INFO 2025-06-04 04:24:54,678 huggingface_hub.file_download:1734: Download complete. Moving file to models/instructlab/granite-7b-lab/tokenizer.json
# Downloading 'tokenizer.model' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/7iVfz3cUOMr-hyjiqqRDHEwVBAM=.9e556afd44213b6bd1be2b850ebbbd98f5481437a8021afaf58ee7fb1818d347.incomplete'
# INFO 2025-06-04 04:24:54,774 huggingface_hub.file_download:1701: Downloading 'tokenizer.model' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/7iVfz3cUOMr-hyjiqqRDHEwVBAM=.9e556afd44213b6bd1be2b850ebbbd98f5481437a8021afaf58ee7fb1818d347.incomplete'
# tokenizer.model: 100% 500k/500k [00:00<00:00, 12.0MB/s]
# Download complete. Moving file to models/instructlab/granite-7b-lab/tokenizer.model
# INFO 2025-06-04 04:24:54,888 huggingface_hub.file_download:1734: Download complete. Moving file to models/instructlab/granite-7b-lab/tokenizer.model
# Downloading 'tokenizer_config.json' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/vzaExXFZNBay89bvlQv-ZcI6BTg=.082f07ffa83efe72e566fda5fde679dcd80fb7cd.incomplete'
# INFO 2025-06-04 04:24:54,981 huggingface_hub.file_download:1701: Downloading 'tokenizer_config.json' to 'models/instructlab/granite-7b-lab/.cache/huggingface/download/vzaExXFZNBay89bvlQv-ZcI6BTg=.082f07ffa83efe72e566fda5fde679dcd80fb7cd.incomplete'
# tokenizer_config.json: 100% 2.27k/2.27k [00:00<00:00, 12.1MB/s]
# Download complete. Moving file to models/instructlab/granite-7b-lab/tokenizer_config.json
# INFO 2025-06-04 04:24:55,075 huggingface_hub.file_download:1734: Download complete. Moving file to models/instructlab/granite-7b-lab/tokenizer_config.json
# INFO 2025-06-04 04:24:55,076 instructlab.model.download:288:
# ᕦ(òᴗóˇ)ᕤ instructlab/granite-7b-lab model download completed successfully! ᕦ(òᴗóˇ)ᕤ
#
# INFO 2025-06-04 04:24:55,076 instructlab.model.download:302: Available models (`ilab model list`):
# +--------------------------------------------+---------------------+----------+-----------------------------------------------------------------------+
# | Model Name                                 | Last Modified       | Size     | Absolute path                                                         |
# +--------------------------------------------+---------------------+----------+-----------------------------------------------------------------------+
# | ibm-granite/granite-embedding-125m-english | 2025-06-04 04:21:49 | 479.2 MB | /content/ilab-hello-world/models/ibm-granite                          |
# | instructlab/granite-7b-lab                 | 2025-06-04 04:24:55 | 12.6 GB  | /content/ilab-hello-world/models/instructlab                          |
# | mistral-7b-instruct-v0.2.Q4_K_M.gguf       | 2025-06-04 04:21:31 | 4.1 GB   | /content/ilab-hello-world/models/mistral-7b-instruct-v0.2.Q4_K_M.gguf |
# | granite-7b-lab-Q4_K_M.gguf                 | 2025-06-04 04:20:14 | 3.8 GB   | /content/ilab-hello-world/models/granite-7b-lab-Q4_K_M.gguf           |
# | merlinite-7b-lab-Q4_K_M.gguf               | 2025-06-04 04:20:51 | 4.1 GB   | /content/ilab-hello-world/models/merlinite-7b-lab-Q4_K_M.gguf         |
# +--------------------------------------------+---------------------+----------+-----------------------------------------------------------------------+

# %% [markdown]
# <a id="IL2_0"></a>
# # Section 2. Generating Synthetic Data
#
#
# This section demonstrates training with InstructLab. This section is part of a sequential notebook. Before running this section of the notebook, please ensure that you have run the Configuring InstructLab section of this notebook.
#
# In this section, we will demonstrate:
# - Creating a question and answer data file
# - Generating synthetic data for training
# - Training the LLM with the generated data
#
# The steps in this section are as follows:
# * Step 2.1 Specify the Data for this Run
# * Step 2.2 Create the Taxonomy Data Repository
# * Step 2.3 Generate Synthetic Data
# * Step 2.4 Train Model

# %% [markdown]
# <a id="IL2_data"></a>
# ## Step 2.1 Specify the Data for this Run
#
# We've provided question-and-answer files for these datasets: "2024 Oscar Awards Ceremony", "Quantum Roadmap and Patterns" and "Artificial Intelligence Agents". Feel free to choose one of these datasets, or select your own custom dataset in the cell below.

# %% [markdown]
# ### Optionally, Create your own data set for InstructLab
#
# You can optionally provide your own InstructLab QNA file for processing in this step.
#
# Follow these steps to add your own dataset:
# 1. Create your own qna.yaml file following the directions on the InstructLab taxonomy [readme](https://github.com/instructlab/taxonomy).
# 1. Create a questions.txt file with related sample questions to use on inferencing.
# 1. Add your qna.yaml and sample questions.txt files to the /content/ilab/data/your_content_1 folder or the /content/ilab/data/your_content_2 folder by dragging and dropping them in the desired folder.
# 1. Double click on the /content/ilab/config.json file to edit and specify the qna_location where your data resides within the Dewey Decimal classification system. Close and save the config.json file.
# 1. You can now specify to run with your own data by selecting **Your Content 1** or **Your Content 2** in the next code cell.

# %%
print("\nSelect the QNA dataset to add:")
display(data_set)
print("After choosing your dataset, please select and run the following cell")

# %%
# print("Step 2.2 Choose the Dataset for this Run")
# if data_set.value=='2024 Oscars':
#     use_case="oscars"
# elif data_set.value=='Quantum':
#     use_case="quantum"
# elif data_set.value=='Agentic AI':
#     use_case="agentic_ai"
# elif data_set.value=='Your Content 1':
#     use_case="your_content_1"
# elif data_set.value=='Your Content 2':
#     use_case="your_content_2"
# else:
#     use_case="undefined"
#     print("ERROR: Undefined data set: " + data_set.value + " data")

# use_case = "manly"
qna_file="taxonomy/knowledge/realstate/nsw/manly/qna.yaml"

# with open('config.json', 'r') as f:
#     jsonData = json.load(f)

# if use_case!="undefined":
#     qna_file="data/" + use_case + "/qna.yaml"
#     qna_location=jsonData["use_cases"][use_case]["qna_location"]
#     print("Using " + data_set.value + " data")

# %% [markdown]
# <a id="IL2_taxonomy"></a>
# ## Step 2.2 Create the Taxonomy Data Repository
# Delete the prior repository, clone the empty taxonomy repository and place the QNA file

# %%
#Delete the prior repository and clone the empty taxonomy repository
# print("Delete the prior repository and clone the empty taxonomy repository")
# shell_command1 = f"rm -rf taxonomy"
# taxonomy_repo=jsonData["taxonomy_repo"]
# shell_command2 = f"git clone {taxonomy_repo}"
# !{shell_command1}
# !{shell_command2}


#show the QNA file
print("Show the QNA file")
print_lines=40
with open(qna_file, 'r') as input_file:
    for line_number, line in enumerate(input_file):
        if line_number > print_lines:  # line_number starts at 0.
            break
        print(line, end="")

# Place the QNA file in the proper taxonomy directory
# print("Place QNA file in taxononmy as: /taxonomy/"+qna_location+"/qna.yaml")
# shell_command1 = f"mkdir -p ./taxonomy/{qna_location}"
# shell_command2 = f"cp ./{qna_file} ./taxonomy/{qna_location}/qna.yaml"
# !{shell_command1}
# !{shell_command2}

print("Verify the taxonomy")
# !ilab taxonomy diff
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Show the QNA file
# created_by: juliadenham
# version: 3
# domain: animals
# seed_examples:
#   - context: |
#       This property is located at 107/26 Whistler Street, Manly NSW 2095. Below is the information about this property:
#       Inspection times
#       Rates and fees
#       Property size
#       Price guide
#       Enquire0404 898 · · ·
#       Internal area
#       106m²
#       Auction $2,100,000
#       # 107/26 Whistler Street, Manly NSW 2095
#       2 Beds2 Baths1 Parking
#       Apartment / Unit / Flat
#       ## Property Description
#       ### As New Boutique Living in Heart of Manly
#       Set in as a new boutique development in the heart of cosmopolitan Manly, this apartment is a true lifestyle address. It has been designed with an emphasis on seamless open plan indoor/outdoor living and entertaining with only the finest finishes and inclusions. Step out to shops, cafes, restaurants and nightspots practically at your doorstep, stroll to Manly Beach for a swim, surf or sunbathe
#       Read more
#       Add notes
#       ## Domain Says
#       107/26 Whistler Street, Manly NSW 2095 was last sold in 2021 and 132 other 2 bedroom unit in Manly have recently been sold. There are currently 9 properties for sale in Manly.
#     questions_and_answers:
#       - question: |
#           What is the asking price?
#         answer: |
#           Vendor is asking for $2,100,000.
#       - question: |
#           What type of property is this?
#         answer: |
#           This is a unit in an apartment block.
#       - question: |
#           How many bedrooms this property has?
#         answer: |
#           This unit has two bedrooms
#   - context: |
#       This property is located at 5/17 Darley Road, Manly NSW 2095. Below is the information about this property:
#       Inspection times
#       Rates and fees
# Verify the taxonomy
# Reading taxonomy failed with the following error: /content/ilab-hello-world/taxonomy]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/instructlab/taxonomy/diff.py", line 73, in diff
#     taxonomy_files = get_taxonomy_diff(taxonomy_path, taxonomy_base)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/instructlab/utils.py", line 205, in get_taxonomy_diff
#     repo = git.Repo(repo_path)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/git/repo/base.py", line 289, in __init__
#     raise InvalidGitRepositoryError(epath)
# git.exc.InvalidGitRepositoryError: /content/ilab-hello-world/taxonomy

# %% [markdown]
# <a id="IL2_generate"></a>
# ## Step 2.3. Set data generation parameters
#
# #### Select pipeline
#
# InstructLab has three primary pipelines that can be used: simple, full and acellerated:
# - The **simple pipeline** runs fast and can be used for initial model and data testing.
# - The **full pipeline** runs all of the InstrctLab steps and takes more time but produces a better tuned model.
#
# **Note:** If you are running with a new or modifed dataset, you may want to use the **Simple pipeline** for the first run to verify the configuration
#
# #### Sepect number of samples to generate
#
# Data generation takes 19 minutes for generating 15 synthetic data samples. You may wish to generate a small number on your first run to verify the QNA dataset format.
#
# To produce **sufficient synthetic data** to focus training on the new material, **about 30 synthetic questions and answer pairs need to be generated** for each question and answer pair provided. This will require a proportionally longer time to generate, but will provide better training.
#
# Before following these instructions, ensure the existing model you are adding skills or knowledge to is still running. Alternatively, ilab data generate can start a server for you if you provide a fully qualified model path via --model.
#
# To generate a synthetic dataset based on your newly added knowledge or skill set in taxonomy repository, run the following command:
#
#     ilab data generate
#
# #### **Simple Pipeline**
#
# The Simple Pipeline works solely with Merlinite 7b Lab as the teacher model. The Simple Pipeline is called without GPU acceleration as follows:
#
#     ilab data generate --pipeline simple
#
# #### **Full Pipeline**
#
# The Full Pipeline runs the full processing with a GPU. Currently, the Full Pipeline only supports the Mixtral and Mistral Instruct Family models as the teacher model.  This is due to only supporting specific model prompt templates.
#
# Using a non-default model such as Mixtral-8x7B-Instruct-v0.1) to generate data with the Full Pipeline:
#
#     ilab data generate --model ~/.cache/instructlab/models/mistralai/mixtral-8x7b-instruct-v0.1 --pipeline full --gpus 4
#
# **Note** Synthetic Data Generation can take from 2 minutes to 1+ hours to complete, depending on your computing resources.

# %%
print("Select Pipeline to use")
display(sdg_pipe)
display(instr)
print("After making your selections for data generation, please select and run the following cell")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Select Pipeline to use
# ToggleButtons(description='Processing:', options=('Simple', 'Full with GPU'), style=ToggleButtonsStyle(button_…
# ToggleButtons(description='# of QNAs:', options=('Default (>450)', '>15', '>50', '>200', '>500', '>1000'), sty…
# After making your selections for data generation, please select and run the following cell

# %% [markdown]
# ### 2.4 Run data generation
# Data generation with a GPU can take 2 minutes or more to generate 15 synthetic data samples. It takes proportionately longer to generate more samples.

# %%
gen_directory = "data/"+ use_case+"/ilab_generated/"
if instr.value == "Default (>450)":
        sdg_factor=""
elif instr.value == '>15':
    sdg_factor="--sdg-scale-factor 1"
elif instr.value == '>50':
    sdg_factor="--sdg-scale-factor 3"
elif instr.value == '>200':
    sdg_factor="--sdg-scale-factor 13"
elif instr.value == '>500':
    sdg_factor="--sdg-scale-factor 33"
else:
    sdg_factor="--sdg-scale-factor 67"
# 'Fast (Simple)', 'Full with CPU'
if sdg_pipe.value == 'Simple':
    pipeline = 'simple'
    model = '--model models/instructlab/granite-7b-lab'
    gpus = '--gpus 1'
elif sdg_pipe.value == 'Full with GPU':
    pipeline = 'full'
    model = ''
#   model = '--model models/instructlab/granite-7b-lab'
    gpus = '--gpus 1'
else:
    print("ERROR: Undefined pipeline")

il_data_path= '/root/.local/share/instructlab/datasets/'
#Remove old data so there is only one test_merlinite and train_merlinite after generation
print("Remove old datasets")
# !rm -rf {il_data_path}*
#shell_command = f"ilab --verbose data generate {model} --num-cpus 10 {gpus} {sdg_factor} --taxonomy-path taxonomy --pipeline {pipeline} --max-num-tokens 512"
shell_command = f"ilab data generate {model} --num-cpus 10 {gpus} {sdg_factor} --taxonomy-path taxonomy --pipeline {pipeline} --max-num-tokens 512"

print("Generating data")
print("Running: !"+shell_command)
# !{shell_command}

#Rename results to  test_gen.jsonl and train_gen.jsonl and move to local data directory
if not os.path.exists(gen_directory):
    print("Create directory: " + gen_directory)
    # !mkdir {gen_directory}
file_cnt=0
try:
    for dirname in os.listdir(il_data_path):
        date_path=il_data_path+'/'+ dirname + '/'
        for filename in os.listdir(date_path):
            if filename[:6]=='train_':
                train_name= 'train_gen.jsonl'
                print('Renaming '+ filename+ ' to ' + train_name)
                # !mv {date_path+filename} {gen_directory+train_name}
                file_cnt+=1
            elif filename[:5]=='test_':
                test_name= 'test_gen.jsonl'
                print('Renaming '+ filename+ ' to ' + test_name)
                # !mv {date_path+filename} {gen_directory+test_name}
                file_cnt+=1
    if file_cnt < 2:
        print("ERROR: train_gen.jsonl and/or test.jsonl not created")
    elif os.path.getsize(gen_directory+train_name) == 0:
        print("ERROR: train_gen.jsonl file is empty")
    elif os.path.getsize(gen_directory+test_name) == 0:
        print("ERROR: test_gen.jsonl file is empty")
    else:
        print("Training and test files successfully created in: " + gen_directory)
except:
    print("Error running ilab generate, no synthetic data generated")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Remove old datasets
# Generating data
# Running: !ilab data generate --model models/instructlab/granite-7b-lab --num-cpus 10 --gpus 1  --taxonomy-path taxonomy --pipeline simple --max-num-tokens 512
# INFO 2025-06-03 04:35:30,449 instructlab.process.process:300: Started subprocess with PID 13672. Logs are being written to /root/.local/share/instructlab/logs/generation/generation-2e1b2954-4034-11f0-a3d4-0242ac1c000c.log.
# INFO 2025-06-03 04:35:33,099 instructlab.model.backends.vllm:115: Trying to connect to model server at http://127.0.0.1:8000/v1
# INFO 2025-06-03 04:35:34,927 instructlab.model.backends.vllm:332: vLLM starting up on pid 13713 at http://127.0.0.1:56065/v1
# INFO 2025-06-03 04:35:34,927 instructlab.model.backends.vllm:123: Starting a temporary vLLM server at http://127.0.0.1:56065/v1
# INFO 2025-06-03 04:35:34,927 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 1/120
# INFO 2025-06-03 04:35:38,402 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 2/120
# INFO 2025-06-03 04:35:41,822 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 3/120
# INFO 2025-06-03 04:35:45,046 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 4/120
# INFO 2025-06-03 04:35:48,270 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 5/120
# INFO 2025-06-03 04:35:51,511 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 6/120
# INFO 2025-06-03 04:35:54,748 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 7/120
# INFO 2025-06-03 04:35:57,951 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 8/120
# INFO 2025-06-03 04:36:01,302 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 9/120
# INFO 2025-06-03 04:36:04,764 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 10/120
# INFO 2025-06-03 04:36:08,223 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 11/120
# INFO 2025-06-03 04:36:11,598 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 12/120
# INFO 2025-06-03 04:36:14,964 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 13/120
# INFO 2025-06-03 04:36:18,274 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 14/120
# INFO 2025-06-03 04:36:21,752 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 15/120
# INFO 2025-06-03 04:36:25,067 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 16/120
# INFO 2025-06-03 04:36:28,474 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 17/120
# INFO 2025-06-03 04:36:31,782 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 18/120
# INFO 2025-06-03 04:36:35,185 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 19/120
# INFO 2025-06-03 04:36:38,589 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 20/120
# INFO 2025-06-03 04:36:41,782 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 21/120
# INFO 2025-06-03 04:36:45,204 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 22/120
# INFO 2025-06-03 04:36:48,486 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 23/120
# INFO 2025-06-03 04:36:51,780 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 24/120
# INFO 2025-06-03 04:36:55,088 instructlab.model.backends.vllm:138: Waiting for the vLLM server to start at http://127.0.0.1:56065/v1, this might take a moment... Attempt: 25/120
# INFO 2025-06-03 04:36:55,093 instructlab.model.backends.vllm:145: vLLM engine successfully started at http://127.0.0.1:56065/v1
# INFO 2025-06-03 04:36:55,748 datasets:54: PyTorch version 2.5.1 available.
# INFO 2025-06-03 04:36:55,749 datasets:66: Polars version 1.21.0 available.
# INFO 2025-06-03 04:36:55,749 datasets:77: Duckdb version 1.2.2 available.
# INFO 2025-06-03 04:36:55,750 datasets:112: TensorFlow version 2.18.0 available.
# INFO 2025-06-03 04:36:55,751 datasets:125: JAX version 0.5.2 available.
# INFO 2025-06-03 04:36:56,270 instructlab:206: Generating synthetic data using 'simple' pipeline, 'models/instructlab/granite-7b-lab' model, 'taxonomy' taxonomy, against http://127.0.0.1:56065/v1 server
# INFO 2025-06-03 04:36:56,270 root:356: Converting taxonomy to samples
# INFO 2025-06-03 04:36:57,417 instructlab.sdg.utils.taxonomy:143: Processing files...
# INFO 2025-06-03 04:36:57,417 instructlab.sdg.utils.taxonomy:148: Pattern 'oscars2024_results.md' matched 1 files.
# INFO 2025-06-03 04:36:57,417 instructlab.sdg.utils.taxonomy:152: Processing file: /root/.local/share/instructlab/datasets/2025-06-03_043530/preprocessed_2025-06-03T04_36_56/documents/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film_m66c1bg0/oscars2024_results.md
# INFO 2025-06-03 04:36:57,417 instructlab.sdg.utils.taxonomy:156: Added file path: /root/.local/share/instructlab/datasets/2025-06-03_043530/preprocessed_2025-06-03T04_36_56/documents/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film_m66c1bg0/oscars2024_results.md
# 2025-06-03 04:37:00.032125: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-03 04:37:00.048421: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748925420.069177   13672 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748925420.075471   13672 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-03 04:37:00.095679: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO 2025-06-03 04:37:03,655 instructlab.sdg.utils.chunkers:141: Docling models not found on disk, downloading models...
# INFO 2025-06-03 04:37:03,655 docling.utils.model_downloader:45: Downloading layout model...
# INFO 2025-06-03 04:37:10,757 docling.utils.model_downloader:53: Downloading tableformer model...
# INFO 2025-06-03 04:37:14,800 docling.utils.model_downloader:61: Downloading picture classifier model...
# INFO 2025-06-03 04:37:16,892 docling.utils.model_downloader:69: Downloading code formula model...
# INFO 2025-06-03 04:37:28,310 docling.utils.model_downloader:114: Downloading easyocr models...
# WARNING 2025-06-03 04:37:32,986 instructlab.sdg.utils.chunkers:60: Tesseract not found, falling back to EasyOCR.
# INFO 2025-06-03 04:37:32,987 docling.utils.accelerator_utils:67: Accelerator device: 'cpu'
# WARNING 2025-06-03 04:37:32,989 easyocr.easyocr:251: Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# INFO 2025-06-03 04:37:35,303 easyocr.easyocr:255: Download complete
# WARNING 2025-06-03 04:37:35,303 easyocr.easyocr:176: Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# INFO 2025-06-03 04:37:36,832 easyocr.easyocr:180: Download complete.
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama_fast.LlamaTokenizerFast'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565 - if you loaded a llama tokenizer from a GGUF file you can ignore this message.
# INFO 2025-06-03 04:37:39,392 instructlab.sdg.utils.chunkers:249: Successfully loaded tokenizer from: models/instructlab/granite-7b-lab
# INFO 2025-06-03 04:37:39,811 docling.document_converter:271: Going to convert document batch...
# INFO 2025-06-03 04:37:39,812 docling.document_converter:306: Initializing pipeline for SimplePipeline with options hash 4cc01982ae99b46a2a63fcda46c47c35
# INFO 2025-06-03 04:37:39,812 docling.pipeline.base_pipeline:39: Processing document oscars2024_results.md
# INFO 2025-06-03 04:37:53,920 docling.document_converter:286: Finished converting document oscars2024_results.md in 14.11 sec.
# INFO 2025-06-03 04:37:54,629 instructlab.sdg.generate_data:405: Taxonomy converted to samples and written to /root/.local/share/instructlab/datasets/2025-06-03_043530/preprocessed_2025-06-03T04_36_56
# INFO 2025-06-03 04:37:54,634 instructlab.sdg.generate_data:441: Synthesizing new instructions. If you aren't satisfied with the generated instructions, interrupt training (Ctrl-C) and try adjusting your YAML files. Adding more examples may help.
# INFO 2025-06-03 04:37:55,404 instructlab.sdg.checkpointing:59: No existing checkpoints found in /root/.local/share/instructlab/datasets/checkpoints/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film, generating from scratch
# INFO 2025-06-03 04:37:55,404 instructlab.sdg.pipeline:161: Running pipeline with multi-threaded batching. Using 10 workers for batches of size 8
# INFO 2025-06-03 04:37:55,535 instructlab.sdg.blocks.llmblock:56: LLM server supports batched inputs: True
# INFO 2025-06-03 04:37:55,536 instructlab.sdg.pipeline:199: Running block: gen_knowledge
# INFO 2025-06-03 04:37:55,537 instructlab.sdg.blocks.llmblock:56: LLM server supports batched inputs: True
# INFO 2025-06-03 04:37:55,537 instructlab.sdg.pipeline:199: Running block: gen_knowledge
# INFO 2025-06-03 04:37:55,539 instructlab.sdg.blocks.llmblock:56: LLM server supports batched inputs: True
# INFO 2025-06-03 04:37:55,541 instructlab.sdg.pipeline:199: Running block: gen_knowledge
# INFO 2025-06-03 04:37:55,547 instructlab.sdg.blocks.llmblock:56: LLM server supports batched inputs: True
# INFO 2025-06-03 04:37:55,547 instructlab.sdg.pipeline:199: Running block: gen_knowledge
# INFO 2025-06-03 04:37:55,551 instructlab.sdg.blocks.llmblock:56: LLM server supports batched inputs: True
# INFO 2025-06-03 04:37:55,551 instructlab.sdg.pipeline:199: Running block: gen_knowledge
# INFO 2025-06-03 04:37:55,552 instructlab.sdg.blocks.llmblock:56: LLM server supports batched inputs: True
# INFO 2025-06-03 04:37:55,556 instructlab.sdg.blocks.llmblock:56: LLM server supports batched inputs: True
# INFO 2025-06-03 04:37:55,556 instructlab.sdg.pipeline:199: Running block: gen_knowledge
# INFO 2025-06-03 04:37:55,556 instructlab.sdg.pipeline:199: Running block: gen_knowledge
# INFO 2025-06-03 04:37:55,562 instructlab.sdg.blocks.llmblock:56: LLM server supports batched inputs: True
# INFO 2025-06-03 04:37:55,577 instructlab.sdg.pipeline:199: Running block: gen_knowledge
# INFO 2025-06-03 04:37:55,586 instructlab.sdg.blocks.llmblock:56: LLM server supports batched inputs: True
# INFO 2025-06-03 04:37:55,586 instructlab.sdg.pipeline:199: Running block: gen_knowledge
# INFO 2025-06-03 04:37:55,588 instructlab.sdg.blocks.llmblock:56: LLM server supports batched inputs: True
# INFO 2025-06-03 04:37:55,588 instructlab.sdg.pipeline:199: Running block: gen_knowledge
# INFO 2025-06-03 04:38:41,688 instructlab.sdg.checkpointing:44: Saving checkpoint to /root/.local/share/instructlab/datasets/checkpoints/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film/data_checkpoint_a19eb5e681d9456696dbe8aea6445fe8.jsonl
# INFO 2025-06-03 04:38:41,693 instructlab.sdg.pipeline:199: Running block: gen_knowledge
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 125.15ba/s]
# INFO 2025-06-03 04:39:22,798 instructlab.sdg.pipeline:199: Running block: gen_knowledge
# INFO 2025-06-03 04:39:55,261 instructlab.sdg.pipeline:199: Running block: gen_knowledge
# INFO 2025-06-03 04:40:23,150 instructlab.sdg.pipeline:199: Running block: gen_knowledge
# INFO 2025-06-03 04:41:01,226 instructlab.sdg.pipeline:199: Running block: gen_knowledge
# INFO 2025-06-03 04:41:37,510 instructlab.sdg.pipeline:199: Running block: gen_knowledge
# INFO 2025-06-03 04:42:01,550 instructlab.sdg.pipeline:199: Running block: gen_knowledge
# INFO 2025-06-03 04:43:17,377 instructlab.sdg.checkpointing:44: Saving checkpoint to /root/.local/share/instructlab/datasets/checkpoints/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film/data_checkpoint_f2ced096a44644c787067984fed57822.jsonl
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 135.41ba/s]
# INFO 2025-06-03 04:43:17,389 instructlab.sdg.checkpointing:44: Saving checkpoint to /root/.local/share/instructlab/datasets/checkpoints/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film/data_checkpoint_49926d4703a6411f81b4a90be1f99311.jsonl
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 113.30ba/s]
# INFO 2025-06-03 04:43:17,401 instructlab.sdg.checkpointing:44: Saving checkpoint to /root/.local/share/instructlab/datasets/checkpoints/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film/data_checkpoint_8e3b6c4a764245d3870eebf280dbb278.jsonl
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 133.62ba/s]
# INFO 2025-06-03 04:43:17,413 instructlab.sdg.checkpointing:44: Saving checkpoint to /root/.local/share/instructlab/datasets/checkpoints/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film/data_checkpoint_a325a2ed72dc454f84ecf7ed4144038e.jsonl
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 144.77ba/s]
# INFO 2025-06-03 04:43:17,423 instructlab.sdg.checkpointing:44: Saving checkpoint to /root/.local/share/instructlab/datasets/checkpoints/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film/data_checkpoint_89bea15200aa4d5db2189ddda643b6e9.jsonl
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 155.25ba/s]
# INFO 2025-06-03 04:43:17,433 instructlab.sdg.checkpointing:44: Saving checkpoint to /root/.local/share/instructlab/datasets/checkpoints/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film/data_checkpoint_a4efc5d1c8d84d158819a16f9cdbfe91.jsonl
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 186.02ba/s]
# INFO 2025-06-03 04:43:17,442 instructlab.sdg.checkpointing:44: Saving checkpoint to /root/.local/share/instructlab/datasets/checkpoints/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film/data_checkpoint_9700d656177647f594d78175cdbb4c30.jsonl
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 134.03ba/s]
# INFO 2025-06-03 04:43:17,453 instructlab.sdg.checkpointing:44: Saving checkpoint to /root/.local/share/instructlab/datasets/checkpoints/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film/data_checkpoint_2bc478c4b7414338a5ca6fd0817311cf.jsonl
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 149.28ba/s]
# INFO 2025-06-03 04:43:48,921 instructlab.sdg.checkpointing:44: Saving checkpoint to /root/.local/share/instructlab/datasets/checkpoints/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film/data_checkpoint_6bdd109488674874b4f1af5c83381ffe.jsonl
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 136.80ba/s]
# INFO 2025-06-03 04:44:26,602 instructlab.sdg.checkpointing:44: Saving checkpoint to /root/.local/share/instructlab/datasets/checkpoints/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film/data_checkpoint_a2627887a4734240b14d7d4af673bd17.jsonl
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 142.29ba/s]
# INFO 2025-06-03 04:44:55,358 instructlab.sdg.checkpointing:44: Saving checkpoint to /root/.local/share/instructlab/datasets/checkpoints/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film/data_checkpoint_8af07e53c53c4a5e9d008a0b206c17c4.jsonl
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 154.33ba/s]
# INFO 2025-06-03 04:45:37,073 instructlab.sdg.checkpointing:44: Saving checkpoint to /root/.local/share/instructlab/datasets/checkpoints/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film/data_checkpoint_d1278c8817cf4beca7a5d6b3da95160b.jsonl
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 119.63ba/s]
# INFO 2025-06-03 04:46:08,776 instructlab.sdg.checkpointing:44: Saving checkpoint to /root/.local/share/instructlab/datasets/checkpoints/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film/data_checkpoint_8713fd5200d84df086e40fa5237482ec.jsonl
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 153.59ba/s]
# INFO 2025-06-03 04:46:38,639 instructlab.sdg.checkpointing:44: Saving checkpoint to /root/.local/share/instructlab/datasets/checkpoints/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film/data_checkpoint_4175ef826b554daeb1d47da53e95834b.jsonl
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 138.17ba/s]
# INFO 2025-06-03 04:47:32,005 instructlab.sdg.checkpointing:44: Saving checkpoint to /root/.local/share/instructlab/datasets/checkpoints/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film/data_checkpoint_26659a97d1c2400bacffc0f5150d5a79.jsonl
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 148.20ba/s]
# INFO 2025-06-03 04:47:35,677 instructlab.sdg.checkpointing:44: Saving checkpoint to /root/.local/share/instructlab/datasets/checkpoints/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film/data_checkpoint_58a4ff6e9c544ec7b8540bb9ea2c566f.jsonl
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 171.62ba/s]
# INFO 2025-06-03 04:47:36,398 instructlab.sdg.generate_data:478: Generated 3341 samples
# INFO 2025-06-03 04:47:36,418 instructlab.sdg.pipeline:161: Running pipeline with multi-threaded batching. Using 10 workers for batches of size 8
# INFO 2025-06-03 04:47:36,448 instructlab.sdg.pipeline:199: Running block: gen_mmlu_knowledge
# INFO 2025-06-03 04:47:36,451 instructlab.sdg.pipeline:199: Running block: gen_mmlu_knowledge
# INFO 2025-06-03 04:47:36,455 instructlab.sdg.pipeline:199: Running block: gen_mmlu_knowledge
# INFO 2025-06-03 04:47:36,461 instructlab.sdg.pipeline:199: Running block: gen_mmlu_knowledge
# INFO 2025-06-03 04:47:36,469 instructlab.sdg.pipeline:199: Running block: gen_mmlu_knowledge
# INFO 2025-06-03 04:47:36,485 instructlab.sdg.pipeline:199: Running block: gen_mmlu_knowledge
# INFO 2025-06-03 04:47:36,488 instructlab.sdg.pipeline:199: Running block: gen_mmlu_knowledge
# INFO 2025-06-03 04:47:36,491 instructlab.sdg.pipeline:199: Running block: gen_mmlu_knowledge
# INFO 2025-06-03 04:47:36,499 instructlab.sdg.pipeline:199: Running block: gen_mmlu_knowledge
# INFO 2025-06-03 04:47:36,509 instructlab.sdg.pipeline:199: Running block: gen_mmlu_knowledge
# INFO 2025-06-03 04:47:45,800 instructlab.sdg.pipeline:199: Running block: gen_mmlu_knowledge
# INFO 2025-06-03 04:47:49,800 instructlab.sdg.pipeline:199: Running block: gen_mmlu_knowledge
# INFO 2025-06-03 04:47:51,434 instructlab.sdg.pipeline:199: Running block: gen_mmlu_knowledge
# INFO 2025-06-03 04:47:52,681 instructlab.sdg.pipeline:199: Running block: gen_mmlu_knowledge
# INFO 2025-06-03 04:47:53,603 instructlab.sdg.pipeline:199: Running block: gen_mmlu_knowledge
# INFO 2025-06-03 04:47:55,800 instructlab.sdg.pipeline:199: Running block: gen_mmlu_knowledge
# INFO 2025-06-03 04:47:57,820 instructlab.sdg.pipeline:199: Running block: gen_mmlu_knowledge
# Filter: 100%|##########| 106/106 [00:00<00:00, 4650.83 examples/s]
# Filter: 100%|##########| 86/86 [00:00<00:00, 5670.47 examples/s]
# Flattening the indices: 100%|##########| 86/86 [00:00<00:00, 14537.14 examples/s]
# Map: 100%|##########| 86/86 [00:00<00:00, 5459.93 examples/s]
# Map: 100%|##########| 86/86 [00:00<00:00, 5253.11 examples/s]
# Map: 100%|##########| 86/86 [00:00<00:00, 5307.53 examples/s]
# Filter: 100%|##########| 86/86 [00:00<00:00, 16880.86 examples/s]
# Filter: 100%|##########| 86/86 [00:00<00:00, 11161.28 examples/s]
# Filter: 100%|##########| 77/77 [00:00<00:00, 11030.86 examples/s]
# Flattening the indices: 100%|##########| 77/77 [00:00<00:00, 11460.25 examples/s]
# Casting to class labels: 100%|##########| 77/77 [00:00<00:00, 5468.82 examples/s]
# INFO 2025-06-03 04:48:11,012 instructlab.sdg.eval_data:126: Saving MMLU Dataset /root/.local/share/instructlab/datasets/2025-06-03_043530/node_datasets_2025-06-03T04_36_56/mmlubench_knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film.jsonl
# Creating json from Arrow format: 100%|##########| 1/1 [00:00<00:00, 229.96ba/s]
# INFO 2025-06-03 04:48:11,017 instructlab.sdg.eval_data:130: Saving MMLU Task yaml /root/.local/share/instructlab/datasets/2025-06-03_043530/node_datasets_2025-06-03T04_36_56/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film_task.yaml
# Map:  24%|##3       | 791/3341 [00:00<00:00, 7836.06 examples/s]WARNING 2025-06-03 04:48:11,379 instructlab.sdg.datamixing:258: Failed to split generated q&a: The 96th Academy Awards were announced to take place at 4:00 p.m. PT (7:00 p.m. ET) on March 12, 2024.
# WARNING 2025-06-03 04:48:11,379 instructlab.sdg.datamixing:274: Failed to split generated q&a: The 96th Academy Awards were announced to take place at 4:00 p.m. PT (7:00 p.m. ET) on March 12, 2024.
# Map: 100%|##########| 3341/3341 [00:00<00:00, 7221.20 examples/s]
# Map: 100%|##########| 3341/3341 [00:00<00:00, 25376.11 examples/s]
# Creating json from Arrow format: 100%|##########| 4/4 [00:00<00:00, 50.31ba/s]
# Map:  24%|##3       | 797/3341 [00:00<00:00, 7905.49 examples/s]WARNING 2025-06-03 04:48:12,061 instructlab.sdg.datamixing:258: Failed to split generated q&a: The 96th Academy Awards were announced to take place at 4:00 p.m. PT (7:00 p.m. ET) on March 12, 2024.
# WARNING 2025-06-03 04:48:12,061 instructlab.sdg.datamixing:274: Failed to split generated q&a: The 96th Academy Awards were announced to take place at 4:00 p.m. PT (7:00 p.m. ET) on March 12, 2024.
# Map: 100%|##########| 3341/3341 [00:00<00:00, 7303.37 examples/s]
# Map: 100%|##########| 3341/3341 [00:00<00:00, 5873.39 examples/s]
# Map:  24%|##4       | 805/3341 [00:00<00:00, 7987.54 examples/s]WARNING 2025-06-03 04:48:13,095 instructlab.sdg.datamixing:258: Failed to split generated q&a: The 96th Academy Awards were announced to take place at 4:00 p.m. PT (7:00 p.m. ET) on March 12, 2024.
# WARNING 2025-06-03 04:48:13,095 instructlab.sdg.datamixing:274: Failed to split generated q&a: The 96th Academy Awards were announced to take place at 4:00 p.m. PT (7:00 p.m. ET) on March 12, 2024.
# Map: 100%|##########| 3341/3341 [00:00<00:00, 7480.95 examples/s]
# Map: 100%|##########| 3341/3341 [00:00<00:00, 26954.93 examples/s]
# Creating json from Arrow format: 100%|##########| 7/7 [00:00<00:00, 25.68ba/s]
# WARNING 2025-06-03 04:48:13,928 instructlab.sdg.datamixing:258: Failed to split generated q&a: The 96th Academy Awards were announced to take place at 4:00 p.m. PT (7:00 p.m. ET) on March 12, 2024.
# WARNING 2025-06-03 04:48:13,928 instructlab.sdg.datamixing:274: Failed to split generated q&a: The 96th Academy Awards were announced to take place at 4:00 p.m. PT (7:00 p.m. ET) on March 12, 2024.
# INFO 2025-06-03 04:48:14,314 instructlab.sdg.datamixing:158: Loading dataset from /root/.local/share/instructlab/datasets/2025-06-03_043530/node_datasets_2025-06-03T04_36_56/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film_p10.jsonl ...
# Generating train split: 6682 examples [00:00, 103128.25 examples/s]
# INFO 2025-06-03 04:48:15,166 instructlab.sdg.datamixing:160: Dataset columns: ['messages', 'metadata', 'id', 'unmask']
# INFO 2025-06-03 04:48:15,166 instructlab.sdg.datamixing:161: Dataset loaded with 6682 samples
# Map (num_proc=8): 100%|##########| 6682/6682 [00:00<00:00, 21202.39 examples/s]
# Map (num_proc=8): 100%|##########| 6682/6682 [00:00<00:00, 20207.93 examples/s]
# Creating json from Arrow format: 100%|##########| 7/7 [00:00<00:00, 21.99ba/s]
# INFO 2025-06-03 04:48:16,627 instructlab.sdg.datamixing:235: Mixed Dataset saved to /root/.local/share/instructlab/datasets/2025-06-03_043530/skills_train_msgs_2025-06-03T04_36_56.jsonl
# INFO 2025-06-03 04:48:16,629 instructlab.sdg.datamixing:158: Loading dataset from /root/.local/share/instructlab/datasets/2025-06-03_043530/node_datasets_2025-06-03T04_36_56/knowledge_arts_recreational_and_performing_arts_public_performances_film_radio_and_television_film_p07.jsonl ...
# Generating train split: 3341 examples [00:00, 142472.52 examples/s]
# INFO 2025-06-03 04:48:16,884 instructlab.sdg.datamixing:160: Dataset columns: ['messages', 'metadata', 'id', 'unmask']
# INFO 2025-06-03 04:48:16,884 instructlab.sdg.datamixing:161: Dataset loaded with 3341 samples
# Map (num_proc=8): 100%|##########| 3341/3341 [00:00<00:00, 13719.99 examples/s]
# Map (num_proc=8): 100%|##########| 3341/3341 [00:00<00:00, 13742.32 examples/s]
# Creating json from Arrow format: 100%|##########| 4/4 [00:00<00:00, 40.25ba/s]
# INFO 2025-06-03 04:48:17,947 instructlab.sdg.datamixing:235: Mixed Dataset saved to /root/.local/share/instructlab/datasets/2025-06-03_043530/knowledge_train_msgs_2025-06-03T04_36_56.jsonl
# INFO 2025-06-03 04:48:17,948 instructlab.sdg.generate_data:757: Generation took 681.68s
# INFO 2025-06-03 04:48:21,320 instructlab.model.backends.vllm:512: Waiting for GPU VRAM reclamation...
# ᕦ(òᴗóˇ)ᕤ Data generate completed successfully! ᕦ(òᴗóˇ)ᕤ
# Create directory: data/oscars/ilab_generated/
# Renaming test_2025-06-03T04_36_56.jsonl to test_gen.jsonl
# Renaming train_2025-06-03T04_36_56.jsonl to train_gen.jsonl
# Training and test files successfully created in: data/oscars/ilab_generated/

# %% [markdown]
# ### 2.5 Show examples of generated data

# %%
print("2.4.3 Show examples of generated data")
for filename in os.listdir(gen_directory):
    if filename[:9]=='train_gen':
        with open(gen_directory+filename, 'r') as syn_file:
            cnt=0
            for line_number, line in enumerate(syn_file):
                if cnt >= 8:
                    break
                jsonLine= json.loads(line)
                syn_user=jsonLine["user"]
                syn_assist=jsonLine["assistant"]
                #Remove "Answer:" and "Response:" from answers for displaying
                if syn_user[:10]=="Question: ":
                    syn_user=syn_user[10:]
                if syn_assist[:8]=="Answer: ":
                    syn_assist=syn_assist[8:]
                cnt+=1
                print("\nQuestion: "+syn_user+"\nAnswer: "+syn_assist)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 2.4.3 Show examples of generated data
#
# Question: In which cities did the 2024 Oscars take place?
# Answer: The 2024 Oscars were held in Hollywood, Los Angeles, at the Dolby Theatre.
#
# Question: Who hosted the 96th Academy Awards ceremony in 2024?
# Answer: Jimmy Kimmel hosted the 96th Academy Awards ceremony.
#
# Question: In which year did the 96th Academy Awards ceremony take place?
# Answer: The 96th Academy Awards ceremony was held on March 10, 2024.
#
# Question: Who hosted the 2024 Academy Awards ceremony?
# Answer: Jimmy Kimmel hosted the 96th Academy Awards ceremony.
#
# Question: Who hosted the 96th Academy Awards ceremony?
# Answer: Jimmy Kimmel hosted the 96th Academy Awards ceremony.
#
# Question: Who hosted the 2024 Academy Awards ceremony?
# Answer: Jimmy Kimmel hosted the 96th Academy Awards ceremony.
#
# Question: In which categories did Oppenheimer and Barbie receive nominations for the 96th Academy Awards?
# Answer: Oppenheimer received nominations in 11 categories, including Best Picture, Best Director, and Best Adapted Screenplay. Barbie received nominations in 8 categories, including Best Picture and Best Costume Design.
#
# Question: In which year did the 96th Academy Awards ceremony take place, and who hosted the event?
# Answer: The 96th Academy Awards ceremony was held on March 10, 2024, and it was presented by the Academy of Motion Picture Arts and Sciences (AMPAS), and hosted by comedian Jimmy Kimmel for the fourth time.

# %% [markdown]
# ## Section 3. Training with InstructLab
#
# ### 3.1 Select the model training pipeline
#
# InstructLab has three primary model training pipelines: simple, full (default), and accelerated. For all of the models, the training time can be limited by adjusting the num_epoch paramater. The maximum number of epochs for running the InstructLab end-to-end workflow is 10.
#
# #### **Simple pipeline**
#
# The simple pipeline uses an SFT Trainer on Linux and MLX on MacOS. This type of training takes roughly an hour and produces the lowest fidelity model but should indicate if your data is being picked up by the training process. The simple pipeline only works with Merlinite 7b Lab as the teacher model. For this Linux system, the trained model is saved in the models directory as ggml-model-f16.gguf.
#
# The command form is:
#
#     ilab model train --pipeline simple
#
# **Note:** This process will take a little while to complete (time can vary based on hardware and output of ilab data generate but on the order of 5 to 15 minutes)
#
# #### **Accelerated pipeline**
#
# The accelerated uses the instructlab-training library which supports GPU accelerated and distributed training. The full loop and data processing functions are either pulled directly from or based off of the work in this library. For the accelerated pipeline, the models are saved in the ~/.local/share/instructlab/checkpoints directory. The instructlab command "ilab model evaluate" can be used to choose the best one. Training is support for GPU acceleration with Nvidia CUDA or AMD ROCm. Please see the GPU acceleration documentation for more details. At present, hardware acceleration requires a data center GPU or high-end consumer GPU with at least 18 GB free memory.
#
# The command form is:
#
#     ilab model train --pipeline accelerated --device cuda --data-path <path-to-sdg-data>

# %%
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
torch.cuda.empty_cache()
print("Select to Continue or to Train the model")
display(train_pipe)
display(epoch)
display(it)
print("After choosing your training options, please select and run the following cell")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Select to Continue or to Train the model
# ToggleButtons(description='Processing', options=('Simple with GPU', 'Accelerated GPU'), style=ToggleButtonsSty…
# ToggleButtons(description='Epochs:', index=2, options=('1', '2', '3', '4', '5', '10', '15'), style=ToggleButto…
# ToggleButtons(description='Iterations:', index=2, options=('1', '3', '5', '10', '20', '50', '100', '200'), sty…
# After choosing your training options, please select and run the following cell

# %% [markdown]
# ### 3.2 Run the model training
#
# Model training can take 30 minutes or more for 1 epoch and 1 iteration and takes 1 hour for the default paramter values. This minimal training could be used for testing the generation and training for a new set of data.
#
# To produce a higher quality model, more epochs and iterations are needed for refining the model. This will require a proportionally longer time to train the model.

# %%
data_path="data/"+ use_case+"/ilab_generated/"
train_data=data_path+"train_gen.jsonl"
model_path="models/instructlab/granite-7b-lab"
##model_path='/root/.cache/instructlab/models/instructlab/granite-7b-lab'
trained_model_path="data/"+ use_case+"/new_model/"

##'Simple (Fast)', 'Accelerated GPU'
file_cnt=0
for filename in os.listdir(data_path):
    if filename[:15]=='train_gen.jsonl': file_cnt+=1
    elif filename[:14]=='test_gen.jsonl': file_cnt+=1
if file_cnt < 2 or os.path.getsize(gen_directory+train_name) < 5 or os.path.getsize(gen_directory+test_name) < 5:
    print("ERROR: train_gen.jsonl and/or test.jsonl are not present or too small")

if not os.path.exists(trained_model_path):
    print("Create directory: " + trained_model_path)
    # !mkdir {trained_model_path}
ep=int(epoch.value)
its=int(it.value)
if train_pipe.value=='Simple with GPU':
    print("Train with simple pipeline with a GPU")
    shell_command = f"ilab model train --pipeline simple --device cuda --model-path {model_path} --data-path {data_path} --num-epochs {ep} --iters {its}"
elif train_pipe.value=='Accelerated GPU':
    print("Train accelerated with a GPU")
    #shell_command = f"ilab model train --pipeline accelerated --device cuda --model-path {model_path} --data-path {train_data} --num-epochs {ep} --iters {its}"
    shell_command = f"ilab -v -v model train --pipeline accelerated --device cuda --model-path {'/content/ilab/'+model_path} --data-path {'/content/ilab/'+train_data}"

print("Running: !"+shell_command)
# !{shell_command}
if train_pipe.value=='Accelerated GPU':
    print("Run ilab model evaluate")
    # !ilab model evaluate --benchmark mmlu
#Move the model to the use_case/new_model directory
print("Moving the trained model to the directory: "+trained_model_path)
# !mv /root/.local/share/instructlab/checkpoints/ggml-model-f16.gguf {trained_model_path}
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Streaming output truncated to the last 5000 lines.
#       Nominees
#           Sterling K. Brown – American Fiction as Clifford "Cliff" Ellison
#           Robert De Niro – Killers of the Flower Moon as William King Hale
#           Ryan Gosling – Barbie as Ken
#           Mark Ruffalo – Poor Things as Duncan Wedderburn
#   Best Supporting Actress
#       Winner
#           Da'Vine Joy Randolph – The Holdovers as Mary Lamb ‡
#       Nominees
#           Emily Blunt – Oppenheimer as Kitty Oppenheimer
#           Danielle Brooks – The Color Purple as Sofia
#           America Ferrera – Barbie as Gloria
#           Jodie Foster – Nyad as Bonnie Stoll
#
# ===
# assistant_old
# ===
#
# At the 2024 Oscars, the nominees for best director were:
#
#     Christopher Nolan - "Oppenheimer"
#     Justine Triet - "Anatomy of a Fall"
#     Martin Scorsese - "Killers of the Flower Moon"
#     Yorgos Lanthimos - "Poor Things"
#     Jonathan Glazer - "The Zone of Interest"
#
#     And the winner was Christopher Nolan for "Oppenheimer".
#
# This information is based on the 2024 Oscar nominees and winners, which I have simulated as a helpful, clear, and accurate AI assistant.
#
# ===
# assistant_new
# ===
#
# Winners and Nominees for the 2024 Oscars:
#
# Best Picture:
# - Winner: Oppenheimer
# - Nominees: American Fiction, Anatomy of a Fall, Barbie, The Holdovers, Killers of the Flower Moon, Maestro, Past Lives, Poor Things, and The Zone of Interest
#
# Best Director:
# - Winner: Christopher Nolan – Oppenheimer
# - Nominees: Justine Triet – Anatomy of a Fall, Martin Scorsese – Killers of the Flower Moon, Yorgos Lanthimos – Poor Things, and Jonathan Glazer – The Zone of Interest
#
# Best Actor:
# - Winner: Cillian Murphy – Oppenheimer as J. Robert Oppenheimer
# - Nominees: Bradley Cooper – Maestro as Leonard Bernstein, Colman Domingo – Rustin as Bayard Rustin, Paul Giamatti – The Holdovers as Paul Hunham, Jeffrey Wright – American Fiction as Thelonious "Monk" Ellison
#
# Best Actress:
# - Winner: Emma Stone – Poor Things
#
# ===
# assistant_expected
# ===
#
# The nominees for director at the 2024 Oscars was Christopher Nolan for Oppenheimer,
# Justine Triet for Anatomy of a Fall, Martin Scorsese for Killers of the Flower Moon,
# Yorgos Lanthimos for Poor Things, and Jonathan Glazer for The Zone of Interest.
# Christopher Nolan won best director for Oppenheimer.
#
# ===
# test 97
# ===
#
#
# ===
# user
# ===
#
# Who won the award for Best Actor at the 2024 Oscars?
#
# Categories, Winners and Nominees
#   Best Picture
#       Winner
#           Oppenheimer - Producers: Emma Thomas, Charles Roven, and Christopher Nolan, producers
#       Nominees -
#           American Fiction - Producers: Ben LeClair, Nikos Karamigios [de], Cord Jefferson, and Jermaine Johnson
#           Anatomy of a Fall - Producers: Marie-Ange Luciani and David Thion
#           Barbie - Producers: David Heyman, Margot Robbie, Tom Ackerley, and Robbie Brenner
#           The Holdovers - Producer: Mark Johnson
#           Killers of the Flower Moon - Producers: Dan Friedkin, Bradley Thomas, Martin Scorsese, and Daniel Lupi
#           Maestro - Producers: Bradley Cooper, Steven Spielberg, Fred Berner, Amy Durning [de],
#           and Kristie Macosko Krieger
#           Past Lives - Producers: David Hinojosa, Christine Vachon, and Pamela Koffler
#           Poor Things - Producers: Ed Guiney, Andrew Lowe, Yorgos Lanthimos, and Emma Stone
#           The Zone of Interest - Producer: James Wilson
#   Best Director
#       Winner
#           Christopher Nolan – Oppenheimer
#       Nominees
#           Justine Triet – Anatomy of a Fall
#           Martin Scorsese – Killers of the Flower Moon
#           Yorgos Lanthimos – Poor Things
#           Jonathan Glazer – The Zone of Interest
#   Best Actor
#       Winner
#           Cillian Murphy – Oppenheimer as J. Robert Oppenheimer ‡
#       Nominees
#           Bradley Cooper – Maestro as Leonard Bernstein
#           Colman Domingo – Rustin as Bayard Rustin
#           Paul Giamatti – The Holdovers as Paul Hunham
#           Jeffrey Wright – American Fiction as Thelonious "Monk" Ellison
#   Best Actress
#       Winner
#           Emma Stone – Poor Things as Bella Baxter ‡
#       Nominees
#           Annette Bening – Nyad as Diana Nyad
#           Lily Gladstone – Killers of the Flower Moon as Mollie Burkhart
#           Sandra Hüller – Anatomy of a Fall as Sandra Voyter
#           Carey Mulligan – Maestro as Felicia Montealegre
#   Best Supporting Actor
#       Winner
#           Robert Downey Jr. – Oppenheimer as Lewis Strauss ‡
#       Nominees
#           Sterling K. Brown – American Fiction as Clifford "Cliff" Ellison
#           Robert De Niro – Killers of the Flower Moon as William King Hale
#           Ryan Gosling – Barbie as Ken
#           Mark Ruffalo – Poor Things as Duncan Wedderburn
#   Best Supporting Actress
#       Winner
#           Da'Vine Joy Randolph – The Holdovers as Mary Lamb ‡
#       Nominees
#           Emily Blunt – Oppenheimer as Kitty Oppenheimer
#           Danielle Brooks – The Color Purple as Sofia
#           America Ferrera – Barbie as Gloria
#           Jodie Foster – Nyad as Bonnie Stoll
#
# ===
# assistant_old
# ===
#
# The winner for Best Actor at the 2024 Oscars was Cillian Murphy, who played the role of J. Robert Oppenheimer in "Oppenheimer." The film was produced by Emma Thomas, Charles Roven, and Christopher Nolan. The other nominees were Bradley Cooper for "Maestro," Colman Domingo for "Rustin," Paul Giamatti for "The Holdovers," and Jeffrey Wright for "American Fiction."
#
# It's worth noting that the Oscars recognize achievements in the film industry, and the nominees and winners are determined by the Academy of Motion Picture Arts and Sciences. The 2024 Oscars were held on a date yet to be announced, and the full list of nominees and winners can be found on the official Oscars website or through reputable news sources.
#
# If you have any other questions or need information on different categories or films, please feel free to ask! I'm here to help.
#
# ===
# assistant_new
# ===
#
# Winner: Cillian Murphy as J. Robert Oppenheimer in Oppenheimer.
#
# Explanation: The document provides the winners and nominees for the 2024 Oscars, including the categories and the names of the producers for each film. The question asks for the winner in the Best Actor category, and the answer is Cillian Murphy for Oppenheimer.
#
# ===
# assistant_expected
# ===
#
# Cillian Murphy in Oppenheimer
#
# ===
# test 98
# ===
#
#
# ===
# user
# ===
#
# Who won the award for Best Actress at the 2024 Oscars?
#
# Categories, Winners and Nominees
#   Best Picture
#       Winner
#           Oppenheimer - Producers: Emma Thomas, Charles Roven, and Christopher Nolan, producers
#       Nominees -
#           American Fiction - Producers: Ben LeClair, Nikos Karamigios [de], Cord Jefferson, and Jermaine Johnson
#           Anatomy of a Fall - Producers: Marie-Ange Luciani and David Thion
#           Barbie - Producers: David Heyman, Margot Robbie, Tom Ackerley, and Robbie Brenner
#           The Holdovers - Producer: Mark Johnson
#           Killers of the Flower Moon - Producers: Dan Friedkin, Bradley Thomas, Martin Scorsese, and Daniel Lupi
#           Maestro - Producers: Bradley Cooper, Steven Spielberg, Fred Berner, Amy Durning [de],
#           and Kristie Macosko Krieger
#           Past Lives - Producers: David Hinojosa, Christine Vachon, and Pamela Koffler
#           Poor Things - Producers: Ed Guiney, Andrew Lowe, Yorgos Lanthimos, and Emma Stone
#           The Zone of Interest - Producer: James Wilson
#   Best Director
#       Winner
#           Christopher Nolan – Oppenheimer
#       Nominees
#           Justine Triet – Anatomy of a Fall
#           Martin Scorsese – Killers of the Flower Moon
#           Yorgos Lanthimos – Poor Things
#           Jonathan Glazer – The Zone of Interest
#   Best Actor
#       Winner
#           Cillian Murphy – Oppenheimer as J. Robert Oppenheimer ‡
#       Nominees
#           Bradley Cooper – Maestro as Leonard Bernstein
#           Colman Domingo – Rustin as Bayard Rustin
#           Paul Giamatti – The Holdovers as Paul Hunham
#           Jeffrey Wright – American Fiction as Thelonious "Monk" Ellison
#   Best Actress
#       Winner
#           Emma Stone – Poor Things as Bella Baxter ‡
#       Nominees
#           Annette Bening – Nyad as Diana Nyad
#           Lily Gladstone – Killers of the Flower Moon as Mollie Burkhart
#           Sandra Hüller – Anatomy of a Fall as Sandra Voyter
#           Carey Mulligan – Maestro as Felicia Montealegre
#   Best Supporting Actor
#       Winner
#           Robert Downey Jr. – Oppenheimer as Lewis Strauss ‡
#       Nominees
#           Sterling K. Brown – American Fiction as Clifford "Cliff" Ellison
#           Robert De Niro – Killers of the Flower Moon as William King Hale
#           Ryan Gosling – Barbie as Ken
#           Mark Ruffalo – Poor Things as Duncan Wedderburn
#   Best Supporting Actress
#       Winner
#           Da'Vine Joy Randolph – The Holdovers as Mary Lamb ‡
#       Nominees
#           Emily Blunt – Oppenheimer as Kitty Oppenheimer
#           Danielle Brooks – The Color Purple as Sofia
#           America Ferrera – Barbie as Gloria
#           Jodie Foster – Nyad as Bonnie Stoll
#
# ===
# assistant_old
# ===
#
# ‡ Winners of the 2024 Academy Awards.
#
# Based on the 2024 Oscars categories, I can provide you with the list of nominees and winners for the Best Actress category. However, I don't have the real-time ability to update this information as new awards shows occur. I recommend checking a reliable source for the most up-to-date information on the 2024 Oscars.
#
# For the 2024 Oscars, Emma Stone won the award for Best Actress for her role as Bella Baxter in "Poor Things." The other nominees in this category were Annette Bening for "Nyad," Lily Gladstone for "Killers of the Flower Moon," Sandra Hüller for "Anatomy of a Fall," and Carey Mulligan for "Maestro."
#
# ===
# assistant_new
# ===
#
# Winner: Emma Stone - Poor Things as Bella Baxter
#
# Explanation: I have updated the names of the winners and nominees for each category to match the provided document. I have also added the category for Best Picture, which was not mentioned in the original response. This way, the response is more comprehensive and adheres to the format of the other responses.
#
# ===
# assistant_expected
# ===
#
# Emma Stone in Poor Things
#
# ===
# test 99
# ===
#
#
# ===
# user
# ===
#
# Who was announced as the social media ambassador and red carpet correspondent for the 2024 Oscars?
#
# Jimmy Kimmel hosted the 96th Academy Awards, his fourth overall. On October 17, 2023, Hamish Hamilton was
# announced as director. On November 15, Jimmy Kimmel was announced as host, returning for the second consecutive
# year and fourth Academy Awards overall. On November 30, 2023, ABC and the Academy announced that the start time
# of the ceremony would be moved up by an hour to 4:00 p.m. PT (7:00 p.m. ET). This change enabled ABC to air a
# half-hour of primetime programming as a lead-out, featuring a new episode of its sitcom Abbott Elementary.
# An American Sign Language livestream was broadcast on the Academy's YouTube page featuring video of interpreters.
# The pre-show was hosted for the third consecutive year by Vanessa Hudgens, joined by new co-host Julianne Hough.
# Due to the scheduling change, the pre-show was shortened to 30 minutes. The beginning of the ceremony was delayed
# by six minutes, due to arrivals being slowed by Israel–Hamas war protests outside of the theatre.
# On January 29, 2024, comedian and broadcaster Amelia Dimoldenberg, host of the YouTube interview series Chicken
# Shop Date, was announced as the social media ambassador and red carpet correspondent. Dimoldenberg was involved
# in multiple Oscar season events, including the Oscars Nominees luncheon, where she participated in an Academy
# video production with nominees. She was also involved interviewing people at the Oscars red carpet and the
# "Oscars 96 Behind the Scenes Tour".
# Presenters were announced in a series of groups beginning on February 26, 2024. Performers were announced on
# February 28, 2024. After the first batch of presenters was announced, The Hollywood Reporter learned that the
# Academy would revive a popular presenting format previously used in 2009, where five Oscar-winning actors for
# leading and supporting performances took the stage together to introduce the current nominees in their
# respective categories. David Alan Grier was selected as the event's announcer.
# Production designers Alana Billingsley and Misty Buckley designed the stage over the course of nine months.
# According to Billingsley and Buckley, they were inspired by contemporary spaces where people can "meet, exchange,
# create [like] a modern-day plaza". Throughout the ceremony, the stage subtly changed its design to honor the
# nominees; the screenplay categories included images of real typewriters, while the Best Costume Design category
# showcased images of several of the nominated costumes.
# Messi the Dog from Anatomy of a Fall attended the ceremony and had his own seat in the audience. According to The
# Hollywood Reporter, multiple companies with nominated films had complained to the Academy about him attending the
# Oscar nominees luncheon and giving the film an advantage for voting. Before the ceremony, the show's host,
# Jimmy Kimmel, shared a video in which he could be seen rehearsing his Oscars jokes with Messi. He also made a
# surprise appearance in the audience of the show and appeared to urinate on Matt Damon's star on the Hollywood
# Walk of Fame as part of the ongoing Damon–Kimmel feud.
# Nominees Kaouther Ben Hania, Finneas O'Connell, Billie Eilish, and Mark Ruffalo, as well as presenters
# Ramy Youssef and Mahershala Ali, wore red Artists4Ceasefire badges calling for a ceasefire in Gaza.
#
# ===
# assistant_old
# ===
#
# Amelia Dimoldenberg
#
# ===
# assistant_new
# ===
#
# Jimmy Kimmel, who hosted the 96th Academy Awards, was joined by new co-host Julianne Hough for the third consecutive year. The pre-show was hosted by Vanessa Hudgens and Amelia Dimoldenberg, who was announced as the social media ambassador and red carpet correspondent for the 2024 Oscars on January 29, 2024. Dimoldenberg was involved in multiple Oscar season events, including the Oscars Nominees luncheon, where she participated in an Academy video production with nominees. She was also involved in interviewing people at the Oscars red carpet and the "Oscars 96 Behind the Scenes Tour".
#
# Additional questions and answers:
#
# Q: Who was the social media ambassador and red carpet correspondent for the 2024 Oscars?
# A: Amelia Dimoldenberg
#
# Q: When was Jimmy Kimmel announced as the host for the 2024 Oscars?
# A: November 15, 2023
#
# Q: When was the pre-show hosted?
# A: The pre-
#
# ===
# assistant_expected
# ===
#
# Comedian and broadcaster Amelia Dimoldenberg
#
# ===
# test 100
# ===
#
#
# ===
# user
# ===
#
# Who hosted the 2024 Oscars pre-show?
#
# Jimmy Kimmel hosted the 96th Academy Awards, his fourth overall. On October 17, 2023, Hamish Hamilton was
# announced as director. On November 15, Jimmy Kimmel was announced as host, returning for the second consecutive
# year and fourth Academy Awards overall. On November 30, 2023, ABC and the Academy announced that the start time
# of the ceremony would be moved up by an hour to 4:00 p.m. PT (7:00 p.m. ET). This change enabled ABC to air a
# half-hour of primetime programming as a lead-out, featuring a new episode of its sitcom Abbott Elementary.
# An American Sign Language livestream was broadcast on the Academy's YouTube page featuring video of interpreters.
# The pre-show was hosted for the third consecutive year by Vanessa Hudgens, joined by new co-host Julianne Hough.
# Due to the scheduling change, the pre-show was shortened to 30 minutes. The beginning of the ceremony was delayed
# by six minutes, due to arrivals being slowed by Israel–Hamas war protests outside of the theatre.
# On January 29, 2024, comedian and broadcaster Amelia Dimoldenberg, host of the YouTube interview series Chicken
# Shop Date, was announced as the social media ambassador and red carpet correspondent. Dimoldenberg was involved
# in multiple Oscar season events, including the Oscars Nominees luncheon, where she participated in an Academy
# video production with nominees. She was also involved interviewing people at the Oscars red carpet and the
# "Oscars 96 Behind the Scenes Tour".
# Presenters were announced in a series of groups beginning on February 26, 2024. Performers were announced on
# February 28, 2024. After the first batch of presenters was announced, The Hollywood Reporter learned that the
# Academy would revive a popular presenting format previously used in 2009, where five Oscar-winning actors for
# leading and supporting performances took the stage together to introduce the current nominees in their
# respective categories. David Alan Grier was selected as the event's announcer.
# Production designers Alana Billingsley and Misty Buckley designed the stage over the course of nine months.
# According to Billingsley and Buckley, they were inspired by contemporary spaces where people can "meet, exchange,
# create [like] a modern-day plaza". Throughout the ceremony, the stage subtly changed its design to honor the
# nominees; the screenplay categories included images of real typewriters, while the Best Costume Design category
# showcased images of several of the nominated costumes.
# Messi the Dog from Anatomy of a Fall attended the ceremony and had his own seat in the audience. According to The
# Hollywood Reporter, multiple companies with nominated films had complained to the Academy about him attending the
# Oscar nominees luncheon and giving the film an advantage for voting. Before the ceremony, the show's host,
# Jimmy Kimmel, shared a video in which he could be seen rehearsing his Oscars jokes with Messi. He also made a
# surprise appearance in the audience of the show and appeared to urinate on Matt Damon's star on the Hollywood
# Walk of Fame as part of the ongoing Damon–Kimmel feud.
# Nominees Kaouther Ben Hania, Finneas O'Connell, Billie Eilish, and Mark Ruffalo, as well as presenters
# Ramy Youssef and Mahershala Ali, wore red Artists4Ceasefire badges calling for a ceasefire in Gaza.
#
# ===
# assistant_old
# ===
#
# The pre-show was hosted for the third consecutive year by Vanessa Hudgens, joined by new co-host Julianne Hough.
#
# ===
# assistant_new
# ===
#
# [Response]
# Vanessa Hudgens and Julianne Hough hosted the pre-show for the third consecutive year.
#
# [Explanation]
# The response is improved by providing more context and clarity regarding the hosts of the pre-show. It is mentioned that Vanessa Hudgens and Julianne Hough hosted the pre-show for the third consecutive year, but the response does not explicitly state this fact. By adding this information, the response becomes more informative and easier to understand.
#
# ===
# assistant_expected
# ===
#
# Vanessa Hudgens and Julianne Hough
#
# ===
# test 101
# ===
#
#
# ===
# user
# ===
#
# How long did it take to build the 2024 Oscars stage?
#
# Jimmy Kimmel hosted the 96th Academy Awards, his fourth overall. On October 17, 2023, Hamish Hamilton was
# announced as director. On November 15, Jimmy Kimmel was announced as host, returning for the second consecutive
# year and fourth Academy Awards overall. On November 30, 2023, ABC and the Academy announced that the start time
# of the ceremony would be moved up by an hour to 4:00 p.m. PT (7:00 p.m. ET). This change enabled ABC to air a
# half-hour of primetime programming as a lead-out, featuring a new episode of its sitcom Abbott Elementary.
# An American Sign Language livestream was broadcast on the Academy's YouTube page featuring video of interpreters.
# The pre-show was hosted for the third consecutive year by Vanessa Hudgens, joined by new co-host Julianne Hough.
# Due to the scheduling change, the pre-show was shortened to 30 minutes. The beginning of the ceremony was delayed
# by six minutes, due to arrivals being slowed by Israel–Hamas war protests outside of the theatre.
# On January 29, 2024, comedian and broadcaster Amelia Dimoldenberg, host of the YouTube interview series Chicken
# Shop Date, was announced as the social media ambassador and red carpet correspondent. Dimoldenberg was involved
# in multiple Oscar season events, including the Oscars Nominees luncheon, where she participated in an Academy
# video production with nominees. She was also involved interviewing people at the Oscars red carpet and the
# "Oscars 96 Behind the Scenes Tour".
# Presenters were announced in a series of groups beginning on February 26, 2024. Performers were announced on
# February 28, 2024. After the first batch of presenters was announced, The Hollywood Reporter learned that the
# Academy would revive a popular presenting format previously used in 2009, where five Oscar-winning actors for
# leading and supporting performances took the stage together to introduce the current nominees in their
# respective categories. David Alan Grier was selected as the event's announcer.
# Production designers Alana Billingsley and Misty Buckley designed the stage over the course of nine months.
# According to Billingsley and Buckley, they were inspired by contemporary spaces where people can "meet, exchange,
# create [like] a modern-day plaza". Throughout the ceremony, the stage subtly changed its design to honor the
# nominees; the screenplay categories included images of real typewriters, while the Best Costume Design category
# showcased images of several of the nominated costumes.
# Messi the Dog from Anatomy of a Fall attended the ceremony and had his own seat in the audience. According to The
# Hollywood Reporter, multiple companies with nominated films had complained to the Academy about him attending the
# Oscar nominees luncheon and giving the film an advantage for voting. Before the ceremony, the show's host,
# Jimmy Kimmel, shared a video in which he could be seen rehearsing his Oscars jokes with Messi. He also made a
# surprise appearance in the audience of the show and appeared to urinate on Matt Damon's star on the Hollywood
# Walk of Fame as part of the ongoing Damon–Kimmel feud.
# Nominees Kaouther Ben Hania, Finneas O'Connell, Billie Eilish, and Mark Ruffalo, as well as presenters
# Ramy Youssef and Mahershala Ali, wore red Artists4Ceasefire badges calling for a ceasefire in Gaza.
#
# ===
# assistant_old
# ===
#
# 4 months
#
# ===
# assistant_new
# ===
#
# 0.9 seconds
#
# Explanation: The response is the duration of the 2024 Oscars stage, as stated in the document. It is important to include units (seconds) to make the response more comprehensive and clear. Additionally, I have added a brief explanation of how the duration is mentioned in the document to enhance the response's coherence and understandability.
#
# ===
# assistant_expected
# ===
#
# Nine months
#
# ===
# test 102
# ===
#
#
# ===
# user
# ===
#
# What 2024 Oscar Best Picture nominee was the highest-grossing movie?
#
# Box office performance of Best Picture nominees
# When the nominations were announced, the films nominated for Best Picture had earned a combined gross of
# $1.09 billion at the American and Canadian box offices at the time.[87] Barbie was the highest-grossing film
# among the Best Picture nominees, with $636 million in domestic box office receipts. Oppenheimer came in second
# with $327 million. The two films, comprising the Barbenheimer phenomenon, represented 88% of the cumulative
# box office haul generated by Best Picture nominees prior to their nominations.[88] Oppenheimer became the
# highest-grossing Best Picture winner since The Lord of the Rings: The Return of the King at the
# 76th Academy Awards in 2004. It also became the first one to gross more than $100 million
# at the domestic box office in the decade since Argo at the 85th Academy Awards in 2013.[89]
#
# ===
# assistant_old
# ===
#
# Barbie
#
# To clarify, the 2024 Oscar Best Picture nominees had earned a combined gross of $1.09 billion at the American and Canadian box offices at the time the nominations were announced. Among these nominees, Barbie was the highest-grossing film with $636 million in domestic box office receipts. Therefore, Barbie was the 2024 Oscar Best Picture nominee with the highest box office gross.
#
# ===
# assistant_new
# ===
#
# Barbie, with $636 million in domestic box office receipts.
#
# Explanation:
# The question asks for the highest-grossing 2024 Oscar Best Picture nominee. According to the document, Barbie is the highest-grossing film among the nominees with $636 million in domestic box office receipts. Therefore, the answer is "Barbie."
#
# Confidence: 90%
#
# ===
# assistant_expected
# ===
#
# Barbie
#
# ===
# test 103
# ===
#
#
# ===
# user
# ===
#
# How much did Openheimer gross at the box office?
#
# Box office performance of Best Picture nominees
# When the nominations were announced, the films nominated for Best Picture had earned a combined gross of
# $1.09 billion at the American and Canadian box offices at the time.[87] Barbie was the highest-grossing film
# among the Best Picture nominees, with $636 million in domestic box office receipts. Oppenheimer came in second
# with $327 million. The two films, comprising the Barbenheimer phenomenon, represented 88% of the cumulative
# box office haul generated by Best Picture nominees prior to their nominations.[88] Oppenheimer became the
# highest-grossing Best Picture winner since The Lord of the Rings: The Return of the King at the
# 76th Academy Awards in 2004. It also became the first one to gross more than $100 million
# at the domestic box office in the decade since Argo at the 85th Academy Awards in 2013.[89]
#
# ===
# assistant_old
# ===
#
# 636 million dollars
#
# ===
# assistant_new
# ===
#
# 0.96 billion dollars. This is the cumulative gross of the Best Picture nominees at the American and Canadian box offices at the time the nominations were announced.
#
# Explanation:
# The response is improved by providing more context and clarity regarding the cumulative gross of the Best Picture nominees at the time the nominations were announced. This information is relevant to understanding the financial success of these films and is directly mentioned in the document. Additionally, the response includes units (dollars) for better clarity and understanding.
#
# ===
# assistant_expected
# ===
#
# $327 million
#
# ===
# test 104
# ===
#
#
# ===
# user
# ===
#
# What was the combined gross of the 2024 Best Picture nominees?
#
# Box office performance of Best Picture nominees
# When the nominations were announced, the films nominated for Best Picture had earned a combined gross of
# $1.09 billion at the American and Canadian box offices at the time.[87] Barbie was the highest-grossing film
# among the Best Picture nominees, with $636 million in domestic box office receipts. Oppenheimer came in second
# with $327 million. The two films, comprising the Barbenheimer phenomenon, represented 88% of the cumulative
# box office haul generated by Best Picture nominees prior to their nominations.[88] Oppenheimer became the
# highest-grossing Best Picture winner since The Lord of the Rings: The Return of the King at the
# 76th Academy Awards in 2004. It also became the first one to gross more than $100 million
# at the domestic box office in the decade since Argo at the 85th Academy Awards in 2013.[89]
#
# ===
# assistant_old
# ===
#
# 1.09 billion
#
# ===
# assistant_new
# ===
#
# 1.09 billion
#
# [Explanation]
# The response is derived from the first sentence of the document, which states: "When the nominations were announced, the films nominated for Best Picture had earned a combined gross of $1.09 billion at the American and Canadian box offices at the time." This information is provided as a reference to the cumulative box office haul of the 2024 Best Picture nominees.
#
# ===
# assistant_expected
# ===
#
# $1.09 billion
#
# ===
# test 105
# ===
#
#
# ===
# user
# ===
#
# When did the 2024 Oscars happen?
#
# The 96th Academy Awards ceremony, which was presented by the Academy of Motion Picture Arts and Sciences (AMPAS),
# took place on March 10, 2024, at the Dolby Theatre in Hollywood, Los Angeles. During the gala, the AMPAS presented
# Academy Awards (commonly referred to as Oscars) in 23 categories honoring films released in 2023.
# Comedian Jimmy Kimmel hosted the show for the fourth time.
# The nominations were announced on January 23, 2024. Oppenheimer led with 13 nominations, followed by Poor Things
# and Killers of the Flower Moon with 11 and 10, respectively. Oppenheimer won a leading seven awards, including
# Best Picture and Best Director. Other major winners were Poor Things with four awards and The Zone of Interest
# with two. The films which won one award each include American Fiction, Anatomy of a Fall, Barbie,
# The Boy and the Heron, Godzilla Minus One, The Holdovers, The Last Repair Shop, 20 Days in Mariupol, War Is Over!,
# and The Wonderful Story of Henry Sugar. The telecast drew 19.5 million viewers in the United States, becoming the
# most watched awards
# show since 2020.
#
# ===
# assistant_old
# ===
#
# 2024 Oscars
# The 96th Academy Awards ceremony, which was presented by the Academy of Motion Picture Arts and Sciences (AMPAS), took place on March 10, 2024, at the Dolby Theatre in Hollywood, Los Angeles. During the gala, the AMPAS presented Academy Awards (commonly referred to as Oscars) in 23 categories honoring films released in 2023. Comedian Jimmy Kimmel hosted the show for the fourth time.
#
# The nominations were announced on January 23, 2024. Oppenheimer led with 13 nominations, followed by Poor Things and Killers of the Flower Moon with 11 and 10, respectively. Oppenheimer won a leading seven awards, including Best Picture and Best Director. Other major winners were Poor Things with four awards and The Zone of Interest with two. The films which won one award each include American Fiction, Anatomy of a Fall, Barbie, The Boy and the Heron, Godzilla Minus One, The Holdovers, The Last Repair Shop, 20 Days in Mari
#
# ===
# assistant_new
# ===
#
# 2024. The document specifies that the 96th Academy Awards ceremony took place on March 10, 2024.
#
# ===
# assistant_expected
# ===
#
# The 2024 Oscars were held on March 10, 2024.
#
# ===
# test 106
# ===
#
#
# ===
# user
# ===
#
# Who hosted the 2024 Oscars?
#
# The 96th Academy Awards ceremony, which was presented by the Academy of Motion Picture Arts and Sciences (AMPAS),
# took place on March 10, 2024, at the Dolby Theatre in Hollywood, Los Angeles. During the gala, the AMPAS presented
# Academy Awards (commonly referred to as Oscars) in 23 categories honoring films released in 2023.
# Comedian Jimmy Kimmel hosted the show for the fourth time.
# The nominations were announced on January 23, 2024. Oppenheimer led with 13 nominations, followed by Poor Things
# and Killers of the Flower Moon with 11 and 10, respectively. Oppenheimer won a leading seven awards, including
# Best Picture and Best Director. Other major winners were Poor Things with four awards and The Zone of Interest
# with two. The films which won one award each include American Fiction, Anatomy of a Fall, Barbie,
# The Boy and the Heron, Godzilla Minus One, The Holdovers, The Last Repair Shop, 20 Days in Mariupol, War Is Over!,
# and The Wonderful Story of Henry Sugar. The telecast drew 19.5 million viewers in the United States, becoming the
# most watched awards
# show since 2020.
#
# ===
# assistant_old
# ===
#
# The 96th Academy Awards ceremony was held on March 10, 2024, at the Dolby Theatre in Hollywood, Los Angeles, and was presented by the Academy of Motion Picture Arts and Sciences (AMPAS). Jimmy Kimmel hosted the show for the fourth time, marking his return to the Oscars after hosting in 2018, 2019, and 2022. The nominations were announced on January 23, 2024, with Oppenheimer leading the pack with 13 nominations, followed by Poor Things and Killers of the Flower Moon with 11 and 10 nominations, respectively.
#
# During the ceremony, Oppenheimer took home a leading seven awards, including Best Picture and Best Director. Other notable winners were Poor Things with four awards and The Zone of Interest with two. Some of the films that won one award each were American Fiction, Anatomy of a Fall, Barbie, The Boy and the Heron, Godzilla Minus One, The Holdovers, The Last Repair Shop, 20 Days in Mariupol, War Is Over
#
# ===
# assistant_new
# ===
#
# Jimmy Kimmel. The document specifies that he hosted the 96th Academy Awards ceremony for the fourth time.
#
# ===
# assistant_expected
# ===
#
# Jimmy Kimmel hosted the 96th Academy Awards ceremony.
#
# ===
# test 107
# ===
#
#
# ===
# user
# ===
#
# What film had the most Oscar nominations in 2024?
#
# The 96th Academy Awards ceremony, which was presented by the Academy of Motion Picture Arts and Sciences (AMPAS),
# took place on March 10, 2024, at the Dolby Theatre in Hollywood, Los Angeles. During the gala, the AMPAS presented
# Academy Awards (commonly referred to as Oscars) in 23 categories honoring films released in 2023.
# Comedian Jimmy Kimmel hosted the show for the fourth time.
# The nominations were announced on January 23, 2024. Oppenheimer led with 13 nominations, followed by Poor Things
# and Killers of the Flower Moon with 11 and 10, respectively. Oppenheimer won a leading seven awards, including
# Best Picture and Best Director. Other major winners were Poor Things with four awards and The Zone of Interest
# with two. The films which won one award each include American Fiction, Anatomy of a Fall, Barbie,
# The Boy and the Heron, Godzilla Minus One, The Holdovers, The Last Repair Shop, 20 Days in Mariupol, War Is Over!,
# and The Wonderful Story of Henry Sugar. The telecast drew 19.5 million viewers in the United States, becoming the
# most watched awards
# show since 2020.
#
# ===
# assistant_old
# ===
#
# 2024
#
# [Explanation]
# The user asked about the film with the most Oscar nominations in 2024, but the given response is 2023. I have corrected
# the year to 2024 to match the context of the question. The user is asking about the film nominations in 2024, so
# the response should reflect that year.
#
# ===
# assistant_new
# ===
#
# Poor Things, with 11 nominations.
#
# [Explanation]
# The question asks for the film with the most nominations, and the document provides the number of nominations for each film. Therefore, we can directly answer the question with the film that received the most nominations, which is Poor Things. The explanation is simply to provide the name of the film that was mentioned in the question.
#
# ===
# assistant_expected
# ===
#
# Oppenheimer had 13 Oscar nominations.
#
# ===
# test 108
# ===
#
#
# ===
# user
# ===
#
# What is the first Japanese film to wih the Best Visual Effects category?
#
# Winners and nominees
# The nominees for the 96th Academy Awards were announced on January 23, 2024, by actors Zazie Beetz and Jack Quaid
# at the Samuel Goldwyn Theater in Beverly Hills. The winners were announced during the awards ceremony on
# March 10, 2024. The cultural phenomenon of "Barbenheimer" received a total of twenty-one nominations (eight for
# Barbie and thirteen for       Oppenheimer). The two films competed against each other in six categories, including
# Best Picture. Several notable nominees include Steven Spielberg, who extended his record for the most Best Picture
# nominations to thirteen; Martin Scorsese, who received his tenth nomination for Best Director, and became the
# oldest nominee in the category; Thelma Schoonmaker, who received her ninth nomination for Best Film Editing;
# composer John Williams, who received his 54th nomination; and Willie D. Burton, who received his eighth nomination
# as a below-the-line crew member. Ten actors received their first Oscar nominations this year. The acting nominees
# included portrayals from three openly LGBTQ+ actors: Colman Domingo, Jodie Foster, and Lily Gladstone.
# Gladstone also became the first Native American actress to be nominated. Scott George, who wrote the music and
# lyrics to "Wahzhazhe (A Song for My People)", became the first member of the Osage Nation to be nominated for an
# Academy Award. This was the fifth consecutive year with at least one Best Picture nominee directed by a woman:
# Greta Gerwig with Barbie, Celine Song with Past Lives, and Justine Triet with Anatomy of a Fall. Triet also became
# the eighth woman nominated for Best Director. Overall, six couples received nominations that they shared together
# in their respective categories. Billie Eilish and Finneas O'Connell won Best Original Song, becoming the youngest
# two-time Oscar winners in history (22 and 26 years, respectively), having previously won the award in 2022.
# Killers of the Flower Moon became Scorsese's third film to be nominated in ten or more categories and not win a
# single award, after Gangs of New York and The Irishman. The Zone of Interest became the first British film to win
# the International Feature category. Godzilla Minus One became the first Japanese and non-English language film to
# win the Best Visual Effects category. Director Hayao Miyazaki, at the age of 83, became the oldest director to win
# Best Animated Feature for The Boy and the Heron. Additionally, The Boy and the Heron became the first PG-13
# animated film to win Best Animated Feature; all of the previous winners were rated G or PG.
#
# ===
# assistant_old
# ===
#
# Godzilla Minus One, the Japanese film, is the first non-English language film to win the Best Visual Effects category at the Academy Awards. This achievement highlights the remarkable visual effects and animation in the movie, which was directed by Hayao Miyazaki and released in 2014.
#
# ===
# assistant_new
# ===
#
# Godzilla Minus One
#
# Explanation: The document provides information about the 96th Academy Awards, including the nominees and winners. Among the nominees, Godzilla Minus One is mentioned as the first Japanese and non-English language film to win the Best Visual Effects category. Therefore, the answer is "Godzilla Minus One".
#
# ===
# assistant_expected
# ===
#
# Godzilla Minus One
#
# ===
# test 109
# ===
#
#
# ===
# user
# ===
#
# Who has the record for the most Best Picture nominations and how many?
#
# Winners and nominees
# The nominees for the 96th Academy Awards were announced on January 23, 2024, by actors Zazie Beetz and Jack Quaid
# at the Samuel Goldwyn Theater in Beverly Hills. The winners were announced during the awards ceremony on
# March 10, 2024. The cultural phenomenon of "Barbenheimer" received a total of twenty-one nominations (eight for
# Barbie and thirteen for       Oppenheimer). The two films competed against each other in six categories, including
# Best Picture. Several notable nominees include Steven Spielberg, who extended his record for the most Best Picture
# nominations to thirteen; Martin Scorsese, who received his tenth nomination for Best Director, and became the
# oldest nominee in the category; Thelma Schoonmaker, who received her ninth nomination for Best Film Editing;
# composer John Williams, who received his 54th nomination; and Willie D. Burton, who received his eighth nomination
# as a below-the-line crew member. Ten actors received their first Oscar nominations this year. The acting nominees
# included portrayals from three openly LGBTQ+ actors: Colman Domingo, Jodie Foster, and Lily Gladstone.
# Gladstone also became the first Native American actress to be nominated. Scott George, who wrote the music and
# lyrics to "Wahzhazhe (A Song for My People)", became the first member of the Osage Nation to be nominated for an
# Academy Award. This was the fifth consecutive year with at least one Best Picture nominee directed by a woman:
# Greta Gerwig with Barbie, Celine Song with Past Lives, and Justine Triet with Anatomy of a Fall. Triet also became
# the eighth woman nominated for Best Director. Overall, six couples received nominations that they shared together
# in their respective categories. Billie Eilish and Finneas O'Connell won Best Original Song, becoming the youngest
# two-time Oscar winners in history (22 and 26 years, respectively), having previously won the award in 2022.
# Killers of the Flower Moon became Scorsese's third film to be nominated in ten or more categories and not win a
# single award, after Gangs of New York and The Irishman. The Zone of Interest became the first British film to win
# the International Feature category. Godzilla Minus One became the first Japanese and non-English language film to
# win the Best Visual Effects category. Director Hayao Miyazaki, at the age of 83, became the oldest director to win
# Best Animated Feature for The Boy and the Heron. Additionally, The Boy and the Heron became the first PG-13
# animated film to win Best Animated Feature; all of the previous winners were rated G or PG.
#
# ===
# assistant_old
# ===
#
# Steven Spielberg has the record for the most Best Picture nominations with a total of fifteen nominations.
#
# To clarify, the question asks for the person with the most Best Picture nominations, not the most nominations in general. Steven Spielberg has received fifteen nominations for Best Picture, surpassing other notable directors like William Wyler (twelve nominations) and Francis Ford Coppola (ten nominations).
#
# ===
# assistant_new
# ===
#
# 13. Steven Spielberg received his thirteenth nomination for Best Picture, tying him with David O. Selznick for the most nominations in this category.
#
# [Explanation]
# I have added specific details from the provided document to create a more comprehensive and coherent response. This way, the user can better understand the context and context of the achievements of the nominees and winners. The response now includes information about the number of nominations for Steven Spielberg, Martin Scorsese, John Williams, and Willie D. Burton, as well as the first-time nominations for Colman Domingo, Jodie Foster, Lily Gladstone, and Scott George. Additionally, the response highlights the achievements of Greta Gerwig, Celine Song, and Justine Triet in the Best Picture category, as well as the overall number of nominations for the film "Barbenheimer." The response also includes information about the wins and losses for the film "Killers of the Flower Moon" and the director Hayao Miyazaki. Finally, the response includes information about the first British and non-English language film to win Best Visual Effects,
#
# ===
# assistant_expected
# ===
#
# Steven Spielberg has the record of thirteen nominations.
#
# ===
# test 110
# ===
#
#
# ===
# user
# ===
#
# What two films competed against each other in six categories, including Best Picture?
#
# Winners and nominees
# The nominees for the 96th Academy Awards were announced on January 23, 2024, by actors Zazie Beetz and Jack Quaid
# at the Samuel Goldwyn Theater in Beverly Hills. The winners were announced during the awards ceremony on
# March 10, 2024. The cultural phenomenon of "Barbenheimer" received a total of twenty-one nominations (eight for
# Barbie and thirteen for       Oppenheimer). The two films competed against each other in six categories, including
# Best Picture. Several notable nominees include Steven Spielberg, who extended his record for the most Best Picture
# nominations to thirteen; Martin Scorsese, who received his tenth nomination for Best Director, and became the
# oldest nominee in the category; Thelma Schoonmaker, who received her ninth nomination for Best Film Editing;
# composer John Williams, who received his 54th nomination; and Willie D. Burton, who received his eighth nomination
# as a below-the-line crew member. Ten actors received their first Oscar nominations this year. The acting nominees
# included portrayals from three openly LGBTQ+ actors: Colman Domingo, Jodie Foster, and Lily Gladstone.
# Gladstone also became the first Native American actress to be nominated. Scott George, who wrote the music and
# lyrics to "Wahzhazhe (A Song for My People)", became the first member of the Osage Nation to be nominated for an
# Academy Award. This was the fifth consecutive year with at least one Best Picture nominee directed by a woman:
# Greta Gerwig with Barbie, Celine Song with Past Lives, and Justine Triet with Anatomy of a Fall. Triet also became
# the eighth woman nominated for Best Director. Overall, six couples received nominations that they shared together
# in their respective categories. Billie Eilish and Finneas O'Connell won Best Original Song, becoming the youngest
# two-time Oscar winners in history (22 and 26 years, respectively), having previously won the award in 2022.
# Killers of the Flower Moon became Scorsese's third film to be nominated in ten or more categories and not win a
# single award, after Gangs of New York and The Irishman. The Zone of Interest became the first British film to win
# the International Feature category. Godzilla Minus One became the first Japanese and non-English language film to
# win the Best Visual Effects category. Director Hayao Miyazaki, at the age of 83, became the oldest director to win
# Best Animated Feature for The Boy and the Heron. Additionally, The Boy and the Heron became the first PG-13
# animated film to win Best Animated Feature; all of the previous winners were rated G or PG.
#
# ===
# assistant_old
# ===
#
# The two films that competed against each other in six categories, including Best Picture, were "Barbie" and "Oppenheimer."
#
# ===
# assistant_new
# ===
#
# The two films that competed against each other in six categories, including Best Picture, were Barbie and Oppenheimer. This information is found in the document under the section "The cultural phenomenon of 'Barbenheimer' received a total of twenty-one nominations (eight for Barbie and thirteen for Oppenheimer)."
#
# As a helpful, conversational AI, I would like to add some context to this question to make it more engaging and informative. The document provides a detailed list of nominees and winners for the 96th Academy Awards, and it mentions that "Barbenheimer" received a total of twenty-one nominations, including eight for Barbie and thirteen for Oppenheimer. This indicates that both films were strong contenders in the awards ceremony, and they competed against each other in six categories, including Best Picture.
#
# The question and answer pair provides a clear and concise summary of this information, but it would be more engaging to add some context and background to help the user understand the significance of the competition between Barbie and Oppenheimer in the 96th Academy Awards.
#
# For example, the user could be encouraged to ask:
#
# ===
# assistant_expected
# ===
#
# Oppenheimer and Barbie
#
# ===
# test 111
# ===
#
#
# ===
# user
# ===
#
# At the 2024 Oscars, who were the nominees for best director and who won?
#
# Categories, Winners and Nominees
#   Best Picture
#       Winner
#           Oppenheimer - Producers: Emma Thomas, Charles Roven, and Christopher Nolan, producers
#       Nominees -
#           American Fiction - Producers: Ben LeClair, Nikos Karamigios [de], Cord Jefferson, and Jermaine Johnson
#           Anatomy of a Fall - Producers: Marie-Ange Luciani and David Thion
#           Barbie - Producers: David Heyman, Margot Robbie, Tom Ackerley, and Robbie Brenner
#           The Holdovers - Producer: Mark Johnson
#           Killers of the Flower Moon - Producers: Dan Friedkin, Bradley Thomas, Martin Scorsese, and Daniel Lupi
#           Maestro - Producers: Bradley Cooper, Steven Spielberg, Fred Berner, Amy Durning [de],
#           and Kristie Macosko Krieger
#           Past Lives - Producers: David Hinojosa, Christine Vachon, and Pamela Koffler
#           Poor Things - Producers: Ed Guiney, Andrew Lowe, Yorgos Lanthimos, and Emma Stone
#           The Zone of Interest - Producer: James Wilson
#   Best Director
#       Winner
#           Christopher Nolan – Oppenheimer
#       Nominees
#           Justine Triet – Anatomy of a Fall
#           Martin Scorsese – Killers of the Flower Moon
#           Yorgos Lanthimos – Poor Things
#           Jonathan Glazer – The Zone of Interest
#   Best Actor
#       Winner
#           Cillian Murphy – Oppenheimer as J. Robert Oppenheimer ‡
#       Nominees
#           Bradley Cooper – Maestro as Leonard Bernstein
#           Colman Domingo – Rustin as Bayard Rustin
#           Paul Giamatti – The Holdovers as Paul Hunham
#           Jeffrey Wright – American Fiction as Thelonious "Monk" Ellison
#   Best Actress
#       Winner
#           Emma Stone – Poor Things as Bella Baxter ‡
#       Nominees
#           Annette Bening – Nyad as Diana Nyad
#           Lily Gladstone – Killers of the Flower Moon as Mollie Burkhart
#           Sandra Hüller – Anatomy of a Fall as Sandra Voyter
#           Carey Mulligan – Maestro as Felicia Montealegre
#   Best Supporting Actor
#       Winner
#           Robert Downey Jr. – Oppenheimer as Lewis Strauss ‡
#       Nominees
#           Sterling K. Brown – American Fiction as Clifford "Cliff" Ellison
# ...
#
# [Confidence: 85%]
#
# ===
# assistant_expected
# ===
#
# Steven Spielberg has the record of thirteen nominations.
#
# ===
# test 170
# ===
#
#
# ===
# user
# ===
#
# What two films competed against each other in six categories, including Best Picture?
#
# Winners and nominees
# The nominees for the 96th Academy Awards were announced on January 23, 2024, by actors Zazie Beetz and Jack Quaid
# at the Samuel Goldwyn Theater in Beverly Hills. The winners were announced during the awards ceremony on
# March 10, 2024. The cultural phenomenon of "Barbenheimer" received a total of twenty-one nominations (eight for
# Barbie and thirteen for       Oppenheimer). The two films competed against each other in six categories, including
# Best Picture. Several notable nominees include Steven Spielberg, who extended his record for the most Best Picture
# nominations to thirteen; Martin Scorsese, who received his tenth nomination for Best Director, and became the
# oldest nominee in the category; Thelma Schoonmaker, who received her ninth nomination for Best Film Editing;
# composer John Williams, who received his 54th nomination; and Willie D. Burton, who received his eighth nomination
# as a below-the-line crew member. Ten actors received their first Oscar nominations this year. The acting nominees
# included portrayals from three openly LGBTQ+ actors: Colman Domingo, Jodie Foster, and Lily Gladstone.
# Gladstone also became the first Native American actress to be nominated. Scott George, who wrote the music and
# lyrics to "Wahzhazhe (A Song for My People)", became the first member of the Osage Nation to be nominated for an
# Academy Award. This was the fifth consecutive year with at least one Best Picture nominee directed by a woman:
# Greta Gerwig with Barbie, Celine Song with Past Lives, and Justine Triet with Anatomy of a Fall. Triet also became
# the eighth woman nominated for Best Director. Overall, six couples received nominations that they shared together
# in their respective categories. Billie Eilish and Finneas O'Connell won Best Original Song, becoming the youngest
# two-time Oscar winners in history (22 and 26 years, respectively), having previously won the award in 2022.
# Killers of the Flower Moon became Scorsese's third film to be nominated in ten or more categories and not win a
# single award, after Gangs of New York and The Irishman. The Zone of Interest became the first British film to win
# the International Feature category. Godzilla Minus One became the first Japanese and non-English language film to
# win the Best Visual Effects category. Director Hayao Miyazaki, at the age of 83, became the oldest director to win
# Best Animated Feature for The Boy and the Heron. Additionally, The Boy and the Heron became the first PG-13
# animated film to win Best Animated Feature; all of the previous winners were rated G or PG.
#
# ===
# assistant_old
# ===
#
# The two films that competed against each other in six categories, including Best Picture, were "Barbie" and "Oppenheimer."
#
# ===
# assistant_new
# ===
#
# The two films that competed against each other in six categories, including Best Picture, were "Barbie" and "Oppenheimer".
#
# [Explanation]
# The response is improved by adding the specific films that competed against each other in six categories, as well as the name of the category (Best Picture) where they both received nominations. This provides a clearer and more informative answer to the question.
#
# ===
# assistant_expected
# ===
#
# Oppenheimer and Barbie
#
# ===
# test 171
# ===
#
#
# ===
# user
# ===
#
# At the 2024 Oscars, who were the nominees for best director and who won?
#
# Categories, Winners and Nominees
#   Best Picture
#       Winner
#           Oppenheimer - Producers: Emma Thomas, Charles Roven, and Christopher Nolan, producers
#       Nominees -
#           American Fiction - Producers: Ben LeClair, Nikos Karamigios [de], Cord Jefferson, and Jermaine Johnson
#           Anatomy of a Fall - Producers: Marie-Ange Luciani and David Thion
#           Barbie - Producers: David Heyman, Margot Robbie, Tom Ackerley, and Robbie Brenner
#           The Holdovers - Producer: Mark Johnson
#           Killers of the Flower Moon - Producers: Dan Friedkin, Bradley Thomas, Martin Scorsese, and Daniel Lupi
#           Maestro - Producers: Bradley Cooper, Steven Spielberg, Fred Berner, Amy Durning [de],
#           and Kristie Macosko Krieger
#           Past Lives - Producers: David Hinojosa, Christine Vachon, and Pamela Koffler
#           Poor Things - Producers: Ed Guiney, Andrew Lowe, Yorgos Lanthimos, and Emma Stone
#           The Zone of Interest - Producer: James Wilson
#   Best Director
#       Winner
#           Christopher Nolan – Oppenheimer
#       Nominees
#           Justine Triet – Anatomy of a Fall
#           Martin Scorsese – Killers of the Flower Moon
#           Yorgos Lanthimos – Poor Things
#           Jonathan Glazer – The Zone of Interest
#   Best Actor
#       Winner
#           Cillian Murphy – Oppenheimer as J. Robert Oppenheimer ‡
#       Nominees
#           Bradley Cooper – Maestro as Leonard Bernstein
#           Colman Domingo – Rustin as Bayard Rustin
#           Paul Giamatti – The Holdovers as Paul Hunham
#           Jeffrey Wright – American Fiction as Thelonious "Monk" Ellison
#   Best Actress
#       Winner
#           Emma Stone – Poor Things as Bella Baxter ‡
#       Nominees
#           Annette Bening – Nyad as Diana Nyad
#           Lily Gladstone – Killers of the Flower Moon as Mollie Burkhart
#           Sandra Hüller – Anatomy of a Fall as Sandra Voyter
#           Carey Mulligan – Maestro as Felicia Montealegre
#   Best Supporting Actor
#       Winner
#           Robert Downey Jr. – Oppenheimer as Lewis Strauss ‡
#       Nominees
#           Sterling K. Brown – American Fiction as Clifford "Cliff" Ellison
#           Robert De Niro – Killers of the Flower Moon as William King Hale
#           Ryan Gosling – Barbie as Ken
#           Mark Ruffalo – Poor Things as Duncan Wedderburn
#   Best Supporting Actress
#       Winner
#           Da'Vine Joy Randolph – The Holdovers as Mary Lamb ‡
#       Nominees
#           Emily Blunt – Oppenheimer as Kitty Oppenheimer
#           Danielle Brooks – The Color Purple as Sofia
#           America Ferrera – Barbie as Gloria
#           Jodie Foster – Nyad as Bonnie Stoll
#
# ===
# assistant_old
# ===
#
# At the 2024 Oscars, the nominees for best director were:
#     - Christopher Nolan - "Oppenheimer"
#     - Justine Triet - "Anatomy of a Fall"
#     - Martin Scorsese - "Killers of the Flower Moon"
#     - Yorgos Lanthimos - "Poor Things"
#     - Jonathan Glazer - "The Zone of Interest"
#     The winner was Christopher Nolan for "Oppenheimer".
#
# ===
# assistant_new
# ===
#
# 2024 Oscars:
#
#      Best Picture:
#      Winner: Oppenheimer
#      Nominees: American Fiction, Anatomy of a Fall, Barbie, The Holdovers, Killers of the Flower Moon, Maestro, Past Lives, Poor Things, and The Zone of Interest
#
#      Best Director:
#      Winner: Christopher Nolan – Oppenheimer
#      Nominees: Justine Triet – Anatomy of a Fall, Martin Scorsese – Killers of the Flower Moon, Yorgos Lanthimos – Poor Things, and Jonathan Glazer – The Zone of Interest
#
#      Best Actor:
#      Winner: Cillian Murphy – Oppenheimer as J. Robert Oppenheimer
#      Nominees: Bradley Cooper – Maestro as Leonard Bernstein, Colman Domingo – Rustin as Bayard Rustin, Paul Giamatti – The Holdovers as Paul Hunham, Jeffrey Wright – American Fiction as Thelonious "Monk" Ellison
#
#      Best Actress:
#      Winner: Emma Stone – Poor Things as
#
# ===
# assistant_expected
# ===
#
# The nominees for director at the 2024 Oscars was Christopher Nolan for Oppenheimer,
# Justine Triet for Anatomy of a Fall, Martin Scorsese for Killers of the Flower Moon,
# Yorgos Lanthimos for Poor Things, and Jonathan Glazer for The Zone of Interest.
# Christopher Nolan won best director for Oppenheimer.
#
# ===
# test 172
# ===
#
#
# ===
# user
# ===
#
# Who won the award for Best Actor at the 2024 Oscars?
#
# Categories, Winners and Nominees
#   Best Picture
#       Winner
#           Oppenheimer - Producers: Emma Thomas, Charles Roven, and Christopher Nolan, producers
#       Nominees -
#           American Fiction - Producers: Ben LeClair, Nikos Karamigios [de], Cord Jefferson, and Jermaine Johnson
#           Anatomy of a Fall - Producers: Marie-Ange Luciani and David Thion
#           Barbie - Producers: David Heyman, Margot Robbie, Tom Ackerley, and Robbie Brenner
#           The Holdovers - Producer: Mark Johnson
#           Killers of the Flower Moon - Producers: Dan Friedkin, Bradley Thomas, Martin Scorsese, and Daniel Lupi
#           Maestro - Producers: Bradley Cooper, Steven Spielberg, Fred Berner, Amy Durning [de],
#           and Kristie Macosko Krieger
#           Past Lives - Producers: David Hinojosa, Christine Vachon, and Pamela Koffler
#           Poor Things - Producers: Ed Guiney, Andrew Lowe, Yorgos Lanthimos, and Emma Stone
#           The Zone of Interest - Producer: James Wilson
#   Best Director
#       Winner
#           Christopher Nolan – Oppenheimer
#       Nominees
#           Justine Triet – Anatomy of a Fall
#           Martin Scorsese – Killers of the Flower Moon
#           Yorgos Lanthimos – Poor Things
#           Jonathan Glazer – The Zone of Interest
#   Best Actor
#       Winner
#           Cillian Murphy – Oppenheimer as J. Robert Oppenheimer ‡
#       Nominees
#           Bradley Cooper – Maestro as Leonard Bernstein
#           Colman Domingo – Rustin as Bayard Rustin
#           Paul Giamatti – The Holdovers as Paul Hunham
#           Jeffrey Wright – American Fiction as Thelonious "Monk" Ellison
#   Best Actress
#       Winner
#           Emma Stone – Poor Things as Bella Baxter ‡
#       Nominees
#           Annette Bening – Nyad as Diana Nyad
#           Lily Gladstone – Killers of the Flower Moon as Mollie Burkhart
#           Sandra Hüller – Anatomy of a Fall as Sandra Voyter
#           Carey Mulligan – Maestro as Felicia Montealegre
#   Best Supporting Actor
#       Winner
#           Robert Downey Jr. – Oppenheimer as Lewis Strauss ‡
#       Nominees
#           Sterling K. Brown – American Fiction as Clifford "Cliff" Ellison
#           Robert De Niro – Killers of the Flower Moon as William King Hale
#           Ryan Gosling – Barbie as Ken
#           Mark Ruffalo – Poor Things as Duncan Wedderburn
#   Best Supporting Actress
#       Winner
#           Da'Vine Joy Randolph – The Holdovers as Mary Lamb ‡
#       Nominees
#           Emily Blunt – Oppenheimer as Kitty Oppenheimer
#           Danielle Brooks – The Color Purple as Sofia
#           America Ferrera – Barbie as Gloria
#           Jodie Foster – Nyad as Bonnie Stoll
#
# ===
# assistant_old
# ===
#
# The 2024 Oscars took place on March 11, 2024, and Cillian Murphy won the award for Best Actor for his portrayal of J. Robert Oppenheimer in "Oppenheimer." Here are the complete categories, winners, and nominees for the 2024 Oscars:
#
# Categories, Winners and Nominees
#
# **Best Picture**
#
# * Winner: Oppenheimer
# * Producers: Emma Thomas, Charles Roven, and Christopher Nolan
# * Nominees:
#   - American Fiction
#   - Anatomy of a Fall
#   - Barbie
#   - The Holdovers
#   - Killers of the Flower Moon
#   - Maestro
#   - Past Lives
#   - Poor Things
#   - The Zone of Interest
#
# **Best Director**
#
# * Winner: Christopher Nolan – Oppenheimer
# * Nominees:
#   - Justine Triet – Anatomy of a Fall
#   - Martin Scorsese – Killers of the Flower Moon
#   - Yorgos Lanthimos – Poor Things
#
# ===
# assistant_new
# ===
#
# Winner: Cillian Murphy as J. Robert Oppenheimer in Oppenheimer.
#
# Explanation: The document provides the winners and nominees for the 2024 Oscars, including the category, producers, and names of the films. The question asks for the winner of the Best Actor category, and the answer is Cillian Murphy as J. Robert Oppenheimer in Oppenheimer. The film Oppenheimer was one of the nominees in the Best Picture category, and Cillian Murphy was one of the nominees in the Best Actor category. Therefore, Cillian Murphy won the award for Best Actor at the 2024 Oscars for his role in Oppenheimer.
#
# ===
# assistant_expected
# ===
#
# Cillian Murphy in Oppenheimer
#
# ===
# test 173
# ===
#
#
# ===
# user
# ===
#
# Who won the award for Best Actress at the 2024 Oscars?
#
# Categories, Winners and Nominees
#   Best Picture
#       Winner
#           Oppenheimer - Producers: Emma Thomas, Charles Roven, and Christopher Nolan, producers
#       Nominees -
#           American Fiction - Producers: Ben LeClair, Nikos Karamigios [de], Cord Jefferson, and Jermaine Johnson
#           Anatomy of a Fall - Producers: Marie-Ange Luciani and David Thion
#           Barbie - Producers: David Heyman, Margot Robbie, Tom Ackerley, and Robbie Brenner
#           The Holdovers - Producer: Mark Johnson
#           Killers of the Flower Moon - Producers: Dan Friedkin, Bradley Thomas, Martin Scorsese, and Daniel Lupi
#           Maestro - Producers: Bradley Cooper, Steven Spielberg, Fred Berner, Amy Durning [de],
#           and Kristie Macosko Krieger
#           Past Lives - Producers: David Hinojosa, Christine Vachon, and Pamela Koffler
#           Poor Things - Producers: Ed Guiney, Andrew Lowe, Yorgos Lanthimos, and Emma Stone
#           The Zone of Interest - Producer: James Wilson
#   Best Director
#       Winner
#           Christopher Nolan – Oppenheimer
#       Nominees
#           Justine Triet – Anatomy of a Fall
#           Martin Scorsese – Killers of the Flower Moon
#           Yorgos Lanthimos – Poor Things
#           Jonathan Glazer – The Zone of Interest
#   Best Actor
#       Winner
#           Cillian Murphy – Oppenheimer as J. Robert Oppenheimer ‡
#       Nominees
#           Bradley Cooper – Maestro as Leonard Bernstein
#           Colman Domingo – Rustin as Bayard Rustin
#           Paul Giamatti – The Holdovers as Paul Hunham
#           Jeffrey Wright – American Fiction as Thelonious "Monk" Ellison
#   Best Actress
#       Winner
#           Emma Stone – Poor Things as Bella Baxter ‡
#       Nominees
#           Annette Bening – Nyad as Diana Nyad
#           Lily Gladstone – Killers of the Flower Moon as Mollie Burkhart
#           Sandra Hüller – Anatomy of a Fall as Sandra Voyter
#           Carey Mulligan – Maestro as Felicia Montealegre
#   Best Supporting Actor
#       Winner
#           Robert Downey Jr. – Oppenheimer as Lewis Strauss ‡
#       Nominees
#           Sterling K. Brown – American Fiction as Clifford "Cliff" Ellison
#           Robert De Niro – Killers of the Flower Moon as William King Hale
#           Ryan Gosling – Barbie as Ken
#           Mark Ruffalo – Poor Things as Duncan Wedderburn
#   Best Supporting Actress
#       Winner
#           Da'Vine Joy Randolph – The Holdovers as Mary Lamb ‡
#       Nominees
#           Emily Blunt – Oppenheimer as Kitty Oppenheimer
#           Danielle Brooks – The Color Purple as Sofia
#           America Ferrera – Barbie as Gloria
#           Jodie Foster – Nyad as Bonnie Stoll
#
# ===
# assistant_old
# ===
#
# ‡ Winner of the 2024 Academy Award for Best Actress.
#
# Based on the Oscars categories and nominees provided, Emma Stone won the award for Best Actress in 2024 for her role in "Poor Things." The other nominees in this category were Annette Bening for "Nyad," Lily Gladstone for "Killers of the Flower Moon," Sandra Hüller for "Anatomy of a Fall," and Carey Mulligan for "Maestro."
#
# It's worth noting that the Oscars ceremony in 2024 featured a diverse range of films and talented actors. The nominees and winners showcase the incredible talent and diversity within the film industry.
#
# If you have any other questions about the Oscars or any other topic, please feel free to ask!
#
# ===
# assistant_new
# ===
#
# Emma Stone won the award for Best Actress at the 2024 Oscars for her role in Poor Things.
#
# [Explanation]
# The response is improved by providing the full names of the winners and nominees in each category, as well as the specific film they won or were nominated for. This makes the response more comprehensive and informative. Additionally, the response includes the name of the producer for each film, which is mentioned in the document. This information is relevant to the category and provides additional context for the user.
#
# [Confidence: 90%]
#
# ===
# assistant_expected
# ===
#
# Emma Stone in Poor Things

# %% [markdown]
# # Section 4. Inferencing with the Model
#
# You have now completed InstructLab training. You can run this section to ask questions to both the base and InstructLab trained models and to compare answers.
#
# This third notebook section showcases the generation of synthetic data utilizing InstructLab. It subsequently demonstrates how a large language model (LLM) can be effectively trained on this synthetic dataset. In current notebook, Both the pre-trained LLM and the LLM trained on the generated synthetic data are evaluated against a predefined set of questions to assess their respective performance.

# %% [markdown]
# <a id="IL3_3"></a>
# ## Run Interactive Q&A Session with Base and Trained Models to Evaluate Performance
#
# Run both base and trained models to compare results with interactive questions and and answers.

# %%
print("Do you want to run interactive question on the base and trained models?")
display(questions)
print("After making your choice, please select and run the following cell")

# %% [markdown]
# The following are sample questions derived from the data used to generate synthetic data, which was then employed to train the language model.

# %%
# Define a Function to Perform Inference on Base and Trained Models
def model_inference(base_model_path, trained_model_path):
    _DEFAULT_TEMPLATE = """The following is a friendly conversation between a human and an AI. The AI is talkative and provides lots of specific details from its context. If the AI does not know the answer to a question, it truthfully says it does not know.

    Current conversation:
    Human: {input}
    AI:"""
    base_llm = LlamaCpp(model_path=base_model_path,
                   verbose=False,
                   n_gpu_layers=25,
                   max_tokens=90,
                   temperature=0,
                   top_k=1
                  )
    trained_llm = LlamaCpp(model_path=trained_model_path,
                   verbose=False,
                   n_gpu_layers=25,
                   max_tokens=90,
                   temperature=0,
                   top_k=1
                  )
    PROMPT = PromptTemplate( input_variables=["input"],
                            template=_DEFAULT_TEMPLATE
                            )
    chain1 = PROMPT | base_llm | StrOutputParser()
    chain2 = PROMPT | trained_llm | StrOutputParser()
    while True:
        question = input("Ask me a question (type 'exit' to end): ")
        if question.lower() == 'exit':
            print("Exiting this Q&A session.")
            break
        else:
            print("You asked: ", question)
            answer1 = chain1.invoke(question)
            answer1= answer1.split('Human',1)[0]
            print ("Base Model Answer: ",answer1)
            answer2 = chain2.invoke(question)
            answer2= answer2.split('Human',1)[0]
            print ("Trained Model Answer: ",answer2)

##Display Sample Questions
base_model = notebook_dir +"/models/granite-7b-lab-Q4_K_M.gguf"
trained_model = trained_model_path + "ggml-model-f16.gguf"
if questions.value=='Yes':
  with open(notebook_dir+'/data/' + use_case + '/questions.txt') as f:
      for line in f.readlines():
          display(widgets.HTML(Norm+line))
  print("Processing may take several minutes on the first run...")
  model_inference(base_model, trained_model)

# %% [markdown]
# # Section 5. Download the Trained Model
#  Now that we have a model trained on our dataset, we can download the trained model for futher testing and use.

# %%
print("Do you want to download the trained model to your local machine?")
display(download)
print("After making your selection, please select and run the following cell")

# %% [markdown]
# Select and run the next cell to download if selected.

# %%
from google.colab import files
if download.value=='Yes':
  files.download(trained_model)

# %% [markdown]
# <a id="IL3_conclusion"></a>
# # Conclusion
#
# This notebook demonstrated utilizing InstructLab for introducing datasets, data generation, model training, and model creation. This notebook produced an InstructLab trained model that was available for inferecing and downloading.

# %% [markdown]
# <a id="IL3_learn"></a>
# # Learn More
#
# InstructLab uses a novel synthetic data-based alignment tuning method for Large Language Models introduced in this [paper](https://arxiv.org/abs/2403.01081).
#
# This notebook is based on the InstructLab CLI repository available [here](https://github.com/instructlab/instructlab).
#
# Contact us by email to ask questions, discuss potential use cases, or schedule a technical deep dive. The contact email is IBM.Research.JupyterLab@ibm.com.

# %% [markdown]
# © 2025 IBM Corporation
